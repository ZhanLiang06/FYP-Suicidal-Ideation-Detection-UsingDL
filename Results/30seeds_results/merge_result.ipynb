# %%
import os
import pandas as pd

# %%
def parse_excel_all_folds(excel_path):
    """
    Parse all_folds.xlsx file where each sheet represents a seed,
    and combine all fold data into a single DataFrame.
    """
    if not os.path.exists(excel_path):
        raise FileNotFoundError(f"File not found: {excel_path}")
    
    try:
        # Read all sheets
        xl = pd.ExcelFile(excel_path, engine='openpyxl')
        all_folds_data = []
        
        for sheet_name in xl.sheet_names:
            df_sheet = pd.read_excel(excel_path, sheet_name=sheet_name, engine='openpyxl')
            all_folds_data.append(df_sheet)
        
        # Combine all sheets into one DataFrame
        df_combined = pd.concat(all_folds_data, ignore_index=True)
        
        print(f"Successfully loaded data from: {excel_path}")
        print(f"Number of sheets (seeds): {len(xl.sheet_names)}")
        print(f"Combined shape: {df_combined.shape}")
        print(f"Columns: {df_combined.columns.tolist()}")
        print(f"Unique seeds: {df_combined['Seed'].nunique()}")
        print(f"Unique folds: {sorted(df_combined['Fold'].unique())}")
        
        return df_combined
    
    except Exception as e:
        print(f"Error reading Excel file: {e}")
        raise

def merge_dataframes(F5_dir, L5_dir, basename):
    df_f5 = parse_excel_all_folds(F5_dir)
    df_l5 = parse_excel_all_folds(L5_dir)
    df_merged = pd.concat([df_f5, df_l5], ignore_index=True)
    output_dir = f'30ST2_{basename}'
    os.makedirs(output_dir, exist_ok=True)
    print(f"Merged DataFrame shape: {df_merged.shape}")
    df_merged.to_excel(os.path.join(output_dir, f"30ST2_{basename}_all_folds.xlsx"), index=False, engine='openpyxl')
    # save summary
    # Calculate summary statistics mean and std_dev
    metrics = [
            'Accuracy', 'Precision', 'Recall', 'F1-Score', 'ROC-AUC',
            'Training Time (s)', 'Epochs Run', 'Avg Time/Epoch (s)',
            'Min GPU Memory (MB)', 'Max GPU Memory (MB)', 'Avg GPU Memory (MB)',
            'Min GPU Utilization (%)', 'Max GPU Utilization (%)', 'Avg GPU Utilization (%)'
        ]
    summary_df = pd.DataFrame({
        'Mean': df_merged[metrics].mean(),
        'Std Dev': df_merged[metrics].std()
    })
    with pd.ExcelWriter(os.path.join(output_dir, f"30ST2_{basename}_summary.xlsx"), engine='openpyxl') as writer:
        # Sheet 1: Overall mean and std dev
        summary_df.to_excel(writer, sheet_name='Overall_Summary', index=True)
    summary_df
    return df_merged, summary_df

# %%
df_merged, summary_df = merge_dataframes(
    F5_dir='F15ST2_baseline_algo/F15ST2_baseline_algo_all_folds.xlsx',
    L5_dir='L15ST2_baseline_algo/L15ST2_baseline_algo_all_folds.xlsx',
    basename='baseline_algo')
df_merged
# Out:
# Successfully loaded data from: F15ST2_baseline_algo/F15ST2_baseline_algo_all_folds.xlsx
# Number of sheets (seeds): 15
# Combined shape: (15, 18)
# Columns: ['Fold', 'Accuracy', 'Precision', 'Recall', 'F1-Score', 'ROC-AUC', 'Training Time (s)', 'Epochs Run', 'Avg Time/Epoch (s)', 'Min GPU Memory (MB)', 'Max GPU Memory (MB)', 'Avg GPU Memory (MB)', 'Min GPU Utilization (%)', 'Max GPU Utilization (%)', 'Avg GPU Utilization (%)', 'Seed', 'Variant', 'Dataset']
# Unique seeds: 15
# Unique folds: [np.float64(nan)]
# Successfully loaded data from: L15ST2_baseline_algo/L15ST2_baseline_algo_all_folds.xlsx
# Number of sheets (seeds): 15
# Combined shape: (15, 18)
# Columns: ['Fold', 'Accuracy', 'Precision', 'Recall', 'F1-Score', 'ROC-AUC', 'Training Time (s)', 'Epochs Run', 'Avg Time/Epoch (s)', 'Min GPU Memory (MB)', 'Max GPU Memory (MB)', 'Avg GPU Memory (MB)', 'Min GPU Utilization (%)', 'Max GPU Utilization (%)', 'Avg GPU Utilization (%)', 'Seed', 'Variant', 'Dataset']
# Unique seeds: 15
# Unique folds: [np.float64(nan)]
# Merged DataFrame shape: (30, 18)
#     Fold  Accuracy  Precision    Recall  F1-Score   ROC-AUC  \
# 0    NaN  0.930358   0.919485  0.941996  0.930605  0.975789
# 1    NaN  0.903473   0.861186  0.960541  0.908154  0.973558
# 2    NaN  0.926438   0.917798  0.936353  0.926983  0.973006
# 8                  4345                 4345                       44
# 9                  4345                 4345                       45
# 10                 4347                 4347                       43
# 11                 4349                 4349                       43
# 12                 4351                 4351                       45
# 13                 4353                 4353                       43
# 14                 4353                 4353                       43
# 15                 4331                 4331                       43
# 16                 4333                 4333                       44
# 17                 4335                 4335                       45
# 18                 4337                 4337                       44
# 19                 4337                 4337                       43
# 20                 4339                 4339                       44
# 21                 4341                 4341                       43
# 22                 4343                 4343                       44
# 23                 4345                 4345                       46
# 24                 4345                 4345                       46
# 25                 4347                 4347                       43
# 26                 4349                 4349                       44
# 27                 4351                 4351                       44
# 28                 4353                 4353                       44
# 29                 4353                 4353                       45
#
#     Max GPU Utilization (%)  Avg GPU Utilization (%)        Seed  \
# 0                        61                53.166667          33
# 1                        63                54.033333          42
# 2                        63                56.100000    26960996
# 3                        63                56.133333   124354170
# 4                        62                54.200000   160056089
# 5                        63                52.300000   258361509
# 6                        61                52.300000   414753135
# 7                        62                53.266667   616149804
# 8                        60                53.400000   660103755
# 9                        62                53.333333   747224581
# 10                       62                52.233333   881851875
# 11                       60                51.600000  1025916409
# 12                       62                55.600000  1286254719
# 13                       62                53.933333  1299444710
# 14                       62                52.400000  1459061738
# 15                       63                55.800000  1631046987
# 16                       63                52.900000  2016059997
# 17                       63                52.800000  2581970541
# 18                       63                51.766667  2621477258
# 19                       63                53.500000  2759883259
# 20                       62                55.300000  2870689723
# 21                       62                54.233333  2925860425
# 22                       62                53.000000  3179792530
# 23                       63                55.033333  3332932065
# 24                       63                53.633333  3449897620
# 25                       63                54.833333  3722043193
# 26                       62                53.600000  3819511104
# 27                       62                54.400000  3968667185
# 28                       62                53.966667  4093008991
# 29                       62                54.333333  4130794218
#
#           Variant     Dataset
# 0   baseline_algo  Twitter II
# 1   baseline_algo  Twitter II
# 2   baseline_algo  Twitter II
# 3   baseline_algo  Twitter II
# 4   baseline_algo  Twitter II
# 5   baseline_algo  Twitter II
# 6   baseline_algo  Twitter II
# 7   baseline_algo  Twitter II
# 8   baseline_algo  Twitter II
# 9   baseline_algo  Twitter II
# 10  baseline_algo  Twitter II
# 11  baseline_algo  Twitter II
# 12  baseline_algo  Twitter II
# 13  baseline_algo  Twitter II
# 14  baseline_algo  Twitter II
# 15  baseline_algo  Twitter II
# 16  baseline_algo  Twitter II
# 17  baseline_algo  Twitter II
# 18  baseline_algo  Twitter II
# 19  baseline_algo  Twitter II
# 20  baseline_algo  Twitter II
# 21  baseline_algo  Twitter II
# 22  baseline_algo  Twitter II
# 23  baseline_algo  Twitter II
# 24  baseline_algo  Twitter II
# 25  baseline_algo  Twitter II
# 26  baseline_algo  Twitter II
# 27  baseline_algo  Twitter II
# 28  baseline_algo  Twitter II
# 29  baseline_algo  Twitter II

# %%
summary_df
# Out:
#                                 Mean   Std Dev
# Accuracy                    0.923120  0.009040
# Precision                   0.916313  0.020477
# Recall                      0.932435  0.026383
# F1-Score                    0.923789  0.010105
# ROC-AUC                     0.973395  0.003379
# Training Time (s)        1689.033618  8.126467
# Epochs Run                 30.000000  0.000000
# Avg Time/Epoch (s)         56.301121  0.270882
# Min GPU Memory (MB)      4342.600000  7.054468
# Max GPU Memory (MB)      4342.600000  7.054468
# Avg GPU Memory (MB)      4342.600000  7.054468
# Min GPU Utilization (%)    44.133333  1.074255
# Max GPU Utilization (%)    62.200000  0.846901
# Avg GPU Utilization (%)    53.770000  1.251737
