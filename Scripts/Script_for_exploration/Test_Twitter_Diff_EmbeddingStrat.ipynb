# %% [markdown]
# ## Imports

# %%
from google.colab import drive
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'
drive.mount('/content/drive')
folder_name = 'T_test_diff_embedding'
output_dir = f'/content/drive/MyDrive/final_FYP_results/{folder_name}'
os.makedirs(output_dir, exist_ok=True)
all_histories = []
# Out:
# Mounted at /content/drive

# %%
# !pip install keras-tcn
# !pip install keras-tcn --no-dependencies  # without the dependencies if you already have TF/Numpy.
# Out:
# Collecting keras-tcn
#   Downloading keras_tcn-3.5.6-py3-none-any.whl.metadata (13 kB)
# Downloading keras_tcn-3.5.6-py3-none-any.whl (12 kB)
# Installing collected packages: keras-tcn
# Successfully installed keras-tcn-3.5.6

# %%
import random
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
# from gensim.models import Word2Vec
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Layer
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

from nltk.tokenize import word_tokenize
from tensorflow.keras.preprocessing.sequence import pad_sequences

from nltk.corpus import stopwords

# import gensim
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
from nltk.corpus import stopwords

import warnings
warnings.filterwarnings(action = 'ignore')

import shutil

import tensorflow_hub as hub
import tensorflow_text as text
# from official.nlp import optimization  # to create AdamW optimizer

tf.get_logger().setLevel('ERROR')

import kagglehub

import ast

import sklearn
import seaborn as sns
from sklearn.model_selection import StratifiedKFold, train_test_split
import time

from tabulate import tabulate

import gc

import torch
from transformers import AutoTokenizer, AutoModel, TFBertModel  # Changed from TFAutoModel
from huggingface_hub import login

def set_all_seeds(seed):
  """Sets the seed for all relevant random number generators."""
  os.environ['PYTHONHASHSEED'] = str(seed)
  random.seed(seed)
  np.random.seed(seed)
  tf.random.set_seed(seed)
  # tf.config.experimental.enable_op_determinism()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
FOLDS=5
seed_value = 42
set_all_seeds(seed_value)

# %%
#Preprocessing function
def preprocessing_old(data_frame):
    ## Preprocessing
    # Removing URLs whithin the tweets
    data_frame["Text"] = data_frame["Text"].str.replace(r'\s*https?://\S+(\s+|$)', ' ', regex=True).str.strip()
    # Removing emails, hashtags and punctuations
    data_frame['Text'] = data_frame["Text"].str.replace(r'\S*@\S*\s?', ' ', regex=True).str.strip()
    data_frame['Text'] = data_frame['Text'].str.replace(r'#\S*\s?', ' ', regex=True).str.strip()
    data_frame['Text'] = data_frame['Text'].str.replace(r'[^\w\s]+', ' ', regex=True).str.strip()

    # Lowercase Text
    data_frame['Text'] = data_frame['Text'].str.lower()

    # # Removing stopwords
    stop = stopwords.words('english')
    data_frame['Text'].apply(lambda x: [item for item in str(x) if item not in stop])

    # Removing newline characters
    data_frame['Text'] = data_frame['Text'].str.rstrip()

    # Tokenizing Posts and counting the length of each post
    data_frame['Tokens'] = data_frame.apply(lambda row: word_tokenize(str(row['Text'])), axis=1)
    data_frame['Length'] = data_frame.apply(lambda row: len(row['Tokens']), axis=1)

    return data_frame

# %%
def extract_feature_bert(preprocessor, encoder, texts, seq_len=128, embedding_dim=512, batch_size=64):
    # Set layers to non-trainable for feature extraction
    encoder.trainable = False

    final_embeddings = np.zeros((len(texts), seq_len, embedding_dim), dtype=np.float32)
    print("\n Starting BERT feature extraction...")
    for i in range(0, len(texts), batch_size):
        batch_end = min(i + batch_size, len(texts))
        batch_texts = texts[i:batch_end]

        preprocessor_outputs = preprocessor(batch_texts.squeeze())
        encoder_outputs = encoder(preprocessor_outputs)

        sequence_embeddings = encoder_outputs["sequence_output"]

        final_embeddings[i:batch_end] = sequence_embeddings.numpy()
    print("Done")
    return final_embeddings

# %%
def data_preparation(df):
  df['Tokens'] = df['Tokens'].apply(lambda x: ast.literal_eval[x] if isinstance(x, str) else x)

  texts = [' '.join(row) for row in df['Tokens']]

  texts = pd.DataFrame(texts)
  X = np.array(texts)
  y = df['Label'].to_numpy()
  return X, y

# %%
def tokenize_process_mb(X):
    tokenizer = AutoTokenizer.from_pretrained("mental/mental-bert-base-uncased",from_pt=True)
    max_length = 128
    print("Tokenizing training data...")
    # .tolist() is safest if X_train is a pandas Series or numpy array
    X_tokenized = tokenizer(
        X.flatten().tolist(),
        max_length=max_length,
        truncation=True,
        padding="max_length",
        return_tensors="tf" # Return TensorFlow tensors
    )
    X_dict = dict(X_tokenized)
    return X_dict

def run_cross_validation(cv_splits, X, y, ModelClass, need_load_mental_bert=False, sequence_length=128, embedding_dim=512):
    batch_size = 64
    history_list = []  # Store history for each fold
    """
    Runs cross-validation for a given number of splits.

    Args:
        cv_splits (int): The number of folds for cross-validation (e.g., 5 or 10).

    Returns:
        pandas.DataFrame: A dataframe containing the results for each fold.
    """
    kfold = StratifiedKFold(n_splits=cv_splits, shuffle=True, random_state=42)

    # Lists to store results for each fold
    accuracies, precisions, recalls, f1_scores, roc_auc_scores, training_times = [], [], [], [], [], []
    fold_no = 1

    for train_idx, test_idx in kfold.split(X, y):
        print(f"--- Starting Fold {fold_no}/{cv_splits} ---")

        # Split data for this fold
        X_train_first, X_test = X[train_idx], X[test_idx]
        y_train_first, y_test = y[train_idx], y[test_idx]

        X_train, X_val, y_train, y_val = train_test_split(
            X_train_first,
            y_train_first,
            test_size=0.2,
            shuffle=True,
            stratify=y_train_first,
            random_state=42
        )

        if need_load_mental_bert:
            X_train = tokenize_process_mb(X_train)
            X_val = tokenize_process_mb(X_val)
            X_test = tokenize_process_mb(X_test)

        train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(batch_size)
        val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(batch_size)

        # --- Model Creation and Compilation ---
        # Re-create the model inside the loop for a fresh start in each fold
        strategy = tf.distribute.MirroredStrategy()
        with strategy.scope():
            if need_load_mental_bert:
                mental_bert_model = TFBertModel.from_pretrained("mental/mental-bert-base-uncased",from_pt=True)
                model = ModelClass(kernel_size = 8, activation='relu', enc_layer=mental_bert_model)
            else:
                model = ModelClass(kernel_size=8, activation='relu')
            model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['accuracy'])
            model.summary()

        epochs = 30

        early_stopping = EarlyStopping(
            monitor='val_loss',      # Monitor validation loss
            patience=7,              # Stop after 7 epochs with no improvement
            restore_best_weights=True,  # Restore weights from the best epoch
            verbose=1                # Print message when stopping
        )

        start_time = time.time()

        history = model.fit(
            train_dataset,
            validation_data=val_dataset,
            batch_size=64,
            epochs=epochs,
            verbose=1,
            callbacks=[early_stopping]
        )

        end_time = time.time()
        training_time = end_time - start_time
        training_times.append(training_time)

        # --- Evaluation ---
        test_dataset = tf.data.Dataset.from_tensor_slices((X_test)).batch(batch_size)
        pred_probs = model.predict(test_dataset)
        y_pred = (pred_probs > 0.5).astype(int)

        # Calculate metrics
        accuracy = sklearn.metrics.accuracy_score(y_test, y_pred)
        precision = sklearn.metrics.precision_score(y_test, y_pred)
        recall = sklearn.metrics.recall_score(y_test, y_pred)
        f1 = sklearn.metrics.f1_score(y_test, y_pred)
        roc_auc = sklearn.metrics.roc_auc_score(y_test, pred_probs)

        accuracies.append(accuracy)
        precisions.append(precision)
        recalls.append(recall)
        f1_scores.append(f1)
        roc_auc_scores.append(roc_auc)

        # Store history for this fold
        history_dict = {
            'fold': fold_no,
            'train_loss': history.history['loss'],
            'val_loss': history.history['val_loss'],
            'train_accuracy': history.history['accuracy'],
            'val_accuracy': history.history['val_accuracy']
        }
        history_list.append(history_dict)

        print(f"Fold {fold_no} Results: Accuracy={accuracy:.4f}, Precision={precision:.4f}, Recall={recall:.4f}, F1={f1:.4f}, ROC-AUC=={roc_auc:.4f}, Time={training_time:.2f}s")

        del model
        del history
        del train_dataset
        del val_dataset
        del test_dataset
        gc.collect()

        fold_no += 1

    # Create a DataFrame with the results
    results_df = pd.DataFrame({
        'Fold': list(range(1, cv_splits + 1)),
        'Accuracy': accuracies,
        'Precision': precisions,
        'Recall': recalls,
        'F1-Score': f1_scores,
        'ROC-AUC': roc_auc_scores,
        'Training Time (s)': training_times
    })

    return results_df, history_list

# %%
def run_cross_validation_no_early_stop(cv_splits, X, y, ModelClass, need_load_mental_bert=False, sequence_length=128, embedding_dim=512):
    batch_size = 64
    history_list = []  # Store history for each fold
    """
    Runs cross-validation for a given number of splits.

    Args:
        cv_splits (int): The number of folds for cross-validation (e.g., 5 or 10).

    Returns:
        pandas.DataFrame: A dataframe containing the results for each fold.
    """
    kfold = StratifiedKFold(n_splits=cv_splits, shuffle=True, random_state=42)

    # Lists to store results for each fold
    accuracies, precisions, recalls, f1_scores, roc_auc_scores, training_times = [], [], [], [], [], []
    fold_no = 1

    for train_idx, test_idx in kfold.split(X, y):
        print(f"--- Starting Fold {fold_no}/{cv_splits} ---")

        # Split data for this fold
        X_train_first, X_test = X[train_idx], X[test_idx]
        y_train_first, y_test = y[train_idx], y[test_idx]

        X_train, X_val, y_train, y_val = train_test_split(
            X_train_first,
            y_train_first,
            test_size=0.2,
            shuffle=True,
            stratify=y_train_first,
            random_state=42
        )

        if need_load_mental_bert:
            X_train = tokenize_process_mb(X_train)
            X_val = tokenize_process_mb(X_val)
            X_test = tokenize_process_mb(X_test)

        train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(batch_size)
        val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(batch_size)

        # --- Model Creation and Compilation ---
        # Re-create the model inside the loop for a fresh start in each fold
        strategy = tf.distribute.MirroredStrategy()
        with strategy.scope():
            if need_load_mental_bert:
                mental_bert_model = TFBertModel.from_pretrained("mental/mental-bert-base-uncased",from_pt=True)
                model = ModelClass(kernel_size = 8, activation='relu', enc_layer=mental_bert_model)
            else:
                model = ModelClass(kernel_size=8, activation='relu')
            model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['accuracy'])
            model.summary()

        epochs = 30

        start_time = time.time()

        history = model.fit(
            train_dataset,
            validation_data=val_dataset,
            batch_size=64,
            epochs=epochs,
            verbose=1
        )

        end_time = time.time()
        training_time = end_time - start_time
        training_times.append(training_time)

        # --- Evaluation ---
        test_dataset = tf.data.Dataset.from_tensor_slices((X_test)).batch(batch_size)
        pred_probs = model.predict(test_dataset)
        y_pred = (pred_probs > 0.5).astype(int)

        # Calculate metrics
        accuracy = sklearn.metrics.accuracy_score(y_test, y_pred)
        precision = sklearn.metrics.precision_score(y_test, y_pred)
        recall = sklearn.metrics.recall_score(y_test, y_pred)
        f1 = sklearn.metrics.f1_score(y_test, y_pred)
        roc_auc = sklearn.metrics.roc_auc_score(y_test, pred_probs)

        accuracies.append(accuracy)
        precisions.append(precision)
        recalls.append(recall)
        f1_scores.append(f1)
        roc_auc_scores.append(roc_auc)

        # Store history for this fold
        history_dict = {
            'fold': fold_no,
            'train_loss': history.history['loss'],
            'val_loss': history.history['val_loss'],
            'train_accuracy': history.history['accuracy'],
            'val_accuracy': history.history['val_accuracy']
        }
        history_list.append(history_dict)

        print(f"Fold {fold_no} Results: Accuracy={accuracy:.4f}, Precision={precision:.4f}, Recall={recall:.4f}, F1={f1:.4f}, ROC-AUC=={roc_auc:.4f}, Time={training_time:.2f}s")

        del model
        del history
        del train_dataset
        del val_dataset
        del test_dataset
        gc.collect()

        fold_no += 1

    # Create a DataFrame with the results
    results_df = pd.DataFrame({
        'Fold': list(range(1, cv_splits + 1)),
        'Accuracy': accuracies,
        'Precision': precisions,
        'Recall': recalls,
        'F1-Score': f1_scores,
        'ROC-AUC': roc_auc_scores,
        'Training Time (s)': training_times
    })

    return results_df, history_list

# %%
def analyze_cv_results(results_df):
    """
    Analyzes and visualizes cross-validation results, consolidating
    plots for easier comparison.

    Args:
        results_df (pd.DataFrame): The DataFrame from run_cross_validation.
    """
    # --- Automatically get the variant name from the DataFrame ---
    if 'Variant' not in results_df.columns:
        print("Error: 'Variant' column not found in the DataFrame.")
        return
    variant_name = results_df['Variant'].iloc[0]
    print(f"--- Analysis for: {variant_name} - Twitter ---")
    print("-" * 50)

    # --- 1. Show the raw result ---
    print("\n[Raw Results per Fold]")
    # Use to_string() to ensure all rows/columns are printed
    print(results_df.drop(columns='Variant').to_string())

    # --- 2. Show the mean and standard deviation for each metric ---
    all_metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score', 'ROC-AUC', 'Training Time (s)']
    summary_stats = results_df[all_metrics].agg(['mean', 'std']).T
    print("\n[Summary Statistics]")
    print(summary_stats)
    print("-" * 50)

    # --- 3. Show total training time ---
    total_time = results_df['Training Time (s)'].sum()
    print(f"\n[Total Training Time]: {total_time} seconds")

    # Define performance metrics for plotting (scale 0-1)
    performance_metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score', 'ROC-AUC']

    # Reshape the data from wide to long format for easier plotting with Seaborn
    df_melted = results_df.melt(
        id_vars='Fold',
        value_vars=performance_metrics,
        var_name='Metric',
        value_name='Score'
    )

    # --- 3. Create a single plot with multiple box plots ---
    plt.style.use('seaborn-v0_8-whitegrid') # Use a modern seaborn style
    plt.figure(figsize=(12, 7))
    sns.boxplot(x='Metric', y='Score', data=df_melted, palette='pastel')
    plt.title(f'Metric Distribution for {variant_name} - Twitter', fontsize=16)
    plt.ylabel("Score")
    plt.xlabel("Metric Type")
    plt.show()
    print("")

    # --- 4. Create a single plot with multiple line plots ---
    plt.figure(figsize=(12, 7))
    sns.lineplot(x='Fold', y='Score', hue='Metric', data=df_melted, marker='o', palette='viridis')
    plt.title(f'Metric Performance Across Folds for {variant_name} - Twitter', fontsize=16)
    plt.ylabel("Score")
    plt.xlabel("Fold Number")
    plt.xticks(results_df['Fold'])
    plt.legend(loc='lower right')
    plt.show()
    print("")

    # --- Bar Chart for Training Time per Fold ---
    plt.figure(figsize=(10, 6))
    ax = sns.barplot(x='Fold', y='Training Time (s)', data=results_df, palette='rocket')
    for container in ax.containers:
      ax.bar_label(container, fmt='%.2f')
    plt.title(f'Training Time per Fold for {variant_name} - Twitter (seconds)', fontsize=16)
    plt.ylabel("Training Time (seconds)")
    plt.xlabel("Fold Number")
    plt.xticks(results_df['Fold'])
    plt.grid(axis='y', linestyle='--')
    plt.show()
    print("")

    del variant_name
    del all_metrics
    del summary_stats
    del total_time
    del df_melted
    gc.collect()

# %% [markdown]
# ## BERT Model

# %%
bert_model_name = 'small_bert/bert_en_uncased_L-4_H-512_A-8'

map_name_to_handle = {
    'bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/3',
    'bert_en_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_cased_L-12_H-768_A-12/3',
    'bert_multi_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_multi_cased_L-12_H-768_A-12/3',
    'small_bert/bert_en_uncased_L-2_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-2_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-2_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-2_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-4_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-4_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-4_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-4_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-6_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-6_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-6_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-6_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-8_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-8_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-8_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-8_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-10_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-10_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-10_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-10_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-12_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-12_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-12_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-768_A-12/1',
    'albert_en_base':
        'https://tfhub.dev/tensorflow/albert_en_base/2',
    'electra_small':
        'https://tfhub.dev/google/electra_small/2',
    'electra_base':
        'https://tfhub.dev/google/electra_base/2',
    'experts_pubmed':
        'https://tfhub.dev/google/experts/bert/pubmed/2',
    'experts_wiki_books':
        'https://tfhub.dev/google/experts/bert/wiki_books/2',
    'talking-heads_base':
        'https://tfhub.dev/tensorflow/talkheads_ggelu_bert_en_base/1',
}

map_model_to_preprocess = {
    'bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'bert_en_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_cased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'bert_multi_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_multi_cased_preprocess/3',
    'albert_en_base':
        'https://tfhub.dev/tensorflow/albert_en_preprocess/3',
    'electra_small':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'electra_base':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'experts_pubmed':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'experts_wiki_books':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'talking-heads_base':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
}

tfhub_handle_encoder = map_name_to_handle[bert_model_name]
tfhub_handle_preprocess = map_model_to_preprocess[bert_model_name]

print(f'BERT model selected           : {tfhub_handle_encoder}')
print(f'Preprocess model auto-selected: {tfhub_handle_preprocess}')
# bert_model_name = 'small_bert/bert_en_uncased_L-4_H-512_A-8'
# BERT model selected           : https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-512_A-8/1
# Preprocess model auto-selected: https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3
# Out:
# BERT model selected           : https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-512_A-8/1
# Preprocess model auto-selected: https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3

# %%
# Download selected bert version
preprocessor_path = kagglehub.model_download("tensorflow/bert/tensorFlow2/en-uncased-preprocess")
print("preprocessor_path to model files:", preprocessor_path)
bert_path = kagglehub.model_download("tensorflow/bert/tensorFlow2/bert-en-uncased-l-4-h-512-a-8/1")
print("preprocessor_path to model files:", bert_path)
# Out:
# preprocessor_path to model files: /kaggle/input/bert/tensorflow2/en-uncased-preprocess/3
# preprocessor_path to model files: /kaggle/input/bert/tensorflow2/bert-en-uncased-l-4-h-512-a-8/1

# %%
os.environ["HF_TOKEN"] = ""
login(token=os.environ["HF_TOKEN"])

# 1. Load the tokenizer and the PyTorch model
# The `AutoModel` class automatically loads the PyTorch weights.
tokenizer = AutoTokenizer.from_pretrained("mental/mental-bert-base-uncased")
model = AutoModel.from_pretrained("mental/mental-bert-base-uncased")
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# tokenizer_config.json:   0%|          | 0.00/321 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/639 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Some weights of BertModel were not initialized from the model checkpoint at mental/mental-bert-base-uncased and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ## Model

# %%
# a custome Attention layer
class CustAttention(Layer):
  def __init__ (self, return_sequences=True):
    self.return_sequences = return_sequences
    super(CustAttention, self).__init__()

  def build (self, input_shape):
    self.W = self.add_weight(name="att_weight", shape=(input_shape[-1],1), initializer="normal")
    self.b = self.add_weight(name="att_bias", shape=(input_shape[1],1), initializer="zeros")
    super(CustAttention, self).build(input_shape)

  def call(self, x):
    e = K.tanh(K.dot(x, self.W)+self.b)
    a = K.softmax(e, axis=1)
    output = x*a
    if self.return_sequences:
      return output
    return K.sum(output, axis = 1)

# a custome Attention layer
class AttentionForSeqOut(Layer):
  def __init__ (self, return_sequences=True):
    self.return_sequences = return_sequences
    super(AttentionForSeqOut, self).__init__()

  def build (self, input_shape):
    self.W = self.add_weight(name="att_weight", shape=(input_shape[-1],1), initializer="normal")
    self.b = self.add_weight(name="att_bias", shape=(128,1), initializer="zeros")
    super(AttentionForSeqOut, self).build(input_shape)

  def call(self, x):
    e = K.tanh(K.dot(x, self.W)+self.b)
    a = K.softmax(e, axis=1)
    output = x*a
    if self.return_sequences:
      return output
    return K.sum(output, axis = 1)

# %%
# !pip install tensorflow_text
import tensorflow_text as text
# Out:
# Requirement already satisfied: tensorflow_text in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: tensorflow<2.20,>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_text) (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19.0->tensorflow_text) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow<2.20,>=2.19.0->tensorflow_text) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19.0->tensorflow_text) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19.0->tensorflow_text) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19.0->tensorflow_text) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19.0->tensorflow_text) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19.0->tensorflow_text) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19.0->tensorflow_text) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19.0->tensorflow_text) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19.0->tensorflow_text) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19.0->tensorflow_text) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19.0->tensorflow_text) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<2.20,>=2.19.0->tensorflow_text) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19.0->tensorflow_text) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19.0->tensorflow_text) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.20,>=2.19.0->tensorflow_text) (0.1.2)
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %%
from tcn import TCN, tcn_full_summary
from keras.layers import Bidirectional
from tensorflow.keras.initializers import RandomNormal, Constant

from tensorflow.keras.layers import Bidirectional, Dense, Input, Embedding, Conv1D, GlobalMaxPooling1D, Dropout, LSTM
from tensorflow.compat.v1.keras.layers import CuDNNLSTM
from tensorflow.keras import regularizers
from tensorflow.keras.models import *

def tcn_model_fine_tune_sb_pool(kernel_size = 3, activation='relu'):

    text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
    preprocessing_layer = hub.KerasLayer(tfhub_handle_preprocess, name='preprocessing')
    encoder_inputs = preprocessing_layer(text_input)
    encoder = hub.KerasLayer(tfhub_handle_encoder, trainable=True, name='BERT_encoder')
    outputs = encoder(encoder_inputs)
    net = outputs['pooled_output']

    x = tf.expand_dims(net, axis=1)  # Add a dummy dimension for timesteps

    x = SpatialDropout1D(0.1)(x)
    # x = LSTM(100, stateful=False, return_sequences = True)(x)
    x = CuDNNLSTM(100, stateful=False, return_sequences = True)(x)

    x = Bidirectional(TCN(128,dilations = [1, 2, 4], return_sequences=True, activation = activation, name = 'tcn1'))(x)
    x = Bidirectional(TCN(64,dilations = [1, 2, 4], return_sequences=True, activation = activation, name = 'tcn2'))(x)
    x = CustAttention(return_sequences=True)(x)

    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)

    conc = concatenate([avg_pool, max_pool])
    conc = Dense(16, activation="relu")(conc)
    conc = Dropout(0.1)(conc)

    output = Dense(1, activation="sigmoid")(conc)
    # output = Dense(2, activation="softmax")(conc)

    model = Model(inputs=text_input, outputs=output)
    # Verify
    trainable_count = sum([tf.size(w).numpy() for w in model.trainable_weights])
    non_trainable_count = sum([tf.size(w).numpy() for w in model.non_trainable_weights])
    print(f"\nTrainable params: {trainable_count:,}")
    print(f"Non-trainable params: {non_trainable_count:,}")
    return model

def tcn_model_fine_tune_sb_seqOut(kernel_size = 3, activation='relu'):

    text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
    preprocessing_layer = hub.KerasLayer(tfhub_handle_preprocess, name='preprocessing')
    encoder_inputs = preprocessing_layer(text_input)
    encoder = hub.KerasLayer(tfhub_handle_encoder, trainable=True, name='BERT_encoder')
    outputs = encoder(encoder_inputs)
    net = outputs['sequence_output']

    x = SpatialDropout1D(0.1)(net)
    # x = LSTM(100, stateful=False, return_sequences = True)(x)
    x = CuDNNLSTM(100, stateful=False, return_sequences = True)(x)

    x = Bidirectional(TCN(128,dilations = [1, 2, 4], return_sequences=True, activation = activation, name = 'tcn1'))(x)
    x = Bidirectional(TCN(64,dilations = [1, 2, 4], return_sequences=True, activation = activation, name = 'tcn2'))(x)
    x = AttentionForSeqOut(return_sequences=True)(x)

    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)

    conc = concatenate([avg_pool, max_pool])
    conc = Dense(16, activation="relu")(conc)
    conc = Dropout(0.1)(conc)

    output = Dense(1, activation="sigmoid")(conc)
    # output = Dense(2, activation="softmax")(conc)

    model = Model(inputs=text_input, outputs=output)
    # Verify
    trainable_count = sum([tf.size(w).numpy() for w in model.trainable_weights])
    non_trainable_count = sum([tf.size(w).numpy() for w in model.non_trainable_weights])
    print(f"\nTrainable params: {trainable_count:,}")
    print(f"Non-trainable params: {non_trainable_count:,}")
    return model

#pooled
def tcn_model_fine_tune_mb_pool(kernel_size = 3, activation='relu', enc_layer=None):

    input_ids = tf.keras.layers.Input(
        shape=(128,), dtype=tf.int32, name='input_ids'
    )
    token_type_ids = tf.keras.layers.Input(
        shape=(128,), dtype=tf.int32, name='token_type_ids'
    )
    attention_mask = tf.keras.layers.Input(
        shape=(128,), dtype=tf.int32, name='attention_mask'
    )
    enc_outputs = enc_layer(
        {
            'input_ids': input_ids,
            'token_type_ids': token_type_ids,
            'attention_mask': attention_mask
        }
    ).pooler_output

    x = tf.expand_dims(enc_outputs, axis=1)  # Add a dummy dimension for timesteps

    x = SpatialDropout1D(0.1)(x)
    # x = LSTM(100, stateful=False, return_sequences = True)(x)
    x = CuDNNLSTM(100, stateful=False, return_sequences = True)(x)

    x = Bidirectional(TCN(128,dilations = [1, 2, 4], return_sequences=True, activation = activation, name = 'tcn1'))(x)
    x = Bidirectional(TCN(64,dilations = [1, 2, 4], return_sequences=True, activation = activation, name = 'tcn2'))(x)
    x = CustAttention(return_sequences=True)(x)

    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)

    conc = concatenate([avg_pool, max_pool])
    conc = Dense(16, activation="relu")(conc)
    conc = Dropout(0.1)(conc)

    output = Dense(1, activation="sigmoid")(conc)
    # output = Dense(2, activation="softmax")(conc)

    model = Model(inputs=[input_ids, attention_mask, token_type_ids], outputs=output)
    # Verify
    trainable_count = sum([tf.size(w).numpy() for w in model.trainable_weights])
    non_trainable_count = sum([tf.size(w).numpy() for w in model.non_trainable_weights])
    print(f"\nTrainable params: {trainable_count:,}")
    print(f"Non-trainable params: {non_trainable_count:,}")
    return model

def tcn_model_fine_tune_mb_seqOut(kernel_size = 3, activation='relu', enc_layer=None):

    input_ids = tf.keras.layers.Input(
        shape=(128,), dtype=tf.int32, name='input_ids'
    )
    token_type_ids = tf.keras.layers.Input(
        shape=(128,), dtype=tf.int32, name='token_type_ids'
    )
    attention_mask = tf.keras.layers.Input(
        shape=(128,), dtype=tf.int32, name='attention_mask'
    )
    enc_outputs = enc_layer(
        {
            'input_ids': input_ids,
            'token_type_ids': token_type_ids,
            'attention_mask': attention_mask
        }
    ).last_hidden_state

    x = SpatialDropout1D(0.1)(enc_outputs)
    # x = LSTM(100, stateful=False, return_sequences = True)(x)
    x = CuDNNLSTM(100, stateful=False, return_sequences = True)(x)

    x = Bidirectional(TCN(128,dilations = [1, 2, 4], return_sequences=True, activation = activation, name = 'tcn1'))(x)
    x = Bidirectional(TCN(64,dilations = [1, 2, 4], return_sequences=True, activation = activation, name = 'tcn2'))(x)
    x = CustAttention(return_sequences=True)(x)

    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)

    conc = concatenate([avg_pool, max_pool])
    conc = Dense(16, activation="relu")(conc)
    conc = Dropout(0.1)(conc)

    output = Dense(1, activation="sigmoid")(conc)
    # output = Dense(2, activation="softmax")(conc)

    model = Model(inputs=[input_ids, attention_mask, token_type_ids], outputs=output)
    # Verify
    trainable_count = sum([tf.size(w).numpy() for w in model.trainable_weights])
    non_trainable_count = sum([tf.size(w).numpy() for w in model.non_trainable_weights])
    print(f"\nTrainable params: {trainable_count:,}")
    print(f"Non-trainable params: {non_trainable_count:,}")
    return model


def tcn_model_sb_precompute_pool(embedding_dim=512, kernel_size = 3, activation='relu'):

    embedding_input = Input(shape=(embedding_dim), dtype='float32', name='embedding_input')

    x = tf.expand_dims(embedding_input, axis=1)
    x = SpatialDropout1D(0.1)(x)
    # x = LSTM(100, stateful=False, return_sequences = True)(x)
    x = CuDNNLSTM(100, stateful=False, return_sequences = True)(x)

    x = Bidirectional(TCN(128,dilations = [1, 2, 4], return_sequences=True, activation = activation, name = 'tcn1'))(x)
    x = Bidirectional(TCN(64,dilations = [1, 2, 4], return_sequences=True, activation = activation, name = 'tcn2'))(x)
    x = CustAttention(return_sequences=True)(x)

    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)

    conc = concatenate([avg_pool, max_pool])
    conc = Dense(16, activation="relu")(conc)
    conc = Dropout(0.1)(conc)

    output = Dense(1, activation="sigmoid")(conc)
    # output = Dense(2, activation="softmax")(conc)

    model = Model(inputs=embedding_input, outputs=output)
    return model

def tcn_model_sb_precompute_seqOut(sequence_length=128, embedding_dim=512, kernel_size = 3, activation='relu'):

    embedding_input = Input(shape=(sequence_length, embedding_dim), dtype='float32', name='embedding_input')

    x = SpatialDropout1D(0.1)(embedding_input)
    # x = LSTM(100, stateful=False, return_sequences = True)(x)
    x = CuDNNLSTM(100, stateful=False, return_sequences = True)(x)

    x = Bidirectional(TCN(128,dilations = [1, 2, 4], return_sequences=True, activation = activation, name = 'tcn1'))(x)
    x = Bidirectional(TCN(64,dilations = [1, 2, 4], return_sequences=True, activation = activation, name = 'tcn2'))(x)
    x = CustAttention(return_sequences=True)(x)

    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)

    conc = concatenate([avg_pool, max_pool])
    conc = Dense(16, activation="relu")(conc)
    conc = Dropout(0.1)(conc)

    output = Dense(1, activation="sigmoid")(conc)
    # output = Dense(2, activation="softmax")(conc)

    model = Model(inputs=embedding_input, outputs=output)
    return model

def tcn_model_mb_precompute_pool(embedding_dim=768, kernel_size = 3, activation='relu'):

    embedding_input = Input(shape=(embedding_dim), dtype='float32', name='embedding_input')

    x = tf.expand_dims(embedding_input, axis=1)
    x = SpatialDropout1D(0.1)(x)
    # x = LSTM(100, stateful=False, return_sequences = True)(x)
    x = CuDNNLSTM(100, stateful=False, return_sequences = True)(x)

    x = Bidirectional(TCN(128,dilations = [1, 2, 4], return_sequences=True, activation = activation, name = 'tcn1'))(x)
    x = Bidirectional(TCN(64,dilations = [1, 2, 4], return_sequences=True, activation = activation, name = 'tcn2'))(x)
    x = CustAttention(return_sequences=True)(x)

    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)

    conc = concatenate([avg_pool, max_pool])
    conc = Dense(16, activation="relu")(conc)
    conc = Dropout(0.1)(conc)

    output = Dense(1, activation="sigmoid")(conc)
    # output = Dense(2, activation="softmax")(conc)

    model = Model(inputs=embedding_input, outputs=output)
    return model

def tcn_model_mb_precompute_seqOut(sequence_length=128, embedding_dim=768, kernel_size = 3, activation='relu'):

    embedding_input = Input(shape=(sequence_length, embedding_dim), dtype='float32', name='embedding_input')

    x = SpatialDropout1D(0.1)(embedding_input)
    # x = LSTM(100, stateful=False, return_sequences = True)(x)
    x = CuDNNLSTM(100, stateful=False, return_sequences = True)(x)

    x = Bidirectional(TCN(128,dilations = [1, 2, 4], return_sequences=True, activation = activation, name = 'tcn1'))(x)
    x = Bidirectional(TCN(64,dilations = [1, 2, 4], return_sequences=True, activation = activation, name = 'tcn2'))(x)
    x = CustAttention(return_sequences=True)(x)

    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)

    conc = concatenate([avg_pool, max_pool])
    conc = Dense(16, activation="relu")(conc)
    conc = Dropout(0.1)(conc)

    output = Dense(1, activation="sigmoid")(conc)
    # output = Dense(2, activation="softmax")(conc)

    model = Model(inputs=embedding_input, outputs=output)
    return model

# %%
def extract_feature_bert_sequence(preprocessor, encoder, texts, seq_len=128, embedding_dim=512, batch_size=64):
    # Set layers to non-trainable for feature extraction
    encoder.trainable = False

    final_embeddings = np.zeros((len(texts), seq_len, embedding_dim), dtype=np.float32)
    print("\n Starting BERT feature extraction...")
    for i in range(0, len(texts), batch_size):
        batch_end = min(i + batch_size, len(texts))
        batch_texts = texts[i:batch_end]

        preprocessor_outputs = preprocessor(batch_texts.squeeze())
        encoder_outputs = encoder(preprocessor_outputs)

        sequence_embeddings = encoder_outputs["sequence_output"]

        final_embeddings[i:batch_end] = sequence_embeddings.numpy()
    print("Done")
    return final_embeddings

def extract_feature_bert_pooled(preprocessor, encoder, texts, seq_len=128, embedding_dim=512, batch_size=64):
    # Set layers to non-trainable for feature extraction
    encoder.trainable = False

    final_embeddings = np.zeros((len(texts), embedding_dim), dtype=np.float32)
    print("\n Starting BERT feature extraction...")
    for i in range(0, len(texts), batch_size):
        batch_end = min(i + batch_size, len(texts))
        batch_texts = texts[i:batch_end]

        preprocessor_outputs = preprocessor(batch_texts.squeeze())
        encoder_outputs = encoder(preprocessor_outputs)

        pooled_embeddings = encoder_outputs["pooled_output"]

        final_embeddings[i:batch_end] = pooled_embeddings.numpy()
    print("Done")
    return final_embeddings

def extract_feature_mb_sequence(tokenizer, model, texts, seq_len=128, batch_size=64):
    embedding_dim = model.config.hidden_size
    texts = np.array(texts)
    # Handle numpy array input
    if isinstance(texts, np.ndarray):
        if texts.ndim > 1:
            texts = texts.squeeze()
        texts = texts.tolist()

    n_texts = len(texts)
    final_embeddings = np.zeros((n_texts, seq_len, embedding_dim), dtype=np.float32)
    # Set model to evaluation model
    model.eval()
    # Determine device (GPU if available, otherwise CPU)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    print("\nStarting BERT feature extraction...")
    with torch.no_grad():  # Disable gradient computation for inference
        for i in range(0, n_texts, batch_size):
            batch_end = min(i + batch_size, n_texts)
            batch_texts = texts[i:batch_end]

            # Tokenize batch
            encoded = tokenizer(
                batch_texts,
                padding='max_length',
                truncation=True,
                max_length=seq_len,
                return_tensors='pt',
                return_attention_mask=True,
                add_special_tokens=True
            )

            # Move inputs to device
            encoded = {key: val.to(device) for key, val in encoded.items()}

            # Get model outputs
            outputs = model(**encoded)

            # Extract sequence embeddings (last hidden state)
            embeddings = outputs.last_hidden_state

            # Convert to numpy and store
            final_embeddings[i:batch_end] = embeddings.cpu().numpy()

            print(f"Processed {batch_end}/{n_texts} texts", end='\r')

    print("\nDone")
    return final_embeddings


def extract_feature_mb_pooled(tokenizer, model, texts, seq_len=128, batch_size=64):
    embedding_dim = model.config.hidden_size
    texts = np.array(texts)
    # Handle numpy array input
    if isinstance(texts, np.ndarray):
        if texts.ndim > 1:
            texts = texts.squeeze()
        texts = texts.tolist()

    n_texts = len(texts)
    final_embeddings = np.zeros((n_texts, embedding_dim), dtype=np.float32)
    # Set model to evaluation model
    model.eval()
    # Determine device (GPU if available, otherwise CPU)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    print("\nStarting BERT feature extraction...")
    with torch.no_grad():  # Disable gradient computation for inference
        for i in range(0, n_texts, batch_size):
            batch_end = min(i + batch_size, n_texts)
            batch_texts = texts[i:batch_end]

            # Tokenize batch
            encoded = tokenizer(
                batch_texts,
                padding='max_length',
                truncation=True,
                max_length=seq_len,
                return_tensors='pt',
                return_attention_mask=True,
                add_special_tokens=True
            )

            # Move inputs to device
            encoded = {key: val.to(device) for key, val in encoded.items()}

            # Get model outputs
            outputs = model(**encoded)

            # Extract sequence embeddings (last hidden state)
            embeddings = outputs.pooler_output

            # Convert to numpy and store
            final_embeddings[i:batch_end] = embeddings.cpu().numpy()

            print(f"Processed {batch_end}/{n_texts} texts", end='\r')

    print("\nDone")
    return final_embeddings

# %%
all_results = []

# %%
# Old Preprocess Twitter
Twitter_path = "/content/twitter-suicidal_data.csv"
df_twitter = pd.read_csv(Twitter_path, encoding='latin-1')
df_twitter = df_twitter.rename(columns={'tweet': 'Text', 'intention': 'Label'})
df_twitter = preprocessing_old(df_twitter)
print(df_twitter)

print(list(df_twitter['Label']).count(1), list(df_twitter['Label']).count(0))

X, y = data_preparation(df_twitter)
print(X)
del df_twitter
gc.collect()
# Out:
#                                                    Text  Label  \
# 0     my life is meaningless i just want to end my l...      1
# 1     muttering i wanna die to myself daily for a fe...      1
# 2     work slave i really feel like my only purpose ...      1
# 3     i did something on the 2 of october i overdose...      1
# 4     i feel like no one cares i just want to die ma...      1
# ...                                                 ...    ...
# 9114  have you ever laid on your bed at night and cr...      1
# 9115  the fault the blame the pain s still there i m...      1
# 9116  stop asking me to trust you when i m still cou...      1
# 9117  i never know how to handle sadness crying make...      1
# 9118  when cancer takes a life we blame cancer depre...      1
#
#                                                  Tokens  Length
# 0     [my, life, is, meaningless, i, just, want, to,...      79
# 1     [muttering, i, wan, na, die, to, myself, daily...      46
# 2     [work, slave, i, really, feel, like, my, only,...      69
# 3     [i, did, something, on, the, 2, of, october, i...      77
# 4     [i, feel, like, no, one, cares, i, just, want,...      18
# ...                                                 ...     ...
# 9114  [have, you, ever, laid, on, your, bed, at, nig...      33
# 9115  [the, fault, the, blame, the, pain, s, still, ...      20
# 9116  [stop, asking, me, to, trust, you, when, i, m,...      22
# 9117  [i, never, know, how, to, handle, sadness, cry...      12
# 9118  [when, cancer, takes, a, life, we, blame, canc...      21
#
# [9119 rows x 4 columns]
# 3998 5121
# [['my life is meaningless i just want to end my life so badly my life is completely empty and i dont want to have to create meaning in it creating meaning is pain how long will i hold back the urge to run my car head first into the next person coming the opposite way when will i stop feeling jealous of tragic characters like gomer pile for the swift end they were able to bring to their lives']
#  ['muttering i wan na die to myself daily for a few months now i feel worthless shes my soulmate i cant live in this horrible world without her i am so lonely i wish i could just turn off the part of my brain that feels']
#  ['work slave i really feel like my only purpose in life is to make a higher man money parents forcing me through college and i have too much on my plate i owe a lot of money i know this is the easy way out but i am really tired all of these issues are on top of dealing with tensions in america as well i want to rest']
#  ...
#  ['stop asking me to trust you when i m still coughing up the water from the last time you let me drown']
#  ['i never know how to handle sadness crying makes me feel stupid']
#  ['when cancer takes a life we blame cancer depression is a disease don t blame the victim for losing the fight']]
# 20

# %%
#baseline_tcn_model_fine_tune_sb_pool_no_early_stop
result, history_list = run_cross_validation_no_early_stop(FOLDS, X, y, tcn_model_fine_tune_sb_pool,False)
variant_name = "baseline_tcn_model_fine_tune_sb_pool_no_early_stop"
result['Variant'] = variant_name
result['Dataset'] = 'Twitter'
all_results.append(result)
analyze_cv_results(result)

for hist in history_list:
    hist['Variant'] = variant_name
    all_histories.extend(history_list)

output_filename = f'/content/drive/MyDrive/final_FYP_results/{folder_name}/{variant_name}_twitter_result.csv'
result.to_csv(output_filename, index=False)
del output_filename
del history_list
del result
gc.collect()
# Out:
# --- Starting Fold 1/5 ---
#
# Trainable params: 29,864,066
# Non-trainable params: 1
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  text (InputLayer)           [(None,)]                    0         []
#
#  preprocessing (KerasLayer)  {'input_type_ids': (None,    0         ['text[0][0]']
#                              128),
#                               'input_mask': (None, 128)
#                              , 'input_word_ids': (None,
#                               128)}
#
#  BERT_encoder (KerasLayer)   {'pooled_output': (None, 5   2876364   ['preprocessing[0][0]',
#                              12),                         9          'preprocessing[0][1]',
#                               'sequence_output': (None,              'preprocessing[0][2]']
#                               None, 512),
#                               'encoder_outputs': [(None
#                              , None, 512),
#                               (None, None, 512),
#                               (None, None, 512),
#                               (None, None, 512)],
#                               'default': (None, 512)}
#
#  tf.expand_dims (TFOpLambda  (None, 1, 512)               0         ['BERT_encoder[0][5]']
#  )
#
#  spatial_dropout1d (Spatial  (None, 1, 512)               0         ['tf.expand_dims[0][0]']
#  Dropout1D)
#
#  cu_dnnlstm (CuDNNLSTM)      (None, 1, 100)               245600    ['spatial_dropout1d[0][0]']
#
#  bidirectional (Bidirection  (None, 1, 256)               595712    ['cu_dnnlstm[0][0]']
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 1, 128)               254848    ['bidirectional[0][0]']
#  onal)
#
#  cust_attention (CustAttent  (None, 1, 128)               129       ['bidirectional_1[0][0]']
#  ion)
#
#  global_average_pooling1d (  (None, 128)                  0         ['cust_attention[0][0]']
#  GlobalAveragePooling1D)
#
#  global_max_pooling1d (Glob  (None, 128)                  0         ['cust_attention[0][0]']
#  alMaxPooling1D)
#
#  concatenate (Concatenate)   (None, 256)                  0         ['global_average_pooling1d[0][
#                                                                     0]',
#                                                                      'global_max_pooling1d[0][0]']
#
#  dense (Dense)               (None, 16)                   4112      ['concatenate[0][0]']
#
#  dropout (Dropout)           (None, 16)                   0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    17        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 29864067 (113.92 MB)
# Trainable params: 29864066 (113.92 MB)
# Non-trainable params: 1 (1.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 51s 274ms/step - loss: 0.5911 - accuracy: 0.8076 - val_loss: 0.4583 - val_accuracy: 0.8197
# Epoch 2/30
# 92/92 [==============================] - 19s 209ms/step - loss: 0.3688 - accuracy: 0.8634 - val_loss: 0.3077 - val_accuracy: 0.8677
# Epoch 3/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.3069 - accuracy: 0.8802 - val_loss: 0.2571 - val_accuracy: 0.8855
# Epoch 4/30
# 92/92 [==============================] - 19s 209ms/step - loss: 0.2680 - accuracy: 0.8917 - val_loss: 0.2470 - val_accuracy: 0.8944
# Epoch 5/30
# 92/92 [==============================] - 19s 210ms/step - loss: 0.2319 - accuracy: 0.9076 - val_loss: 0.2183 - val_accuracy: 0.9184
# Epoch 6/30
# 92/92 [==============================] - 20s 212ms/step - loss: 0.1970 - accuracy: 0.9251 - val_loss: 0.2062 - val_accuracy: 0.9225
# Epoch 7/30
# 92/92 [==============================] - 20s 214ms/step - loss: 0.2009 - accuracy: 0.9258 - val_loss: 0.2083 - val_accuracy: 0.9212
# Epoch 8/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.1578 - accuracy: 0.9423 - val_loss: 0.2005 - val_accuracy: 0.9280
# Epoch 9/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.1399 - accuracy: 0.9486 - val_loss: 0.1928 - val_accuracy: 0.9308
# Epoch 10/30
# 92/92 [==============================] - 19s 210ms/step - loss: 0.1156 - accuracy: 0.9566 - val_loss: 0.2028 - val_accuracy: 0.9294
# Epoch 11/30
# 92/92 [==============================] - 19s 210ms/step - loss: 0.1243 - accuracy: 0.9558 - val_loss: 0.1996 - val_accuracy: 0.9342
# Epoch 12/30
# 92/92 [==============================] - 19s 210ms/step - loss: 0.0944 - accuracy: 0.9671 - val_loss: 0.2795 - val_accuracy: 0.9219
# Epoch 13/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0995 - accuracy: 0.9649 - val_loss: 0.2204 - val_accuracy: 0.9260
# Epoch 14/30
# 92/92 [==============================] - 19s 210ms/step - loss: 0.0837 - accuracy: 0.9716 - val_loss: 0.2307 - val_accuracy: 0.9349
# Epoch 15/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0740 - accuracy: 0.9750 - val_loss: 0.2772 - val_accuracy: 0.9315
# Epoch 16/30
# 92/92 [==============================] - 19s 210ms/step - loss: 0.0709 - accuracy: 0.9764 - val_loss: 0.2096 - val_accuracy: 0.9363
# Epoch 17/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0521 - accuracy: 0.9830 - val_loss: 0.2336 - val_accuracy: 0.9411
# Epoch 18/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0448 - accuracy: 0.9853 - val_loss: 0.2643 - val_accuracy: 0.9383
# Epoch 19/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0424 - accuracy: 0.9871 - val_loss: 0.2752 - val_accuracy: 0.9356
# Epoch 20/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0470 - accuracy: 0.9858 - val_loss: 0.2346 - val_accuracy: 0.9349
# Epoch 21/30
# 92/92 [==============================] - 19s 210ms/step - loss: 0.0510 - accuracy: 0.9846 - val_loss: 0.2403 - val_accuracy: 0.9369
# Epoch 22/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0287 - accuracy: 0.9918 - val_loss: 0.3227 - val_accuracy: 0.9239
# Epoch 23/30
# 92/92 [==============================] - 19s 210ms/step - loss: 0.0450 - accuracy: 0.9854 - val_loss: 0.2696 - val_accuracy: 0.9369
# Epoch 24/30
# 92/92 [==============================] - 19s 210ms/step - loss: 0.0293 - accuracy: 0.9902 - val_loss: 0.2877 - val_accuracy: 0.9308
# Epoch 25/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0221 - accuracy: 0.9930 - val_loss: 0.3166 - val_accuracy: 0.9315
# Epoch 26/30
# 92/92 [==============================] - 19s 210ms/step - loss: 0.0702 - accuracy: 0.9818 - val_loss: 0.2849 - val_accuracy: 0.9342
# Epoch 27/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0283 - accuracy: 0.9921 - val_loss: 0.2607 - val_accuracy: 0.9321
# Epoch 28/30
# 92/92 [==============================] - 19s 210ms/step - loss: 0.0239 - accuracy: 0.9923 - val_loss: 0.2965 - val_accuracy: 0.9383
# Epoch 29/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0198 - accuracy: 0.9949 - val_loss: 0.3177 - val_accuracy: 0.9321
# Epoch 30/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0149 - accuracy: 0.9955 - val_loss: 0.3664 - val_accuracy: 0.9390
# 29/29 [==============================] - 4s 84ms/step
# Fold 1 Results: Accuracy=0.9424, Precision=0.9590, Recall=0.9075, F1=0.9326, ROC-AUC==0.9829, Time=615.17s
# --- Starting Fold 2/5 ---
#
# Trainable params: 29,864,066
# Non-trainable params: 1
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  text (InputLayer)           [(None,)]                    0         []
#
#  preprocessing (KerasLayer)  {'input_type_ids': (None,    0         ['text[0][0]']
#                              128),
#                               'input_mask': (None, 128)
#                              , 'input_word_ids': (None,
#                               128)}
#
#  BERT_encoder (KerasLayer)   {'pooled_output': (None, 5   2876364   ['preprocessing[0][0]',
#                              12),                         9          'preprocessing[0][1]',
#                               'sequence_output': (None,              'preprocessing[0][2]']
#                               None, 512),
#                               'encoder_outputs': [(None
#                              , None, 512),
#                               (None, None, 512),
#                               (None, None, 512),
#                               (None, None, 512)],
#                               'default': (None, 512)}
#
#  tf.expand_dims_1 (TFOpLamb  (None, 1, 512)               0         ['BERT_encoder[0][5]']
#  da)
#
#  spatial_dropout1d_1 (Spati  (None, 1, 512)               0         ['tf.expand_dims_1[0][0]']
#  alDropout1D)
#
#  cu_dnnlstm_1 (CuDNNLSTM)    (None, 1, 100)               245600    ['spatial_dropout1d_1[0][0]']
#
#  bidirectional_2 (Bidirecti  (None, 1, 256)               595712    ['cu_dnnlstm_1[0][0]']
#  onal)
#
#  bidirectional_3 (Bidirecti  (None, 1, 128)               254848    ['bidirectional_2[0][0]']
#  onal)
#
#  cust_attention_1 (CustAtte  (None, 1, 128)               129       ['bidirectional_3[0][0]']
#  ntion)
#
#  global_average_pooling1d_1  (None, 128)                  0         ['cust_attention_1[0][0]']
#   (GlobalAveragePooling1D)
#
#  global_max_pooling1d_1 (Gl  (None, 128)                  0         ['cust_attention_1[0][0]']
#  obalMaxPooling1D)
#
#  concatenate_1 (Concatenate  (None, 256)                  0         ['global_average_pooling1d_1[0
#  )                                                                  ][0]',
#                                                                      'global_max_pooling1d_1[0][0]
#                                                                     ']
#
#  dense_2 (Dense)             (None, 16)                   4112      ['concatenate_1[0][0]']
#
#  dropout_1 (Dropout)         (None, 16)                   0         ['dense_2[0][0]']
#
#  dense_3 (Dense)             (None, 1)                    17        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 29864067 (113.92 MB)
# Trainable params: 29864066 (113.92 MB)
# Non-trainable params: 1 (1.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 46s 270ms/step - loss: 0.5673 - accuracy: 0.7300 - val_loss: 0.4073 - val_accuracy: 0.8554
# Epoch 2/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.3745 - accuracy: 0.8627 - val_loss: 0.2733 - val_accuracy: 0.8944
# Epoch 3/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.3072 - accuracy: 0.8790 - val_loss: 0.2176 - val_accuracy: 0.9054
# Epoch 4/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.2671 - accuracy: 0.8897 - val_loss: 0.1838 - val_accuracy: 0.9273
# Epoch 5/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.2179 - accuracy: 0.9130 - val_loss: 0.1827 - val_accuracy: 0.9232
# Epoch 6/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.1913 - accuracy: 0.9246 - val_loss: 0.1545 - val_accuracy: 0.9356
# Epoch 7/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.1828 - accuracy: 0.9340 - val_loss: 0.1553 - val_accuracy: 0.9342
# Epoch 8/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1503 - accuracy: 0.9431 - val_loss: 0.1457 - val_accuracy: 0.9438
# Epoch 9/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.1382 - accuracy: 0.9476 - val_loss: 0.1399 - val_accuracy: 0.9465
# Epoch 10/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1186 - accuracy: 0.9563 - val_loss: 0.1430 - val_accuracy: 0.9507
# Epoch 11/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1134 - accuracy: 0.9584 - val_loss: 0.1583 - val_accuracy: 0.9445
# Epoch 12/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0885 - accuracy: 0.9690 - val_loss: 0.1588 - val_accuracy: 0.9493
# Epoch 13/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.1014 - accuracy: 0.9647 - val_loss: 0.1695 - val_accuracy: 0.9417
# Epoch 14/30
# 92/92 [==============================] - 20s 212ms/step - loss: 0.0786 - accuracy: 0.9716 - val_loss: 0.1657 - val_accuracy: 0.9404
# Epoch 15/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0710 - accuracy: 0.9741 - val_loss: 0.1756 - val_accuracy: 0.9452
# Epoch 16/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0550 - accuracy: 0.9808 - val_loss: 0.1857 - val_accuracy: 0.9431
# Epoch 17/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0632 - accuracy: 0.9777 - val_loss: 0.2042 - val_accuracy: 0.9356
# Epoch 18/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0450 - accuracy: 0.9842 - val_loss: 0.2636 - val_accuracy: 0.9219
# Epoch 19/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0468 - accuracy: 0.9865 - val_loss: 0.2177 - val_accuracy: 0.9404
# Epoch 20/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0387 - accuracy: 0.9877 - val_loss: 0.2236 - val_accuracy: 0.9417
# Epoch 21/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0379 - accuracy: 0.9885 - val_loss: 0.2691 - val_accuracy: 0.9383
# Epoch 22/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0337 - accuracy: 0.9887 - val_loss: 0.2354 - val_accuracy: 0.9417
# Epoch 23/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0296 - accuracy: 0.9894 - val_loss: 0.2190 - val_accuracy: 0.9431
# Epoch 24/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0508 - accuracy: 0.9868 - val_loss: 0.1929 - val_accuracy: 0.9424
# Epoch 25/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0852 - accuracy: 0.9781 - val_loss: 0.1769 - val_accuracy: 0.9342
# Epoch 26/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0217 - accuracy: 0.9947 - val_loss: 0.2253 - val_accuracy: 0.9417
# Epoch 27/30
# 92/92 [==============================] - 20s 212ms/step - loss: 0.0179 - accuracy: 0.9954 - val_loss: 0.2601 - val_accuracy: 0.9459
# Epoch 28/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0212 - accuracy: 0.9931 - val_loss: 0.2765 - val_accuracy: 0.9363
# Epoch 29/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0257 - accuracy: 0.9935 - val_loss: 0.2357 - val_accuracy: 0.9445
# Epoch 30/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0107 - accuracy: 0.9974 - val_loss: 0.2651 - val_accuracy: 0.9417
# 29/29 [==============================] - 4s 85ms/step
# Fold 2 Results: Accuracy=0.9359, Precision=0.9328, Recall=0.9200, F1=0.9264, ROC-AUC==0.9780, Time=612.33s
# --- Starting Fold 3/5 ---
#
# Trainable params: 29,864,066
# Non-trainable params: 1
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  text (InputLayer)           [(None,)]                    0         []
#
#  preprocessing (KerasLayer)  {'input_type_ids': (None,    0         ['text[0][0]']
#                              128),
#                               'input_mask': (None, 128)
#                              , 'input_word_ids': (None,
#                               128)}
#
#  BERT_encoder (KerasLayer)   {'pooled_output': (None, 5   2876364   ['preprocessing[0][0]',
#                              12),                         9          'preprocessing[0][1]',
#                               'sequence_output': (None,              'preprocessing[0][2]']
#                               None, 512),
#                               'encoder_outputs': [(None
#                              , None, 512),
#                               (None, None, 512),
#                               (None, None, 512),
#                               (None, None, 512)],
#                               'default': (None, 512)}
#
#  tf.expand_dims_2 (TFOpLamb  (None, 1, 512)               0         ['BERT_encoder[0][5]']
#  da)
#
#  spatial_dropout1d_2 (Spati  (None, 1, 512)               0         ['tf.expand_dims_2[0][0]']
#  alDropout1D)
#
#  cu_dnnlstm_2 (CuDNNLSTM)    (None, 1, 100)               245600    ['spatial_dropout1d_2[0][0]']
#
#  bidirectional_4 (Bidirecti  (None, 1, 256)               595712    ['cu_dnnlstm_2[0][0]']
#  onal)
#
#  bidirectional_5 (Bidirecti  (None, 1, 128)               254848    ['bidirectional_4[0][0]']
#  onal)
#
#  cust_attention_2 (CustAtte  (None, 1, 128)               129       ['bidirectional_5[0][0]']
#  ntion)
#
#  global_average_pooling1d_2  (None, 128)                  0         ['cust_attention_2[0][0]']
#   (GlobalAveragePooling1D)
#
#  global_max_pooling1d_2 (Gl  (None, 128)                  0         ['cust_attention_2[0][0]']
#  obalMaxPooling1D)
#
#  concatenate_2 (Concatenate  (None, 256)                  0         ['global_average_pooling1d_2[0
#  )                                                                  ][0]',
#                                                                      'global_max_pooling1d_2[0][0]
#                                                                     ']
#
#  dense_4 (Dense)             (None, 16)                   4112      ['concatenate_2[0][0]']
#
#  dropout_2 (Dropout)         (None, 16)                   0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 1)                    17        ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 29864067 (113.92 MB)
# Trainable params: 29864066 (113.92 MB)
# Non-trainable params: 1 (1.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 46s 268ms/step - loss: 0.5061 - accuracy: 0.8237 - val_loss: 0.4489 - val_accuracy: 0.8033
# Epoch 2/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.3511 - accuracy: 0.8658 - val_loss: 0.4114 - val_accuracy: 0.8005
# Epoch 3/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.2881 - accuracy: 0.8869 - val_loss: 0.2253 - val_accuracy: 0.9143
# Epoch 4/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.2365 - accuracy: 0.9080 - val_loss: 0.1973 - val_accuracy: 0.9205
# Epoch 5/30
# 92/92 [==============================] - 19s 210ms/step - loss: 0.2130 - accuracy: 0.9195 - val_loss: 0.1928 - val_accuracy: 0.9273
# Epoch 6/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1835 - accuracy: 0.9301 - val_loss: 0.2114 - val_accuracy: 0.9315
# Epoch 7/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1660 - accuracy: 0.9359 - val_loss: 0.1776 - val_accuracy: 0.9301
# Epoch 8/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1585 - accuracy: 0.9381 - val_loss: 0.1817 - val_accuracy: 0.9294
# Epoch 9/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1345 - accuracy: 0.9501 - val_loss: 0.1830 - val_accuracy: 0.9287
# Epoch 10/30
# 92/92 [==============================] - 19s 210ms/step - loss: 0.1175 - accuracy: 0.9572 - val_loss: 0.1757 - val_accuracy: 0.9404
# Epoch 11/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1029 - accuracy: 0.9632 - val_loss: 0.2204 - val_accuracy: 0.9321
# Epoch 12/30
# 92/92 [==============================] - 19s 210ms/step - loss: 0.0955 - accuracy: 0.9669 - val_loss: 0.2042 - val_accuracy: 0.9369
# Epoch 13/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0892 - accuracy: 0.9722 - val_loss: 0.2102 - val_accuracy: 0.9404
# Epoch 14/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0801 - accuracy: 0.9729 - val_loss: 0.2040 - val_accuracy: 0.9342
# Epoch 15/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0717 - accuracy: 0.9767 - val_loss: 0.2196 - val_accuracy: 0.9383
# Epoch 16/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0591 - accuracy: 0.9796 - val_loss: 0.2382 - val_accuracy: 0.9342
# Epoch 17/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0518 - accuracy: 0.9834 - val_loss: 0.2295 - val_accuracy: 0.9390
# Epoch 18/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0536 - accuracy: 0.9832 - val_loss: 0.2630 - val_accuracy: 0.9356
# Epoch 19/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0657 - accuracy: 0.9810 - val_loss: 0.2320 - val_accuracy: 0.9315
# Epoch 20/30
# 92/92 [==============================] - 19s 210ms/step - loss: 0.1011 - accuracy: 0.9746 - val_loss: 0.2128 - val_accuracy: 0.9301
# Epoch 21/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0406 - accuracy: 0.9873 - val_loss: 0.3343 - val_accuracy: 0.9321
# Epoch 22/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0418 - accuracy: 0.9875 - val_loss: 0.2593 - val_accuracy: 0.9349
# Epoch 23/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0337 - accuracy: 0.9911 - val_loss: 0.2622 - val_accuracy: 0.9219
# Epoch 24/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0499 - accuracy: 0.9842 - val_loss: 0.2596 - val_accuracy: 0.9321
# Epoch 25/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0397 - accuracy: 0.9865 - val_loss: 0.2505 - val_accuracy: 0.9404
# Epoch 26/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0301 - accuracy: 0.9928 - val_loss: 0.2540 - val_accuracy: 0.9397
# Epoch 27/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0259 - accuracy: 0.9931 - val_loss: 0.3073 - val_accuracy: 0.9356
# Epoch 28/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0269 - accuracy: 0.9933 - val_loss: 0.2727 - val_accuracy: 0.9328
# Epoch 29/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0273 - accuracy: 0.9911 - val_loss: 0.2854 - val_accuracy: 0.9376
# Epoch 30/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0194 - accuracy: 0.9949 - val_loss: 0.2967 - val_accuracy: 0.9342
# 29/29 [==============================] - 4s 82ms/step
# Fold 3 Results: Accuracy=0.9265, Precision=0.9269, Recall=0.9038, F1=0.9152, ROC-AUC==0.9711, Time=610.04s
# --- Starting Fold 4/5 ---
#
# Trainable params: 29,864,066
# Non-trainable params: 1
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  text (InputLayer)           [(None,)]                    0         []
#
#  preprocessing (KerasLayer)  {'input_type_ids': (None,    0         ['text[0][0]']
#                              128),
#                               'input_mask': (None, 128)
#                              , 'input_word_ids': (None,
#                               128)}
#
#  BERT_encoder (KerasLayer)   {'pooled_output': (None, 5   2876364   ['preprocessing[0][0]',
#                              12),                         9          'preprocessing[0][1]',
#                               'sequence_output': (None,              'preprocessing[0][2]']
#                               None, 512),
#                               'encoder_outputs': [(None
#                              , None, 512),
#                               (None, None, 512),
#                               (None, None, 512),
#                               (None, None, 512)],
#                               'default': (None, 512)}
#
#  tf.expand_dims_3 (TFOpLamb  (None, 1, 512)               0         ['BERT_encoder[0][5]']
#  da)
#
#  spatial_dropout1d_3 (Spati  (None, 1, 512)               0         ['tf.expand_dims_3[0][0]']
#  alDropout1D)
#
#  cu_dnnlstm_3 (CuDNNLSTM)    (None, 1, 100)               245600    ['spatial_dropout1d_3[0][0]']
#
#  bidirectional_6 (Bidirecti  (None, 1, 256)               595712    ['cu_dnnlstm_3[0][0]']
#  onal)
#
#  bidirectional_7 (Bidirecti  (None, 1, 128)               254848    ['bidirectional_6[0][0]']
#  onal)
#
#  cust_attention_3 (CustAtte  (None, 1, 128)               129       ['bidirectional_7[0][0]']
#  ntion)
#
#  global_average_pooling1d_3  (None, 128)                  0         ['cust_attention_3[0][0]']
#   (GlobalAveragePooling1D)
#
#  global_max_pooling1d_3 (Gl  (None, 128)                  0         ['cust_attention_3[0][0]']
#  obalMaxPooling1D)
#
#  concatenate_3 (Concatenate  (None, 256)                  0         ['global_average_pooling1d_3[0
#  )                                                                  ][0]',
#                                                                      'global_max_pooling1d_3[0][0]
#                                                                     ']
#
#  dense_6 (Dense)             (None, 16)                   4112      ['concatenate_3[0][0]']
#
#  dropout_3 (Dropout)         (None, 16)                   0         ['dense_6[0][0]']
#
#  dense_7 (Dense)             (None, 1)                    17        ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 29864067 (113.92 MB)
# Trainable params: 29864066 (113.92 MB)
# Non-trainable params: 1 (1.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 46s 269ms/step - loss: 0.5933 - accuracy: 0.7257 - val_loss: 0.5297 - val_accuracy: 0.7738
# Epoch 2/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.4053 - accuracy: 0.8490 - val_loss: 0.5219 - val_accuracy: 0.7423
# Epoch 3/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.3211 - accuracy: 0.8756 - val_loss: 0.4391 - val_accuracy: 0.8129
# Epoch 4/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.2647 - accuracy: 0.8975 - val_loss: 0.3452 - val_accuracy: 0.8424
# Epoch 5/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.2294 - accuracy: 0.9104 - val_loss: 0.5655 - val_accuracy: 0.7526
# Epoch 6/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.2039 - accuracy: 0.9249 - val_loss: 0.2530 - val_accuracy: 0.8958
# Epoch 7/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1734 - accuracy: 0.9351 - val_loss: 0.2530 - val_accuracy: 0.8931
# Epoch 8/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1678 - accuracy: 0.9397 - val_loss: 0.2025 - val_accuracy: 0.9198
# Epoch 9/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1487 - accuracy: 0.9464 - val_loss: 0.1948 - val_accuracy: 0.9315
# Epoch 10/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1325 - accuracy: 0.9549 - val_loss: 0.1915 - val_accuracy: 0.9253
# Epoch 11/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1199 - accuracy: 0.9596 - val_loss: 0.2905 - val_accuracy: 0.8965
# Epoch 12/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1085 - accuracy: 0.9621 - val_loss: 0.2078 - val_accuracy: 0.9273
# Epoch 13/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0940 - accuracy: 0.9688 - val_loss: 0.1988 - val_accuracy: 0.9308
# Epoch 14/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0971 - accuracy: 0.9676 - val_loss: 0.2071 - val_accuracy: 0.9280
# Epoch 15/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0790 - accuracy: 0.9721 - val_loss: 0.1939 - val_accuracy: 0.9328
# Epoch 16/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0704 - accuracy: 0.9789 - val_loss: 0.2096 - val_accuracy: 0.9342
# Epoch 17/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0515 - accuracy: 0.9837 - val_loss: 0.2373 - val_accuracy: 0.9294
# Epoch 18/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1144 - accuracy: 0.9650 - val_loss: 0.2190 - val_accuracy: 0.9308
# Epoch 19/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0488 - accuracy: 0.9858 - val_loss: 0.2357 - val_accuracy: 0.9335
# Epoch 20/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0481 - accuracy: 0.9839 - val_loss: 0.2343 - val_accuracy: 0.9369
# Epoch 21/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0394 - accuracy: 0.9878 - val_loss: 0.2685 - val_accuracy: 0.9342
# Epoch 22/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0434 - accuracy: 0.9849 - val_loss: 0.3032 - val_accuracy: 0.9260
# Epoch 23/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0382 - accuracy: 0.9885 - val_loss: 0.2727 - val_accuracy: 0.9321
# Epoch 24/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0430 - accuracy: 0.9870 - val_loss: 0.2809 - val_accuracy: 0.9308
# Epoch 25/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0340 - accuracy: 0.9899 - val_loss: 0.2594 - val_accuracy: 0.9267
# Epoch 26/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0259 - accuracy: 0.9923 - val_loss: 0.2911 - val_accuracy: 0.9301
# Epoch 27/30
# 92/92 [==============================] - 19s 210ms/step - loss: 0.0260 - accuracy: 0.9935 - val_loss: 0.2747 - val_accuracy: 0.9390
# Epoch 28/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0192 - accuracy: 0.9952 - val_loss: 0.3998 - val_accuracy: 0.9109
# Epoch 29/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0195 - accuracy: 0.9950 - val_loss: 0.3039 - val_accuracy: 0.9308
# Epoch 30/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0238 - accuracy: 0.9926 - val_loss: 0.3024 - val_accuracy: 0.9356
# 29/29 [==============================] - 4s 84ms/step
# Fold 4 Results: Accuracy=0.9496, Precision=0.9695, Recall=0.9136, F1=0.9407, ROC-AUC==0.9877, Time=610.24s
# --- Starting Fold 5/5 ---
#
# Trainable params: 29,864,066
# Non-trainable params: 1
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  text (InputLayer)           [(None,)]                    0         []
#
#  preprocessing (KerasLayer)  {'input_type_ids': (None,    0         ['text[0][0]']
#                              128),
#                               'input_mask': (None, 128)
#                              , 'input_word_ids': (None,
#                               128)}
#
#  BERT_encoder (KerasLayer)   {'pooled_output': (None, 5   2876364   ['preprocessing[0][0]',
#                              12),                         9          'preprocessing[0][1]',
#                               'sequence_output': (None,              'preprocessing[0][2]']
#                               None, 512),
#                               'encoder_outputs': [(None
#                              , None, 512),
#                               (None, None, 512),
#                               (None, None, 512),
#                               (None, None, 512)],
#                               'default': (None, 512)}
#
#  tf.expand_dims_4 (TFOpLamb  (None, 1, 512)               0         ['BERT_encoder[0][5]']
#  da)
#
#  spatial_dropout1d_4 (Spati  (None, 1, 512)               0         ['tf.expand_dims_4[0][0]']
#  alDropout1D)
#
#  cu_dnnlstm_4 (CuDNNLSTM)    (None, 1, 100)               245600    ['spatial_dropout1d_4[0][0]']
#
#  bidirectional_8 (Bidirecti  (None, 1, 256)               595712    ['cu_dnnlstm_4[0][0]']
#  onal)
#
#  bidirectional_9 (Bidirecti  (None, 1, 128)               254848    ['bidirectional_8[0][0]']
#  onal)
#
#  cust_attention_4 (CustAtte  (None, 1, 128)               129       ['bidirectional_9[0][0]']
#  ntion)
#
#  global_average_pooling1d_4  (None, 128)                  0         ['cust_attention_4[0][0]']
#   (GlobalAveragePooling1D)
#
#  global_max_pooling1d_4 (Gl  (None, 128)                  0         ['cust_attention_4[0][0]']
#  obalMaxPooling1D)
#
#  concatenate_4 (Concatenate  (None, 256)                  0         ['global_average_pooling1d_4[0
#  )                                                                  ][0]',
#                                                                      'global_max_pooling1d_4[0][0]
#                                                                     ']
#
#  dense_8 (Dense)             (None, 16)                   4112      ['concatenate_4[0][0]']
#
#  dropout_4 (Dropout)         (None, 16)                   0         ['dense_8[0][0]']
#
#  dense_9 (Dense)             (None, 1)                    17        ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 29864067 (113.92 MB)
# Trainable params: 29864066 (113.92 MB)
# Non-trainable params: 1 (1.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 47s 271ms/step - loss: 0.6068 - accuracy: 0.7082 - val_loss: 0.5192 - val_accuracy: 0.8000
# Epoch 2/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.4310 - accuracy: 0.8514 - val_loss: 0.6814 - val_accuracy: 0.6671
# Epoch 3/30
# 92/92 [==============================] - 20s 214ms/step - loss: 0.3432 - accuracy: 0.8756 - val_loss: 0.2533 - val_accuracy: 0.9041
# Epoch 4/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.2730 - accuracy: 0.8967 - val_loss: 0.2970 - val_accuracy: 0.8781
# Epoch 5/30
# 92/92 [==============================] - 20s 212ms/step - loss: 0.2413 - accuracy: 0.9090 - val_loss: 0.1933 - val_accuracy: 0.9212
# Epoch 6/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.2037 - accuracy: 0.9243 - val_loss: 0.1758 - val_accuracy: 0.9295
# Epoch 7/30
# 92/92 [==============================] - 20s 212ms/step - loss: 0.1841 - accuracy: 0.9321 - val_loss: 0.1686 - val_accuracy: 0.9377
# Epoch 8/30
# 92/92 [==============================] - 20s 212ms/step - loss: 0.1669 - accuracy: 0.9354 - val_loss: 0.1778 - val_accuracy: 0.9404
# Epoch 9/30
# 92/92 [==============================] - 20s 212ms/step - loss: 0.1413 - accuracy: 0.9519 - val_loss: 0.1790 - val_accuracy: 0.9322
# Epoch 10/30
# 92/92 [==============================] - 20s 212ms/step - loss: 0.1275 - accuracy: 0.9549 - val_loss: 0.1734 - val_accuracy: 0.9384
# Epoch 11/30
# 92/92 [==============================] - 20s 212ms/step - loss: 0.1124 - accuracy: 0.9587 - val_loss: 0.2037 - val_accuracy: 0.9342
# Epoch 12/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.1153 - accuracy: 0.9602 - val_loss: 0.2098 - val_accuracy: 0.9370
# Epoch 13/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.0973 - accuracy: 0.9638 - val_loss: 0.2118 - val_accuracy: 0.9274
# Epoch 14/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.0984 - accuracy: 0.9654 - val_loss: 0.1975 - val_accuracy: 0.9315
# Epoch 15/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0759 - accuracy: 0.9734 - val_loss: 0.2029 - val_accuracy: 0.9377
# Epoch 16/30
# 92/92 [==============================] - 20s 212ms/step - loss: 0.0610 - accuracy: 0.9781 - val_loss: 0.2444 - val_accuracy: 0.9342
# Epoch 17/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0670 - accuracy: 0.9765 - val_loss: 0.2238 - val_accuracy: 0.9336
# Epoch 18/30
# 92/92 [==============================] - 20s 212ms/step - loss: 0.0521 - accuracy: 0.9844 - val_loss: 0.2442 - val_accuracy: 0.9301
# Epoch 19/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.0512 - accuracy: 0.9834 - val_loss: 0.3293 - val_accuracy: 0.9110
# Epoch 20/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0454 - accuracy: 0.9861 - val_loss: 0.2763 - val_accuracy: 0.9253
# Epoch 21/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0485 - accuracy: 0.9866 - val_loss: 0.2344 - val_accuracy: 0.9322
# Epoch 22/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0377 - accuracy: 0.9889 - val_loss: 0.2645 - val_accuracy: 0.9363
# Epoch 23/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0505 - accuracy: 0.9854 - val_loss: 0.2353 - val_accuracy: 0.9404
# Epoch 24/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.0360 - accuracy: 0.9907 - val_loss: 0.2641 - val_accuracy: 0.9404
# Epoch 25/30
# 92/92 [==============================] - 20s 212ms/step - loss: 0.0256 - accuracy: 0.9913 - val_loss: 0.2786 - val_accuracy: 0.9322
# Epoch 26/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.0504 - accuracy: 0.9851 - val_loss: 0.3018 - val_accuracy: 0.9274
# Epoch 27/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.1010 - accuracy: 0.9736 - val_loss: 0.2279 - val_accuracy: 0.9336
# Epoch 28/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.0264 - accuracy: 0.9911 - val_loss: 0.2588 - val_accuracy: 0.9411
# Epoch 29/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.0203 - accuracy: 0.9940 - val_loss: 0.2772 - val_accuracy: 0.9418
# Epoch 30/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0280 - accuracy: 0.9906 - val_loss: 0.3034 - val_accuracy: 0.9322
# 29/29 [==============================] - 4s 84ms/step
# Fold 5 Results: Accuracy=0.9281, Precision=0.9053, Recall=0.9337, F1=0.9193, ROC-AUC==0.9826, Time=614.55s
# --- Analysis for: baseline_tcn_model_fine_tune_sb_pool_no_early_stop - Twitter ---
# --------------------------------------------------
#
# [Raw Results per Fold]
#    Fold  Accuracy  Precision    Recall  F1-Score   ROC-AUC  Training Time (s)  Dataset
# 0     1  0.942434   0.959049  0.907500  0.932563  0.982930         615.173294  Twitter
# 1     2  0.935855   0.932826  0.920000  0.926369  0.978029         612.334074  Twitter
# 2     3  0.926535   0.926923  0.903750  0.915190  0.971073         610.044009  Twitter
# 3     4  0.949561   0.969456  0.913642  0.940722  0.987701         610.243202  Twitter
# 4     5  0.928140   0.905340  0.933667  0.919285  0.982559         614.550603  Twitter
#
# [Summary Statistics]
#                          mean       std
# Accuracy             0.936505  0.009688
# Precision            0.938719  0.025720
# Recall               0.915712  0.011785
# F1-Score             0.926826  0.010228
# ROC-AUC              0.980458  0.006264
# Training Time (s)  612.469036  2.371668
# --------------------------------------------------
#
# [Total Training Time]: 3062.345181941986 seconds
# 8227

# %%
#tcn_model_fine_tune_sb_pool
result, history_list = run_cross_validation(FOLDS, X, y, tcn_model_fine_tune_sb_pool,False)
variant_name = "tcn_model_fine_tune_sb_pool"
result['Variant'] = variant_name
result['Dataset'] = 'Twitter'
all_results.append(result)
analyze_cv_results(result)

for hist in history_list:
    hist['Variant'] = variant_name
    all_histories.extend(history_list)

output_filename = f'/content/drive/MyDrive/final_FYP_results/{folder_name}/{variant_name}_twitter_result.csv'
result.to_csv(output_filename, index=False)
del output_filename
del history_list
del result
gc.collect()
# Out:
# --- Starting Fold 1/5 ---
#
# Trainable params: 29,864,066
# Non-trainable params: 1
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  text (InputLayer)           [(None,)]                    0         []
#
#  preprocessing (KerasLayer)  {'input_type_ids': (None,    0         ['text[0][0]']
#                              128),
#                               'input_mask': (None, 128)
#                              , 'input_word_ids': (None,
#                               128)}
#
#  BERT_encoder (KerasLayer)   {'pooled_output': (None, 5   2876364   ['preprocessing[0][0]',
#                              12),                         9          'preprocessing[0][1]',
#                               'sequence_output': (None,              'preprocessing[0][2]']
#                               None, 512),
#                               'encoder_outputs': [(None
#                              , None, 512),
#                               (None, None, 512),
#                               (None, None, 512),
#                               (None, None, 512)],
#                               'default': (None, 512)}
#
#  tf.expand_dims_5 (TFOpLamb  (None, 1, 512)               0         ['BERT_encoder[0][5]']
#  da)
#
#  spatial_dropout1d_5 (Spati  (None, 1, 512)               0         ['tf.expand_dims_5[0][0]']
#  alDropout1D)
#
#  cu_dnnlstm_5 (CuDNNLSTM)    (None, 1, 100)               245600    ['spatial_dropout1d_5[0][0]']
#
#  bidirectional_10 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_5[0][0]']
#  ional)
#
#  bidirectional_11 (Bidirect  (None, 1, 128)               254848    ['bidirectional_10[0][0]']
#  ional)
#
#  cust_attention_5 (CustAtte  (None, 1, 128)               129       ['bidirectional_11[0][0]']
#  ntion)
#
#  global_average_pooling1d_5  (None, 128)                  0         ['cust_attention_5[0][0]']
#   (GlobalAveragePooling1D)
#
#  global_max_pooling1d_5 (Gl  (None, 128)                  0         ['cust_attention_5[0][0]']
#  obalMaxPooling1D)
#
#  concatenate_5 (Concatenate  (None, 256)                  0         ['global_average_pooling1d_5[0
#  )                                                                  ][0]',
#                                                                      'global_max_pooling1d_5[0][0]
#                                                                     ']
#
#  dense_10 (Dense)            (None, 16)                   4112      ['concatenate_5[0][0]']
#
#  dropout_5 (Dropout)         (None, 16)                   0         ['dense_10[0][0]']
#
#  dense_11 (Dense)            (None, 1)                    17        ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 29864067 (113.92 MB)
# Trainable params: 29864066 (113.92 MB)
# Non-trainable params: 1 (1.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 47s 276ms/step - loss: 0.5838 - accuracy: 0.7031 - val_loss: 0.4809 - val_accuracy: 0.8211
# Epoch 2/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.4121 - accuracy: 0.8580 - val_loss: 0.3740 - val_accuracy: 0.8410
# Epoch 3/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.3270 - accuracy: 0.8717 - val_loss: 0.2833 - val_accuracy: 0.8821
# Epoch 4/30
# 92/92 [==============================] - 20s 215ms/step - loss: 0.2708 - accuracy: 0.8950 - val_loss: 0.2505 - val_accuracy: 0.8992
# Epoch 5/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.2318 - accuracy: 0.9106 - val_loss: 0.2851 - val_accuracy: 0.8979
# Epoch 6/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.2054 - accuracy: 0.9174 - val_loss: 0.2466 - val_accuracy: 0.9157
# Epoch 7/30
# 92/92 [==============================] - 20s 212ms/step - loss: 0.1669 - accuracy: 0.9345 - val_loss: 0.2388 - val_accuracy: 0.9260
# Epoch 8/30
# 92/92 [==============================] - 20s 212ms/step - loss: 0.1446 - accuracy: 0.9464 - val_loss: 0.2164 - val_accuracy: 0.9342
# Epoch 9/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.1314 - accuracy: 0.9476 - val_loss: 0.1858 - val_accuracy: 0.9363
# Epoch 10/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1094 - accuracy: 0.9578 - val_loss: 0.3061 - val_accuracy: 0.9191
# Epoch 11/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1310 - accuracy: 0.9524 - val_loss: 0.2284 - val_accuracy: 0.9342
# Epoch 12/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0966 - accuracy: 0.9690 - val_loss: 0.2329 - val_accuracy: 0.9349
# Epoch 13/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0783 - accuracy: 0.9714 - val_loss: 0.2191 - val_accuracy: 0.9369
# Epoch 14/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0662 - accuracy: 0.9757 - val_loss: 0.2752 - val_accuracy: 0.9301
# Epoch 15/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0881 - accuracy: 0.9714 - val_loss: 0.2070 - val_accuracy: 0.9335
# Epoch 16/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0664 - accuracy: 0.9758 - val_loss: 0.2312 - val_accuracy: 0.9356
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 29/29 [==============================] - 4s 84ms/step
# Fold 1 Results: Accuracy=0.9446, Precision=0.9629, Recall=0.9087, F1=0.9350, ROC-AUC==0.9842, Time=340.94s
# --- Starting Fold 2/5 ---
#
# Trainable params: 29,864,066
# Non-trainable params: 1
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  text (InputLayer)           [(None,)]                    0         []
#
#  preprocessing (KerasLayer)  {'input_type_ids': (None,    0         ['text[0][0]']
#                              128),
#                               'input_mask': (None, 128)
#                              , 'input_word_ids': (None,
#                               128)}
#
#  BERT_encoder (KerasLayer)   {'pooled_output': (None, 5   2876364   ['preprocessing[0][0]',
#                              12),                         9          'preprocessing[0][1]',
#                               'sequence_output': (None,              'preprocessing[0][2]']
#                               None, 512),
#                               'encoder_outputs': [(None
#                              , None, 512),
#                               (None, None, 512),
#                               (None, None, 512),
#                               (None, None, 512)],
#                               'default': (None, 512)}
#
#  tf.expand_dims_6 (TFOpLamb  (None, 1, 512)               0         ['BERT_encoder[0][5]']
#  da)
#
#  spatial_dropout1d_6 (Spati  (None, 1, 512)               0         ['tf.expand_dims_6[0][0]']
#  alDropout1D)
#
#  cu_dnnlstm_6 (CuDNNLSTM)    (None, 1, 100)               245600    ['spatial_dropout1d_6[0][0]']
#
#  bidirectional_12 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_6[0][0]']
#  ional)
#
#  bidirectional_13 (Bidirect  (None, 1, 128)               254848    ['bidirectional_12[0][0]']
#  ional)
#
#  cust_attention_6 (CustAtte  (None, 1, 128)               129       ['bidirectional_13[0][0]']
#  ntion)
#
#  global_average_pooling1d_6  (None, 128)                  0         ['cust_attention_6[0][0]']
#   (GlobalAveragePooling1D)
#
#  global_max_pooling1d_6 (Gl  (None, 128)                  0         ['cust_attention_6[0][0]']
#  obalMaxPooling1D)
#
#  concatenate_6 (Concatenate  (None, 256)                  0         ['global_average_pooling1d_6[0
#  )                                                                  ][0]',
#                                                                      'global_max_pooling1d_6[0][0]
#                                                                     ']
#
#  dense_12 (Dense)            (None, 16)                   4112      ['concatenate_6[0][0]']
#
#  dropout_6 (Dropout)         (None, 16)                   0         ['dense_12[0][0]']
#
#  dense_13 (Dense)            (None, 1)                    17        ['dropout_6[0][0]']
#
# ==================================================================================================
# Total params: 29864067 (113.92 MB)
# Trainable params: 29864066 (113.92 MB)
# Non-trainable params: 1 (1.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 48s 273ms/step - loss: 0.6465 - accuracy: 0.7443 - val_loss: 0.5223 - val_accuracy: 0.8472
# Epoch 2/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.4303 - accuracy: 0.8554 - val_loss: 0.3200 - val_accuracy: 0.8849
# Epoch 3/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.3303 - accuracy: 0.8753 - val_loss: 0.2715 - val_accuracy: 0.8986
# Epoch 4/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.2814 - accuracy: 0.8924 - val_loss: 0.2225 - val_accuracy: 0.9143
# Epoch 5/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.2423 - accuracy: 0.9095 - val_loss: 0.1847 - val_accuracy: 0.9219
# Epoch 6/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.2111 - accuracy: 0.9196 - val_loss: 0.1706 - val_accuracy: 0.9383
# Epoch 7/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.2119 - accuracy: 0.9219 - val_loss: 0.1950 - val_accuracy: 0.9136
# Epoch 8/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.1593 - accuracy: 0.9414 - val_loss: 0.1653 - val_accuracy: 0.9239
# Epoch 9/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.1486 - accuracy: 0.9453 - val_loss: 0.1680 - val_accuracy: 0.9246
# Epoch 10/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1313 - accuracy: 0.9529 - val_loss: 0.1751 - val_accuracy: 0.9363
# Epoch 11/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1156 - accuracy: 0.9565 - val_loss: 0.1881 - val_accuracy: 0.9260
# Epoch 12/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.1138 - accuracy: 0.9609 - val_loss: 0.1752 - val_accuracy: 0.9328
# Epoch 13/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0902 - accuracy: 0.9697 - val_loss: 0.1953 - val_accuracy: 0.9273
# Epoch 14/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0929 - accuracy: 0.9661 - val_loss: 0.1949 - val_accuracy: 0.9184
# Epoch 15/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0734 - accuracy: 0.9741 - val_loss: 0.2042 - val_accuracy: 0.9205
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 29/29 [==============================] - 4s 85ms/step
# Fold 2 Results: Accuracy=0.9200, Precision=0.9007, Recall=0.9187, F1=0.9097, ROC-AUC==0.9754, Time=321.78s
# --- Starting Fold 3/5 ---
#
# Trainable params: 29,864,066
# Non-trainable params: 1
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  text (InputLayer)           [(None,)]                    0         []
#
#  preprocessing (KerasLayer)  {'input_type_ids': (None,    0         ['text[0][0]']
#                              128),
#                               'input_mask': (None, 128)
#                              , 'input_word_ids': (None,
#                               128)}
#
#  BERT_encoder (KerasLayer)   {'pooled_output': (None, 5   2876364   ['preprocessing[0][0]',
#                              12),                         9          'preprocessing[0][1]',
#                               'sequence_output': (None,              'preprocessing[0][2]']
#                               None, 512),
#                               'encoder_outputs': [(None
#                              , None, 512),
#                               (None, None, 512),
#                               (None, None, 512),
#                               (None, None, 512)],
#                               'default': (None, 512)}
#
#  tf.expand_dims_7 (TFOpLamb  (None, 1, 512)               0         ['BERT_encoder[0][5]']
#  da)
#
#  spatial_dropout1d_7 (Spati  (None, 1, 512)               0         ['tf.expand_dims_7[0][0]']
#  alDropout1D)
#
#  cu_dnnlstm_7 (CuDNNLSTM)    (None, 1, 100)               245600    ['spatial_dropout1d_7[0][0]']
#
#  bidirectional_14 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_7[0][0]']
#  ional)
#
#  bidirectional_15 (Bidirect  (None, 1, 128)               254848    ['bidirectional_14[0][0]']
#  ional)
#
#  cust_attention_7 (CustAtte  (None, 1, 128)               129       ['bidirectional_15[0][0]']
#  ntion)
#
#  global_average_pooling1d_7  (None, 128)                  0         ['cust_attention_7[0][0]']
#   (GlobalAveragePooling1D)
#
#  global_max_pooling1d_7 (Gl  (None, 128)                  0         ['cust_attention_7[0][0]']
#  obalMaxPooling1D)
#
#  concatenate_7 (Concatenate  (None, 256)                  0         ['global_average_pooling1d_7[0
#  )                                                                  ][0]',
#                                                                      'global_max_pooling1d_7[0][0]
#                                                                     ']
#
#  dense_14 (Dense)            (None, 16)                   4112      ['concatenate_7[0][0]']
#
#  dropout_7 (Dropout)         (None, 16)                   0         ['dense_14[0][0]']
#
#  dense_15 (Dense)            (None, 1)                    17        ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 29864067 (113.92 MB)
# Trainable params: 29864066 (113.92 MB)
# Non-trainable params: 1 (1.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 48s 279ms/step - loss: 0.6107 - accuracy: 0.7676 - val_loss: 0.4451 - val_accuracy: 0.8430
# Epoch 2/30
# 92/92 [==============================] - 20s 216ms/step - loss: 0.3871 - accuracy: 0.8595 - val_loss: 0.2974 - val_accuracy: 0.8855
# Epoch 3/30
# 92/92 [==============================] - 20s 214ms/step - loss: 0.3143 - accuracy: 0.8790 - val_loss: 0.3396 - val_accuracy: 0.8520
# Epoch 4/30
# 92/92 [==============================] - 20s 215ms/step - loss: 0.2794 - accuracy: 0.8924 - val_loss: 0.2042 - val_accuracy: 0.9246
# Epoch 5/30
# 92/92 [==============================] - 20s 214ms/step - loss: 0.2375 - accuracy: 0.9112 - val_loss: 0.2529 - val_accuracy: 0.8992
# Epoch 6/30
# 92/92 [==============================] - 20s 214ms/step - loss: 0.2138 - accuracy: 0.9178 - val_loss: 0.1821 - val_accuracy: 0.9342
# Epoch 7/30
# 92/92 [==============================] - 20s 215ms/step - loss: 0.1901 - accuracy: 0.9260 - val_loss: 0.1711 - val_accuracy: 0.9383
# Epoch 8/30
# 92/92 [==============================] - 20s 214ms/step - loss: 0.1736 - accuracy: 0.9375 - val_loss: 0.1630 - val_accuracy: 0.9390
# Epoch 9/30
# 92/92 [==============================] - 20s 214ms/step - loss: 0.1512 - accuracy: 0.9467 - val_loss: 0.1818 - val_accuracy: 0.9390
# Epoch 10/30
# 92/92 [==============================] - 20s 214ms/step - loss: 0.1360 - accuracy: 0.9537 - val_loss: 0.1790 - val_accuracy: 0.9328
# Epoch 11/30
# 92/92 [==============================] - 20s 214ms/step - loss: 0.1276 - accuracy: 0.9554 - val_loss: 0.1640 - val_accuracy: 0.9404
# Epoch 12/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.1107 - accuracy: 0.9635 - val_loss: 0.1735 - val_accuracy: 0.9356
# Epoch 13/30
# 92/92 [==============================] - 20s 214ms/step - loss: 0.1002 - accuracy: 0.9664 - val_loss: 0.2030 - val_accuracy: 0.9280
# Epoch 14/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.0959 - accuracy: 0.9676 - val_loss: 0.1905 - val_accuracy: 0.9349
# Epoch 15/30
# 92/92 [==============================] - 20s 214ms/step - loss: 0.0839 - accuracy: 0.9746 - val_loss: 0.1980 - val_accuracy: 0.9301
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 29/29 [==============================] - 4s 84ms/step
# Fold 3 Results: Accuracy=0.9249, Precision=0.9333, Recall=0.8925, F1=0.9125, ROC-AUC==0.9757, Time=325.25s
# --- Starting Fold 4/5 ---
#
# Trainable params: 29,864,066
# Non-trainable params: 1
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  text (InputLayer)           [(None,)]                    0         []
#
#  preprocessing (KerasLayer)  {'input_type_ids': (None,    0         ['text[0][0]']
#                              128),
#                               'input_mask': (None, 128)
#                              , 'input_word_ids': (None,
#                               128)}
#
#  BERT_encoder (KerasLayer)   {'pooled_output': (None, 5   2876364   ['preprocessing[0][0]',
#                              12),                         9          'preprocessing[0][1]',
#                               'sequence_output': (None,              'preprocessing[0][2]']
#                               None, 512),
#                               'encoder_outputs': [(None
#                              , None, 512),
#                               (None, None, 512),
#                               (None, None, 512),
#                               (None, None, 512)],
#                               'default': (None, 512)}
#
#  tf.expand_dims_8 (TFOpLamb  (None, 1, 512)               0         ['BERT_encoder[0][5]']
#  da)
#
#  spatial_dropout1d_8 (Spati  (None, 1, 512)               0         ['tf.expand_dims_8[0][0]']
#  alDropout1D)
#
#  cu_dnnlstm_8 (CuDNNLSTM)    (None, 1, 100)               245600    ['spatial_dropout1d_8[0][0]']
#
#  bidirectional_16 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_8[0][0]']
#  ional)
#
#  bidirectional_17 (Bidirect  (None, 1, 128)               254848    ['bidirectional_16[0][0]']
#  ional)
#
#  cust_attention_8 (CustAtte  (None, 1, 128)               129       ['bidirectional_17[0][0]']
#  ntion)
#
#  global_average_pooling1d_8  (None, 128)                  0         ['cust_attention_8[0][0]']
#   (GlobalAveragePooling1D)
#
#  global_max_pooling1d_8 (Gl  (None, 128)                  0         ['cust_attention_8[0][0]']
#  obalMaxPooling1D)
#
#  concatenate_8 (Concatenate  (None, 256)                  0         ['global_average_pooling1d_8[0
#  )                                                                  ][0]',
#                                                                      'global_max_pooling1d_8[0][0]
#                                                                     ']
#
#  dense_16 (Dense)            (None, 16)                   4112      ['concatenate_8[0][0]']
#
#  dropout_8 (Dropout)         (None, 16)                   0         ['dense_16[0][0]']
#
#  dense_17 (Dense)            (None, 1)                    17        ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 29864067 (113.92 MB)
# Trainable params: 29864066 (113.92 MB)
# Non-trainable params: 1 (1.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 49s 280ms/step - loss: 0.6463 - accuracy: 0.7623 - val_loss: 0.5651 - val_accuracy: 0.8382
# Epoch 2/30
# 92/92 [==============================] - 20s 215ms/step - loss: 0.4629 - accuracy: 0.8496 - val_loss: 0.5511 - val_accuracy: 0.7354
# Epoch 3/30
# 92/92 [==============================] - 20s 215ms/step - loss: 0.3480 - accuracy: 0.8576 - val_loss: 0.4394 - val_accuracy: 0.7930
# Epoch 4/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.2913 - accuracy: 0.8804 - val_loss: 0.5414 - val_accuracy: 0.7814
# Epoch 5/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.2544 - accuracy: 0.9008 - val_loss: 0.6513 - val_accuracy: 0.6943
# Epoch 6/30
# 92/92 [==============================] - 20s 215ms/step - loss: 0.2267 - accuracy: 0.9160 - val_loss: 0.2190 - val_accuracy: 0.9130
# Epoch 7/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.2011 - accuracy: 0.9277 - val_loss: 0.2324 - val_accuracy: 0.9116
# Epoch 8/30
# 92/92 [==============================] - 20s 215ms/step - loss: 0.1700 - accuracy: 0.9385 - val_loss: 0.1933 - val_accuracy: 0.9253
# Epoch 9/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.1450 - accuracy: 0.9491 - val_loss: 0.3601 - val_accuracy: 0.8615
# Epoch 10/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.1412 - accuracy: 0.9488 - val_loss: 0.2037 - val_accuracy: 0.9212
# Epoch 11/30
# 92/92 [==============================] - 20s 214ms/step - loss: 0.1207 - accuracy: 0.9575 - val_loss: 0.1860 - val_accuracy: 0.9246
# Epoch 12/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.1077 - accuracy: 0.9652 - val_loss: 0.2008 - val_accuracy: 0.9273
# Epoch 13/30
# 92/92 [==============================] - 20s 212ms/step - loss: 0.1036 - accuracy: 0.9668 - val_loss: 0.1956 - val_accuracy: 0.9369
# Epoch 14/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.0931 - accuracy: 0.9693 - val_loss: 0.1981 - val_accuracy: 0.9369
# Epoch 15/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0737 - accuracy: 0.9764 - val_loss: 0.2023 - val_accuracy: 0.9321
# Epoch 16/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0735 - accuracy: 0.9755 - val_loss: 0.2181 - val_accuracy: 0.9301
# Epoch 17/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0698 - accuracy: 0.9796 - val_loss: 0.2065 - val_accuracy: 0.9397
# Epoch 18/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0547 - accuracy: 0.9830 - val_loss: 0.2434 - val_accuracy: 0.9253
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 11.
# 29/29 [==============================] - 4s 83ms/step
# Fold 4 Results: Accuracy=0.9391, Precision=0.9268, Recall=0.9349, F1=0.9308, ROC-AUC==0.9868, Time=382.97s
# --- Starting Fold 5/5 ---
#
# Trainable params: 29,864,066
# Non-trainable params: 1
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  text (InputLayer)           [(None,)]                    0         []
#
#  preprocessing (KerasLayer)  {'input_type_ids': (None,    0         ['text[0][0]']
#                              128),
#                               'input_mask': (None, 128)
#                              , 'input_word_ids': (None,
#                               128)}
#
#  BERT_encoder (KerasLayer)   {'pooled_output': (None, 5   2876364   ['preprocessing[0][0]',
#                              12),                         9          'preprocessing[0][1]',
#                               'sequence_output': (None,              'preprocessing[0][2]']
#                               None, 512),
#                               'encoder_outputs': [(None
#                              , None, 512),
#                               (None, None, 512),
#                               (None, None, 512),
#                               (None, None, 512)],
#                               'default': (None, 512)}
#
#  tf.expand_dims_9 (TFOpLamb  (None, 1, 512)               0         ['BERT_encoder[0][5]']
#  da)
#
#  spatial_dropout1d_9 (Spati  (None, 1, 512)               0         ['tf.expand_dims_9[0][0]']
#  alDropout1D)
#
#  cu_dnnlstm_9 (CuDNNLSTM)    (None, 1, 100)               245600    ['spatial_dropout1d_9[0][0]']
#
#  bidirectional_18 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_9[0][0]']
#  ional)
#
#  bidirectional_19 (Bidirect  (None, 1, 128)               254848    ['bidirectional_18[0][0]']
#  ional)
#
#  cust_attention_9 (CustAtte  (None, 1, 128)               129       ['bidirectional_19[0][0]']
#  ntion)
#
#  global_average_pooling1d_9  (None, 128)                  0         ['cust_attention_9[0][0]']
#   (GlobalAveragePooling1D)
#
#  global_max_pooling1d_9 (Gl  (None, 128)                  0         ['cust_attention_9[0][0]']
#  obalMaxPooling1D)
#
#  concatenate_9 (Concatenate  (None, 256)                  0         ['global_average_pooling1d_9[0
#  )                                                                  ][0]',
#                                                                      'global_max_pooling1d_9[0][0]
#                                                                     ']
#
#  dense_18 (Dense)            (None, 16)                   4112      ['concatenate_9[0][0]']
#
#  dropout_9 (Dropout)         (None, 16)                   0         ['dense_18[0][0]']
#
#  dense_19 (Dense)            (None, 1)                    17        ['dropout_9[0][0]']
#
# ==================================================================================================
# Total params: 29864067 (113.92 MB)
# Trainable params: 29864066 (113.92 MB)
# Non-trainable params: 1 (1.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 48s 275ms/step - loss: 0.6540 - accuracy: 0.6534 - val_loss: 0.5727 - val_accuracy: 0.8452
# Epoch 2/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.5259 - accuracy: 0.8441 - val_loss: 0.4577 - val_accuracy: 0.8795
# Epoch 3/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.4449 - accuracy: 0.8681 - val_loss: 0.4178 - val_accuracy: 0.8616
# Epoch 4/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.3850 - accuracy: 0.8756 - val_loss: 0.4940 - val_accuracy: 0.7781
# Epoch 5/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.3118 - accuracy: 0.8922 - val_loss: 0.2650 - val_accuracy: 0.9034
# Epoch 6/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.2769 - accuracy: 0.8960 - val_loss: 0.3203 - val_accuracy: 0.8733
# Epoch 7/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.2591 - accuracy: 0.9032 - val_loss: 0.1875 - val_accuracy: 0.9301
# Epoch 8/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.2176 - accuracy: 0.9205 - val_loss: 0.1747 - val_accuracy: 0.9404
# Epoch 9/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.2039 - accuracy: 0.9256 - val_loss: 0.1769 - val_accuracy: 0.9370
# Epoch 10/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.1835 - accuracy: 0.9363 - val_loss: 0.1784 - val_accuracy: 0.9336
# Epoch 11/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.1676 - accuracy: 0.9375 - val_loss: 0.1658 - val_accuracy: 0.9390
# Epoch 12/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.1444 - accuracy: 0.9498 - val_loss: 0.1784 - val_accuracy: 0.9390
# Epoch 13/30
# 92/92 [==============================] - 20s 212ms/step - loss: 0.1403 - accuracy: 0.9542 - val_loss: 0.1672 - val_accuracy: 0.9438
# Epoch 14/30
# 92/92 [==============================] - 20s 213ms/step - loss: 0.1215 - accuracy: 0.9602 - val_loss: 0.1662 - val_accuracy: 0.9384
# Epoch 15/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.1093 - accuracy: 0.9635 - val_loss: 0.1678 - val_accuracy: 0.9425
# Epoch 16/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.1030 - accuracy: 0.9671 - val_loss: 0.1740 - val_accuracy: 0.9466
# Epoch 17/30
# 92/92 [==============================] - 19s 211ms/step - loss: 0.0941 - accuracy: 0.9676 - val_loss: 0.1771 - val_accuracy: 0.9411
# Epoch 18/30
# 92/92 [==============================] - 19s 212ms/step - loss: 0.0775 - accuracy: 0.9757 - val_loss: 0.1939 - val_accuracy: 0.9363
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 11.
# 29/29 [==============================] - 4s 84ms/step
# Fold 5 Results: Accuracy=0.9309, Precision=0.9287, Recall=0.9124, F1=0.9205, ROC-AUC==0.9779, Time=381.03s
# --- Analysis for: tcn_model_fine_tune_sb_pool - Twitter ---
# --------------------------------------------------
#
# [Raw Results per Fold]
#    Fold  Accuracy  Precision    Recall  F1-Score   ROC-AUC  Training Time (s)  Dataset
# 0     1  0.944627   0.962914  0.908750  0.935048  0.984243         340.937136  Twitter
# 1     2  0.919956   0.900735  0.918750  0.909653  0.975398         321.783820  Twitter
# 2     3  0.924890   0.933333  0.892500  0.912460  0.975658         325.248180  Twitter
# 3     4  0.939145   0.926799  0.934919  0.930841  0.986774         382.972803  Twitter
# 4     5  0.930883   0.928662  0.912390  0.920455  0.977920         381.025045  Twitter
#
# [Summary Statistics]
#                          mean        std
# Accuracy             0.931900   0.010091
# Precision            0.930489   0.022146
# Recall               0.913462   0.015420
# F1-Score             0.921691   0.011111
# ROC-AUC              0.979999   0.005202
# Training Time (s)  350.393397  29.748640
# --------------------------------------------------
#
# [Total Training Time]: 1751.966984987259 seconds
# 73469

# %%
#tcn_model_fine_tune_sb_seqOut
result, history_list = run_cross_validation(FOLDS, X, y, tcn_model_fine_tune_sb_seqOut,False)
variant_name = "tcn_model_fine_tune_sb_seqOut"
result['Variant'] = variant_name
result['Dataset'] = 'Twitter'
all_results.append(result)
analyze_cv_results(result)

for hist in history_list:
    hist['Variant'] = variant_name
    all_histories.extend(history_list)

output_filename = f'/content/drive/MyDrive/final_FYP_results/{folder_name}/{variant_name}_twitter_result.csv'
result.to_csv(output_filename, index=False)
del output_filename
del history_list
del result
gc.collect()
# Out:
# --- Starting Fold 1/5 ---
#
# Trainable params: 29,864,193
# Non-trainable params: 1
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  text (InputLayer)           [(None,)]                    0         []
#
#  preprocessing (KerasLayer)  {'input_type_ids': (None,    0         ['text[0][0]']
#                              128),
#                               'input_mask': (None, 128)
#                              , 'input_word_ids': (None,
#                               128)}
#
#  BERT_encoder (KerasLayer)   {'pooled_output': (None, 5   2876364   ['preprocessing[0][0]',
#                              12),                         9          'preprocessing[0][1]',
#                               'sequence_output': (None,              'preprocessing[0][2]']
#                               None, 512),
#                               'encoder_outputs': [(None
#                              , None, 512),
#                               (None, None, 512),
#                               (None, None, 512),
#                               (None, None, 512)],
#                               'default': (None, 512)}
#
#  spatial_dropout1d_10 (Spat  (None, None, 512)            0         ['BERT_encoder[0][6]']
#  ialDropout1D)
#
#  cu_dnnlstm_10 (CuDNNLSTM)   (None, None, 100)            245600    ['spatial_dropout1d_10[0][0]']
#
#  bidirectional_20 (Bidirect  (None, None, 256)            595712    ['cu_dnnlstm_10[0][0]']
#  ional)
#
#  bidirectional_21 (Bidirect  (None, None, 128)            254848    ['bidirectional_20[0][0]']
#  ional)
#
#  attention_for_seq_out (Att  (None, 128, 128)             256       ['bidirectional_21[0][0]']
#  entionForSeqOut)
#
#  global_average_pooling1d_1  (None, 128)                  0         ['attention_for_seq_out[0][0]'
#  0 (GlobalAveragePooling1D)                                         ]
#
#  global_max_pooling1d_10 (G  (None, 128)                  0         ['attention_for_seq_out[0][0]'
#  lobalMaxPooling1D)                                                 ]
#
#  concatenate_10 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_10[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_10[0][0
#                                                                     ]']
#
#  dense_20 (Dense)            (None, 16)                   4112      ['concatenate_10[0][0]']
#
#  dropout_10 (Dropout)        (None, 16)                   0         ['dense_20[0][0]']
#
#  dense_21 (Dense)            (None, 1)                    17        ['dropout_10[0][0]']
#
# ==================================================================================================
# Total params: 29864194 (113.92 MB)
# Trainable params: 29864193 (113.92 MB)
# Non-trainable params: 1 (1.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 49s 290ms/step - loss: 0.5941 - accuracy: 0.6167 - val_loss: 0.5274 - val_accuracy: 0.8280
# Epoch 2/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.4754 - accuracy: 0.8496 - val_loss: 0.4588 - val_accuracy: 0.8348
# Epoch 3/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.4190 - accuracy: 0.8537 - val_loss: 0.4335 - val_accuracy: 0.8513
# Epoch 4/30
# 92/92 [==============================] - 20s 220ms/step - loss: 0.3689 - accuracy: 0.8619 - val_loss: 0.3178 - val_accuracy: 0.8746
# Epoch 5/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.2821 - accuracy: 0.8873 - val_loss: 0.2615 - val_accuracy: 0.9027
# Epoch 6/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.2408 - accuracy: 0.9010 - val_loss: 0.2477 - val_accuracy: 0.9088
# Epoch 7/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.2233 - accuracy: 0.9082 - val_loss: 0.2288 - val_accuracy: 0.9205
# Epoch 8/30
# 92/92 [==============================] - 20s 220ms/step - loss: 0.1743 - accuracy: 0.9340 - val_loss: 0.2325 - val_accuracy: 0.9212
# Epoch 9/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.1662 - accuracy: 0.9359 - val_loss: 0.1914 - val_accuracy: 0.9369
# Epoch 10/30
# 92/92 [==============================] - 20s 220ms/step - loss: 0.1464 - accuracy: 0.9423 - val_loss: 0.1945 - val_accuracy: 0.9349
# Epoch 11/30
# 92/92 [==============================] - 20s 220ms/step - loss: 0.1252 - accuracy: 0.9517 - val_loss: 0.1982 - val_accuracy: 0.9321
# Epoch 12/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.1201 - accuracy: 0.9536 - val_loss: 0.1819 - val_accuracy: 0.9301
# Epoch 13/30
# 92/92 [==============================] - 20s 220ms/step - loss: 0.0999 - accuracy: 0.9621 - val_loss: 0.2354 - val_accuracy: 0.9342
# Epoch 14/30
# 92/92 [==============================] - 20s 220ms/step - loss: 0.1172 - accuracy: 0.9556 - val_loss: 0.2071 - val_accuracy: 0.9349
# Epoch 15/30
# 92/92 [==============================] - 20s 220ms/step - loss: 0.0794 - accuracy: 0.9693 - val_loss: 0.2145 - val_accuracy: 0.9369
# Epoch 16/30
# 92/92 [==============================] - 20s 220ms/step - loss: 0.0705 - accuracy: 0.9738 - val_loss: 0.2216 - val_accuracy: 0.9342
# Epoch 17/30
# 92/92 [==============================] - 20s 219ms/step - loss: 0.0726 - accuracy: 0.9740 - val_loss: 0.2008 - val_accuracy: 0.9404
# Epoch 18/30
# 92/92 [==============================] - 20s 219ms/step - loss: 0.0487 - accuracy: 0.9822 - val_loss: 0.3115 - val_accuracy: 0.9253
# Epoch 19/30
# 92/92 [==============================] - 20s 219ms/step - loss: 0.0782 - accuracy: 0.9740 - val_loss: 0.1927 - val_accuracy: 0.9356
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 12.
# 29/29 [==============================] - 4s 90ms/step
# Fold 1 Results: Accuracy=0.9402, Precision=0.9528, Recall=0.9087, F1=0.9303, ROC-AUC==0.9852, Time=414.36s
# --- Starting Fold 2/5 ---
#
# Trainable params: 29,864,193
# Non-trainable params: 1
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  text (InputLayer)           [(None,)]                    0         []
#
#  preprocessing (KerasLayer)  {'input_type_ids': (None,    0         ['text[0][0]']
#                              128),
#                               'input_mask': (None, 128)
#                              , 'input_word_ids': (None,
#                               128)}
#
#  BERT_encoder (KerasLayer)   {'pooled_output': (None, 5   2876364   ['preprocessing[0][0]',
#                              12),                         9          'preprocessing[0][1]',
#                               'sequence_output': (None,              'preprocessing[0][2]']
#                               None, 512),
#                               'encoder_outputs': [(None
#                              , None, 512),
#                               (None, None, 512),
#                               (None, None, 512),
#                               (None, None, 512)],
#                               'default': (None, 512)}
#
#  spatial_dropout1d_11 (Spat  (None, None, 512)            0         ['BERT_encoder[0][6]']
#  ialDropout1D)
#
#  cu_dnnlstm_11 (CuDNNLSTM)   (None, None, 100)            245600    ['spatial_dropout1d_11[0][0]']
#
#  bidirectional_22 (Bidirect  (None, None, 256)            595712    ['cu_dnnlstm_11[0][0]']
#  ional)
#
#  bidirectional_23 (Bidirect  (None, None, 128)            254848    ['bidirectional_22[0][0]']
#  ional)
#
#  attention_for_seq_out_1 (A  (None, 128, 128)             256       ['bidirectional_23[0][0]']
#  ttentionForSeqOut)
#
#  global_average_pooling1d_1  (None, 128)                  0         ['attention_for_seq_out_1[0][0
#  1 (GlobalAveragePooling1D)                                         ]']
#
#  global_max_pooling1d_11 (G  (None, 128)                  0         ['attention_for_seq_out_1[0][0
#  lobalMaxPooling1D)                                                 ]']
#
#  concatenate_11 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_11[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_11[0][0
#                                                                     ]']
#
#  dense_22 (Dense)            (None, 16)                   4112      ['concatenate_11[0][0]']
#
#  dropout_11 (Dropout)        (None, 16)                   0         ['dense_22[0][0]']
#
#  dense_23 (Dense)            (None, 1)                    17        ['dropout_11[0][0]']
#
# ==================================================================================================
# Total params: 29864194 (113.92 MB)
# Trainable params: 29864193 (113.92 MB)
# Non-trainable params: 1 (1.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 49s 282ms/step - loss: 0.5962 - accuracy: 0.6163 - val_loss: 0.5006 - val_accuracy: 0.8520
# Epoch 2/30
# 92/92 [==============================] - 20s 223ms/step - loss: 0.4717 - accuracy: 0.8451 - val_loss: 0.4185 - val_accuracy: 0.8602
# Epoch 3/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.4108 - accuracy: 0.8729 - val_loss: 0.3551 - val_accuracy: 0.8869
# Epoch 4/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.3599 - accuracy: 0.8833 - val_loss: 0.2933 - val_accuracy: 0.9027
# Epoch 5/30
# 92/92 [==============================] - 20s 223ms/step - loss: 0.2983 - accuracy: 0.8926 - val_loss: 0.2384 - val_accuracy: 0.9116
# Epoch 6/30
# 92/92 [==============================] - 20s 223ms/step - loss: 0.2389 - accuracy: 0.9049 - val_loss: 0.2063 - val_accuracy: 0.9212
# Epoch 7/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.2048 - accuracy: 0.9214 - val_loss: 0.2269 - val_accuracy: 0.8999
# Epoch 8/30
# 92/92 [==============================] - 21s 223ms/step - loss: 0.1867 - accuracy: 0.9256 - val_loss: 0.1740 - val_accuracy: 0.9246
# Epoch 9/30
# 92/92 [==============================] - 20s 223ms/step - loss: 0.1667 - accuracy: 0.9363 - val_loss: 0.1664 - val_accuracy: 0.9342
# Epoch 10/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.1510 - accuracy: 0.9417 - val_loss: 0.1704 - val_accuracy: 0.9321
# Epoch 11/30
# 92/92 [==============================] - 20s 223ms/step - loss: 0.1198 - accuracy: 0.9536 - val_loss: 0.1494 - val_accuracy: 0.9417
# Epoch 12/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.1105 - accuracy: 0.9616 - val_loss: 0.1557 - val_accuracy: 0.9390
# Epoch 13/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.1023 - accuracy: 0.9649 - val_loss: 0.1640 - val_accuracy: 0.9315
# Epoch 14/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.0773 - accuracy: 0.9717 - val_loss: 0.1613 - val_accuracy: 0.9465
# Epoch 15/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.0782 - accuracy: 0.9726 - val_loss: 0.1637 - val_accuracy: 0.9431
# Epoch 16/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.0552 - accuracy: 0.9817 - val_loss: 0.1686 - val_accuracy: 0.9465
# Epoch 17/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.0636 - accuracy: 0.9779 - val_loss: 0.1636 - val_accuracy: 0.9390
# Epoch 18/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.0562 - accuracy: 0.9805 - val_loss: 0.1782 - val_accuracy: 0.9404
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 11.
# 29/29 [==============================] - 4s 89ms/step
# Fold 2 Results: Accuracy=0.9293, Precision=0.9137, Recall=0.9263, F1=0.9199, ROC-AUC==0.9794, Time=397.07s
# --- Starting Fold 3/5 ---
#
# Trainable params: 29,864,193
# Non-trainable params: 1
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  text (InputLayer)           [(None,)]                    0         []
#
#  preprocessing (KerasLayer)  {'input_type_ids': (None,    0         ['text[0][0]']
#                              128),
#                               'input_mask': (None, 128)
#                              , 'input_word_ids': (None,
#                               128)}
#
#  BERT_encoder (KerasLayer)   {'pooled_output': (None, 5   2876364   ['preprocessing[0][0]',
#                              12),                         9          'preprocessing[0][1]',
#                               'sequence_output': (None,              'preprocessing[0][2]']
#                               None, 512),
#                               'encoder_outputs': [(None
#                              , None, 512),
#                               (None, None, 512),
#                               (None, None, 512),
#                               (None, None, 512)],
#                               'default': (None, 512)}
#
#  spatial_dropout1d_12 (Spat  (None, None, 512)            0         ['BERT_encoder[0][6]']
#  ialDropout1D)
#
#  cu_dnnlstm_12 (CuDNNLSTM)   (None, None, 100)            245600    ['spatial_dropout1d_12[0][0]']
#
#  bidirectional_24 (Bidirect  (None, None, 256)            595712    ['cu_dnnlstm_12[0][0]']
#  ional)
#
#  bidirectional_25 (Bidirect  (None, None, 128)            254848    ['bidirectional_24[0][0]']
#  ional)
#
#  attention_for_seq_out_2 (A  (None, 128, 128)             256       ['bidirectional_25[0][0]']
#  ttentionForSeqOut)
#
#  global_average_pooling1d_1  (None, 128)                  0         ['attention_for_seq_out_2[0][0
#  2 (GlobalAveragePooling1D)                                         ]']
#
#  global_max_pooling1d_12 (G  (None, 128)                  0         ['attention_for_seq_out_2[0][0
#  lobalMaxPooling1D)                                                 ]']
#
#  concatenate_12 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_12[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_12[0][0
#                                                                     ]']
#
#  dense_24 (Dense)            (None, 16)                   4112      ['concatenate_12[0][0]']
#
#  dropout_12 (Dropout)        (None, 16)                   0         ['dense_24[0][0]']
#
#  dense_25 (Dense)            (None, 1)                    17        ['dropout_12[0][0]']
#
# ==================================================================================================
# Total params: 29864194 (113.92 MB)
# Trainable params: 29864193 (113.92 MB)
# Non-trainable params: 1 (1.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 49s 283ms/step - loss: 0.6595 - accuracy: 0.5591 - val_loss: 0.5486 - val_accuracy: 0.5860
# Epoch 2/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.5048 - accuracy: 0.8144 - val_loss: 0.7244 - val_accuracy: 0.4578
# Epoch 3/30
# 92/92 [==============================] - 21s 223ms/step - loss: 0.4348 - accuracy: 0.8307 - val_loss: 0.3771 - val_accuracy: 0.8389
# Epoch 4/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.3259 - accuracy: 0.8592 - val_loss: 0.2924 - val_accuracy: 0.8670
# Epoch 5/30
# 92/92 [==============================] - 20s 223ms/step - loss: 0.2754 - accuracy: 0.8790 - val_loss: 0.2539 - val_accuracy: 0.8814
# Epoch 6/30
# 92/92 [==============================] - 20s 223ms/step - loss: 0.2391 - accuracy: 0.8934 - val_loss: 0.2129 - val_accuracy: 0.9136
# Epoch 7/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.2023 - accuracy: 0.9183 - val_loss: 0.1950 - val_accuracy: 0.9205
# Epoch 8/30
# 92/92 [==============================] - 21s 223ms/step - loss: 0.1840 - accuracy: 0.9272 - val_loss: 0.1878 - val_accuracy: 0.9301
# Epoch 9/30
# 92/92 [==============================] - 20s 223ms/step - loss: 0.1567 - accuracy: 0.9376 - val_loss: 0.1726 - val_accuracy: 0.9356
# Epoch 10/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.1456 - accuracy: 0.9448 - val_loss: 0.1771 - val_accuracy: 0.9349
# Epoch 11/30
# 92/92 [==============================] - 20s 223ms/step - loss: 0.1289 - accuracy: 0.9493 - val_loss: 0.1884 - val_accuracy: 0.9342
# Epoch 12/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.1200 - accuracy: 0.9534 - val_loss: 0.1817 - val_accuracy: 0.9328
# Epoch 13/30
# 92/92 [==============================] - 20s 223ms/step - loss: 0.1148 - accuracy: 0.9599 - val_loss: 0.1662 - val_accuracy: 0.9383
# Epoch 14/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.1757 - accuracy: 0.9375 - val_loss: 0.1648 - val_accuracy: 0.9369
# Epoch 15/30
# 92/92 [==============================] - 20s 223ms/step - loss: 0.1080 - accuracy: 0.9584 - val_loss: 0.1622 - val_accuracy: 0.9417
# Epoch 16/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.0796 - accuracy: 0.9697 - val_loss: 0.1727 - val_accuracy: 0.9424
# Epoch 17/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.0746 - accuracy: 0.9726 - val_loss: 0.1896 - val_accuracy: 0.9390
# Epoch 18/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.0584 - accuracy: 0.9808 - val_loss: 2.0172 - val_accuracy: 0.5284
# Epoch 19/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.1562 - accuracy: 0.9453 - val_loss: 0.2201 - val_accuracy: 0.9417
# Epoch 20/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.0576 - accuracy: 0.9798 - val_loss: 0.2250 - val_accuracy: 0.9383
# Epoch 21/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.0390 - accuracy: 0.9866 - val_loss: 0.2309 - val_accuracy: 0.9390
# Epoch 22/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.0425 - accuracy: 0.9846 - val_loss: 0.2816 - val_accuracy: 0.9383
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 15.
# 29/29 [==============================] - 4s 88ms/step
# Fold 3 Results: Accuracy=0.9348, Precision=0.9463, Recall=0.9025, F1=0.9239, ROC-AUC==0.9793, Time=478.98s
# --- Starting Fold 4/5 ---
#
# Trainable params: 29,864,193
# Non-trainable params: 1
# Model: "model_13"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  text (InputLayer)           [(None,)]                    0         []
#
#  preprocessing (KerasLayer)  {'input_type_ids': (None,    0         ['text[0][0]']
#                              128),
#                               'input_mask': (None, 128)
#                              , 'input_word_ids': (None,
#                               128)}
#
#  BERT_encoder (KerasLayer)   {'pooled_output': (None, 5   2876364   ['preprocessing[0][0]',
#                              12),                         9          'preprocessing[0][1]',
#                               'sequence_output': (None,              'preprocessing[0][2]']
#                               None, 512),
#                               'encoder_outputs': [(None
#                              , None, 512),
#                               (None, None, 512),
#                               (None, None, 512),
#                               (None, None, 512)],
#                               'default': (None, 512)}
#
#  spatial_dropout1d_13 (Spat  (None, None, 512)            0         ['BERT_encoder[0][6]']
#  ialDropout1D)
#
#  cu_dnnlstm_13 (CuDNNLSTM)   (None, None, 100)            245600    ['spatial_dropout1d_13[0][0]']
#
#  bidirectional_26 (Bidirect  (None, None, 256)            595712    ['cu_dnnlstm_13[0][0]']
#  ional)
#
#  bidirectional_27 (Bidirect  (None, None, 128)            254848    ['bidirectional_26[0][0]']
#  ional)
#
#  attention_for_seq_out_3 (A  (None, 128, 128)             256       ['bidirectional_27[0][0]']
#  ttentionForSeqOut)
#
#  global_average_pooling1d_1  (None, 128)                  0         ['attention_for_seq_out_3[0][0
#  3 (GlobalAveragePooling1D)                                         ]']
#
#  global_max_pooling1d_13 (G  (None, 128)                  0         ['attention_for_seq_out_3[0][0
#  lobalMaxPooling1D)                                                 ]']
#
#  concatenate_13 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_13[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_13[0][0
#                                                                     ]']
#
#  dense_26 (Dense)            (None, 16)                   4112      ['concatenate_13[0][0]']
#
#  dropout_13 (Dropout)        (None, 16)                   0         ['dense_26[0][0]']
#
#  dense_27 (Dense)            (None, 1)                    17        ['dropout_13[0][0]']
#
# ==================================================================================================
# Total params: 29864194 (113.92 MB)
# Trainable params: 29864193 (113.92 MB)
# Non-trainable params: 1 (1.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 50s 285ms/step - loss: 0.6451 - accuracy: 0.5617 - val_loss: 0.5987 - val_accuracy: 0.5613
# Epoch 2/30
# 92/92 [==============================] - 21s 224ms/step - loss: 0.5268 - accuracy: 0.7736 - val_loss: 0.5325 - val_accuracy: 0.8424
# Epoch 3/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.4686 - accuracy: 0.8588 - val_loss: 0.5572 - val_accuracy: 0.7101
# Epoch 4/30
# 92/92 [==============================] - 21s 223ms/step - loss: 0.4065 - accuracy: 0.8605 - val_loss: 0.4918 - val_accuracy: 0.7519
# Epoch 5/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.3357 - accuracy: 0.8758 - val_loss: 0.9028 - val_accuracy: 0.4942
# Epoch 6/30
# 92/92 [==============================] - 21s 223ms/step - loss: 0.2833 - accuracy: 0.8854 - val_loss: 0.3751 - val_accuracy: 0.8019
# Epoch 7/30
# 92/92 [==============================] - 20s 223ms/step - loss: 0.2407 - accuracy: 0.9044 - val_loss: 0.3651 - val_accuracy: 0.8067
# Epoch 8/30
# 92/92 [==============================] - 20s 223ms/step - loss: 0.1924 - accuracy: 0.9227 - val_loss: 0.2610 - val_accuracy: 0.8732
# Epoch 9/30
# 92/92 [==============================] - 21s 224ms/step - loss: 0.1788 - accuracy: 0.9277 - val_loss: 0.2536 - val_accuracy: 0.8766
# Epoch 10/30
# 92/92 [==============================] - 21s 223ms/step - loss: 0.1591 - accuracy: 0.9397 - val_loss: 0.2048 - val_accuracy: 0.9054
# Epoch 11/30
# 92/92 [==============================] - 20s 221ms/step - loss: 0.1391 - accuracy: 0.9489 - val_loss: 0.2143 - val_accuracy: 0.9047
# Epoch 12/30
# 92/92 [==============================] - 21s 224ms/step - loss: 0.1734 - accuracy: 0.9388 - val_loss: 0.1812 - val_accuracy: 0.9260
# Epoch 13/30
# 92/92 [==============================] - 20s 223ms/step - loss: 0.1167 - accuracy: 0.9570 - val_loss: 0.1800 - val_accuracy: 0.9349
# Epoch 14/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.1007 - accuracy: 0.9640 - val_loss: 0.1848 - val_accuracy: 0.9383
# Epoch 15/30
# 92/92 [==============================] - 21s 223ms/step - loss: 0.0977 - accuracy: 0.9647 - val_loss: 0.1749 - val_accuracy: 0.9459
# Epoch 16/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.0874 - accuracy: 0.9693 - val_loss: 0.1797 - val_accuracy: 0.9431
# Epoch 17/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.0759 - accuracy: 0.9740 - val_loss: 0.1876 - val_accuracy: 0.9349
# Epoch 18/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.0774 - accuracy: 0.9746 - val_loss: 0.1975 - val_accuracy: 0.9417
# Epoch 19/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.0555 - accuracy: 0.9798 - val_loss: 0.1932 - val_accuracy: 0.9472
# Epoch 20/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.0849 - accuracy: 0.9738 - val_loss: 0.2964 - val_accuracy: 0.9136
# Epoch 21/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.0569 - accuracy: 0.9815 - val_loss: 0.2210 - val_accuracy: 0.9376
# Epoch 22/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.0391 - accuracy: 0.9882 - val_loss: 0.2754 - val_accuracy: 0.9068
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 15.
# 29/29 [==============================] - 4s 88ms/step
# Fold 4 Results: Accuracy=0.9496, Precision=0.9707, Recall=0.9124, F1=0.9406, ROC-AUC==0.9884, Time=480.56s
# --- Starting Fold 5/5 ---
#
# Trainable params: 29,864,193
# Non-trainable params: 1
# Model: "model_14"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  text (InputLayer)           [(None,)]                    0         []
#
#  preprocessing (KerasLayer)  {'input_type_ids': (None,    0         ['text[0][0]']
#                              128),
#                               'input_mask': (None, 128)
#                              , 'input_word_ids': (None,
#                               128)}
#
#  BERT_encoder (KerasLayer)   {'pooled_output': (None, 5   2876364   ['preprocessing[0][0]',
#                              12),                         9          'preprocessing[0][1]',
#                               'sequence_output': (None,              'preprocessing[0][2]']
#                               None, 512),
#                               'encoder_outputs': [(None
#                              , None, 512),
#                               (None, None, 512),
#                               (None, None, 512),
#                               (None, None, 512)],
#                               'default': (None, 512)}
#
#  spatial_dropout1d_14 (Spat  (None, None, 512)            0         ['BERT_encoder[0][6]']
#  ialDropout1D)
#
#  cu_dnnlstm_14 (CuDNNLSTM)   (None, None, 100)            245600    ['spatial_dropout1d_14[0][0]']
#
#  bidirectional_28 (Bidirect  (None, None, 256)            595712    ['cu_dnnlstm_14[0][0]']
#  ional)
#
#  bidirectional_29 (Bidirect  (None, None, 128)            254848    ['bidirectional_28[0][0]']
#  ional)
#
#  attention_for_seq_out_4 (A  (None, 128, 128)             256       ['bidirectional_29[0][0]']
#  ttentionForSeqOut)
#
#  global_average_pooling1d_1  (None, 128)                  0         ['attention_for_seq_out_4[0][0
#  4 (GlobalAveragePooling1D)                                         ]']
#
#  global_max_pooling1d_14 (G  (None, 128)                  0         ['attention_for_seq_out_4[0][0
#  lobalMaxPooling1D)                                                 ]']
#
#  concatenate_14 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_14[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_14[0][0
#                                                                     ]']
#
#  dense_28 (Dense)            (None, 16)                   4112      ['concatenate_14[0][0]']
#
#  dropout_14 (Dropout)        (None, 16)                   0         ['dense_28[0][0]']
#
#  dense_29 (Dense)            (None, 1)                    17        ['dropout_14[0][0]']
#
# ==================================================================================================
# Total params: 29864194 (113.92 MB)
# Trainable params: 29864193 (113.92 MB)
# Non-trainable params: 1 (1.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 49s 286ms/step - loss: 0.6867 - accuracy: 0.5598 - val_loss: 0.6791 - val_accuracy: 0.5616
# Epoch 2/30
# 92/92 [==============================] - 21s 224ms/step - loss: 0.6686 - accuracy: 0.5615 - val_loss: 0.6418 - val_accuracy: 0.5616
# Epoch 3/30
# 92/92 [==============================] - 21s 225ms/step - loss: 0.5573 - accuracy: 0.6773 - val_loss: 0.5523 - val_accuracy: 0.8363
# Epoch 4/30
# 92/92 [==============================] - 21s 224ms/step - loss: 0.4053 - accuracy: 0.8509 - val_loss: 0.2976 - val_accuracy: 0.8637
# Epoch 5/30
# 92/92 [==============================] - 21s 223ms/step - loss: 0.3154 - accuracy: 0.8638 - val_loss: 0.2444 - val_accuracy: 0.8979
# Epoch 6/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.2753 - accuracy: 0.8814 - val_loss: 0.3340 - val_accuracy: 0.8342
# Epoch 7/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.2944 - accuracy: 0.8862 - val_loss: 0.2690 - val_accuracy: 0.8829
# Epoch 8/30
# 92/92 [==============================] - 20s 223ms/step - loss: 0.2196 - accuracy: 0.9088 - val_loss: 0.3567 - val_accuracy: 0.8836
# Epoch 9/30
# 92/92 [==============================] - 21s 223ms/step - loss: 0.2081 - accuracy: 0.9138 - val_loss: 0.1684 - val_accuracy: 0.9247
# Epoch 10/30
# 92/92 [==============================] - 21s 224ms/step - loss: 0.1859 - accuracy: 0.9249 - val_loss: 0.1604 - val_accuracy: 0.9322
# Epoch 11/30
# 92/92 [==============================] - 21s 223ms/step - loss: 0.1596 - accuracy: 0.9402 - val_loss: 0.1523 - val_accuracy: 0.9390
# Epoch 12/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.1454 - accuracy: 0.9440 - val_loss: 0.1570 - val_accuracy: 0.9349
# Epoch 13/30
# 92/92 [==============================] - 21s 225ms/step - loss: 0.1435 - accuracy: 0.9474 - val_loss: 0.1439 - val_accuracy: 0.9432
# Epoch 14/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.1184 - accuracy: 0.9577 - val_loss: 0.1580 - val_accuracy: 0.9418
# Epoch 15/30
# 92/92 [==============================] - 20s 223ms/step - loss: 0.1329 - accuracy: 0.9572 - val_loss: 0.1538 - val_accuracy: 0.9452
# Epoch 16/30
# 92/92 [==============================] - 20s 223ms/step - loss: 0.0965 - accuracy: 0.9645 - val_loss: 0.1714 - val_accuracy: 0.9356
# Epoch 17/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.0911 - accuracy: 0.9671 - val_loss: 0.1669 - val_accuracy: 0.9411
# Epoch 18/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.1159 - accuracy: 0.9596 - val_loss: 0.2173 - val_accuracy: 0.9342
# Epoch 19/30
# 92/92 [==============================] - 20s 223ms/step - loss: 0.0864 - accuracy: 0.9705 - val_loss: 0.1632 - val_accuracy: 0.9452
# Epoch 20/30
# 92/92 [==============================] - 20s 222ms/step - loss: 0.0632 - accuracy: 0.9789 - val_loss: 0.2057 - val_accuracy: 0.9384
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 13.
# 29/29 [==============================] - 4s 92ms/step
# Fold 5 Results: Accuracy=0.9347, Precision=0.9348, Recall=0.9149, F1=0.9247, ROC-AUC==0.9798, Time=439.87s
# --- Analysis for: tcn_model_fine_tune_sb_seqOut - Twitter ---
# --------------------------------------------------
#
# [Raw Results per Fold]
#    Fold  Accuracy  Precision    Recall  F1-Score   ROC-AUC  Training Time (s)  Dataset
# 0     1  0.940241   0.952818  0.908750  0.930262  0.985233         414.360306  Twitter
# 1     2  0.929276   0.913687  0.926250  0.919926  0.979431         397.065814  Twitter
# 2     3  0.934759   0.946265  0.902500  0.923864  0.979288         478.980929  Twitter
# 3     4  0.949561   0.970706  0.912390  0.940645  0.988370         480.564809  Twitter
# 4     5  0.934723   0.934783  0.914894  0.924731  0.979814         439.865971  Twitter
#
# [Summary Statistics]
#                          mean        std
# Accuracy             0.937712   0.007675
# Precision            0.943652   0.021209
# Recall               0.912957   0.008772
# F1-Score             0.927886   0.008030
# ROC-AUC              0.982427   0.004149
# Training Time (s)  442.167566  37.557559
# --------------------------------------------------
#
# [Total Training Time]: 2210.8378286361694 seconds
# 73154

# %%
#tcn_model_fine_tune_mb_pool
result, history_list = run_cross_validation(FOLDS, X, y, tcn_model_fine_tune_mb_pool,True)
variant_name = "tcn_model_fine_tune_mb_pool"
result['Variant'] = variant_name
result['Dataset'] = 'Twitter'
all_results.append(result)
analyze_cv_results(result)

for hist in history_list:
    hist['Variant'] = variant_name
    all_histories.extend(history_list)

output_filename = f'/content/drive/MyDrive/final_FYP_results/{folder_name}/{variant_name}_twitter_result.csv'
result.to_csv(output_filename, index=False)
del output_filename
del history_list
del result
gc.collect()
# Out:
# --- Starting Fold 1/5 ---
# TensorFlow and JAX classes are deprecated and will be removed in Transformers v5. We recommend migrating to PyTorch classes or pinning your version of Transformers.
# Tokenizing training data...
# Tokenizing training data...
# Tokenizing training data...
# TensorFlow and JAX classes are deprecated and will be removed in Transformers v5. We recommend migrating to PyTorch classes or pinning your version of Transformers.
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'bert.embeddings.position_ids', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertModel were not initialized from the PyTorch model and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Trainable params: 110,685,058
# Non-trainable params: 0
# Model: "model_15"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  attention_mask (InputLayer  [(None, 128)]                0         []
#  )
#
#  input_ids (InputLayer)      [(None, 128)]                0         []
#
#  token_type_ids (InputLayer  [(None, 128)]                0         []
#  )
#
#  tf_bert_model (TFBertModel  TFBaseModelOutputWithPooli   1094822   ['attention_mask[0][0]',
#  )                           ngAndCrossAttentions(last_   40         'input_ids[0][0]',
#                              hidden_state=(None, 128, 7              'token_type_ids[0][0]']
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  tf.expand_dims_10 (TFOpLam  (None, 1, 768)               0         ['tf_bert_model[0][1]']
#  bda)
#
#  spatial_dropout1d_15 (Spat  (None, 1, 768)               0         ['tf.expand_dims_10[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_15 (CuDNNLSTM)   (None, 1, 100)               348000    ['spatial_dropout1d_15[0][0]']
#
#  bidirectional_30 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_15[0][0]']
#  ional)
#
#  bidirectional_31 (Bidirect  (None, 1, 128)               254848    ['bidirectional_30[0][0]']
#  ional)
#
#  cust_attention_10 (CustAtt  (None, 1, 128)               129       ['bidirectional_31[0][0]']
#  ention)
#
#  global_average_pooling1d_1  (None, 128)                  0         ['cust_attention_10[0][0]']
#  5 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_15 (G  (None, 128)                  0         ['cust_attention_10[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_15 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_15[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_15[0][0
#                                                                     ]']
#
#  dense_30 (Dense)            (None, 16)                   4112      ['concatenate_15[0][0]']
#
#  dropout_52 (Dropout)        (None, 16)                   0         ['dense_30[0][0]']
#
#  dense_31 (Dense)            (None, 1)                    17        ['dropout_52[0][0]']
#
# ==================================================================================================
# Total params: 110685058 (422.23 MB)
# Trainable params: 110685058 (422.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 112s 718ms/step - loss: 0.5718 - accuracy: 0.8266 - val_loss: 0.3656 - val_accuracy: 0.8849
# Epoch 2/30
# 92/92 [==============================] - 61s 664ms/step - loss: 0.2994 - accuracy: 0.8989 - val_loss: 0.2265 - val_accuracy: 0.9157
# Epoch 3/30
# 92/92 [==============================] - 61s 665ms/step - loss: 0.2200 - accuracy: 0.9236 - val_loss: 0.2078 - val_accuracy: 0.9232
# Epoch 4/30
# 92/92 [==============================] - 61s 664ms/step - loss: 0.1867 - accuracy: 0.9339 - val_loss: 0.1836 - val_accuracy: 0.9308
# Epoch 5/30
# 92/92 [==============================] - 61s 665ms/step - loss: 0.1347 - accuracy: 0.9548 - val_loss: 0.1789 - val_accuracy: 0.9404
# Epoch 6/30
# 92/92 [==============================] - 61s 664ms/step - loss: 0.1421 - accuracy: 0.9510 - val_loss: 0.1763 - val_accuracy: 0.9397
# Epoch 7/30
# 92/92 [==============================] - 61s 660ms/step - loss: 0.0935 - accuracy: 0.9714 - val_loss: 0.1794 - val_accuracy: 0.9424
# Epoch 8/30
# 92/92 [==============================] - 61s 665ms/step - loss: 0.0820 - accuracy: 0.9762 - val_loss: 0.1614 - val_accuracy: 0.9411
# Epoch 9/30
# 92/92 [==============================] - 61s 660ms/step - loss: 0.0683 - accuracy: 0.9803 - val_loss: 0.1953 - val_accuracy: 0.9383
# Epoch 10/30
# 92/92 [==============================] - 61s 661ms/step - loss: 0.0670 - accuracy: 0.9810 - val_loss: 0.1752 - val_accuracy: 0.9459
# Epoch 11/30
# 92/92 [==============================] - 61s 661ms/step - loss: 0.0592 - accuracy: 0.9824 - val_loss: 0.2006 - val_accuracy: 0.9445
# Epoch 12/30
# 92/92 [==============================] - 61s 661ms/step - loss: 0.0428 - accuracy: 0.9902 - val_loss: 0.1874 - val_accuracy: 0.9438
# Epoch 13/30
# 92/92 [==============================] - 61s 660ms/step - loss: 0.0518 - accuracy: 0.9846 - val_loss: 0.1686 - val_accuracy: 0.9465
# Epoch 14/30
# 92/92 [==============================] - 61s 661ms/step - loss: 0.0344 - accuracy: 0.9930 - val_loss: 0.1994 - val_accuracy: 0.9472
# Epoch 15/30
# 92/92 [==============================] - 61s 660ms/step - loss: 0.0279 - accuracy: 0.9925 - val_loss: 0.1957 - val_accuracy: 0.9424
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 29/29 [==============================] - 10s 200ms/step
# Fold 1 Results: Accuracy=0.9545, Precision=0.9442, Recall=0.9525, F1=0.9484, ROC-AUC==0.9887, Time=966.27s
# --- Starting Fold 2/5 ---
# Tokenizing training data...
# Tokenizing training data...
# Tokenizing training data...
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'bert.embeddings.position_ids', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertModel were not initialized from the PyTorch model and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Trainable params: 110,685,058
# Non-trainable params: 0
# Model: "model_16"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  attention_mask (InputLayer  [(None, 128)]                0         []
#  )
#
#  input_ids (InputLayer)      [(None, 128)]                0         []
#
#  token_type_ids (InputLayer  [(None, 128)]                0         []
#  )
#
#  tf_bert_model_1 (TFBertMod  TFBaseModelOutputWithPooli   1094822   ['attention_mask[0][0]',
#  el)                         ngAndCrossAttentions(last_   40         'input_ids[0][0]',
#                              hidden_state=(None, 128, 7              'token_type_ids[0][0]']
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  tf.expand_dims_11 (TFOpLam  (None, 1, 768)               0         ['tf_bert_model_1[0][1]']
#  bda)
#
#  spatial_dropout1d_16 (Spat  (None, 1, 768)               0         ['tf.expand_dims_11[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_16 (CuDNNLSTM)   (None, 1, 100)               348000    ['spatial_dropout1d_16[0][0]']
#
#  bidirectional_32 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_16[0][0]']
#  ional)
#
#  bidirectional_33 (Bidirect  (None, 1, 128)               254848    ['bidirectional_32[0][0]']
#  ional)
#
#  cust_attention_11 (CustAtt  (None, 1, 128)               129       ['bidirectional_33[0][0]']
#  ention)
#
#  global_average_pooling1d_1  (None, 128)                  0         ['cust_attention_11[0][0]']
#  6 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_16 (G  (None, 128)                  0         ['cust_attention_11[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_16 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_16[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_16[0][0
#                                                                     ]']
#
#  dense_32 (Dense)            (None, 16)                   4112      ['concatenate_16[0][0]']
#
#  dropout_90 (Dropout)        (None, 16)                   0         ['dense_32[0][0]']
#
#  dense_33 (Dense)            (None, 1)                    17        ['dropout_90[0][0]']
#
# ==================================================================================================
# Total params: 110685058 (422.23 MB)
# Trainable params: 110685058 (422.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 114s 719ms/step - loss: 0.6553 - accuracy: 0.6791 - val_loss: 0.5630 - val_accuracy: 0.8958
# Epoch 2/30
# 92/92 [==============================] - 61s 664ms/step - loss: 0.4198 - accuracy: 0.8944 - val_loss: 0.2708 - val_accuracy: 0.9123
# Epoch 3/30
# 92/92 [==============================] - 61s 664ms/step - loss: 0.2692 - accuracy: 0.9092 - val_loss: 0.1794 - val_accuracy: 0.9404
# Epoch 4/30
# 92/92 [==============================] - 61s 664ms/step - loss: 0.2007 - accuracy: 0.9327 - val_loss: 0.1620 - val_accuracy: 0.9376
# Epoch 5/30
# 92/92 [==============================] - 61s 662ms/step - loss: 0.1656 - accuracy: 0.9438 - val_loss: 0.1739 - val_accuracy: 0.9301
# Epoch 6/30
# 92/92 [==============================] - 61s 664ms/step - loss: 0.1577 - accuracy: 0.9472 - val_loss: 0.1325 - val_accuracy: 0.9520
# Epoch 7/30
# 92/92 [==============================] - 61s 664ms/step - loss: 0.1139 - accuracy: 0.9652 - val_loss: 0.1288 - val_accuracy: 0.9513
# Epoch 8/30
# 92/92 [==============================] - 61s 661ms/step - loss: 0.1077 - accuracy: 0.9674 - val_loss: 0.1571 - val_accuracy: 0.9363
# Epoch 9/30
# 92/92 [==============================] - 61s 665ms/step - loss: 0.0925 - accuracy: 0.9722 - val_loss: 0.1265 - val_accuracy: 0.9554
# Epoch 10/30
# 92/92 [==============================] - 61s 661ms/step - loss: 0.0682 - accuracy: 0.9794 - val_loss: 0.1493 - val_accuracy: 0.9479
# Epoch 11/30
# 92/92 [==============================] - 61s 662ms/step - loss: 0.0702 - accuracy: 0.9815 - val_loss: 0.1292 - val_accuracy: 0.9534
# Epoch 12/30
# 92/92 [==============================] - 61s 661ms/step - loss: 0.0523 - accuracy: 0.9871 - val_loss: 0.1515 - val_accuracy: 0.9500
# Epoch 13/30
# 92/92 [==============================] - 61s 661ms/step - loss: 0.0506 - accuracy: 0.9854 - val_loss: 0.1409 - val_accuracy: 0.9554
# Epoch 14/30
# 92/92 [==============================] - 61s 661ms/step - loss: 0.0401 - accuracy: 0.9887 - val_loss: 0.1374 - val_accuracy: 0.9541
# Epoch 15/30
# 92/92 [==============================] - 61s 661ms/step - loss: 0.0315 - accuracy: 0.9921 - val_loss: 0.1432 - val_accuracy: 0.9589
# Epoch 16/30
# 92/92 [==============================] - 61s 661ms/step - loss: 0.0298 - accuracy: 0.9914 - val_loss: 0.2454 - val_accuracy: 0.9321
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 29/29 [==============================] - 10s 197ms/step
# Fold 2 Results: Accuracy=0.9474, Precision=0.9303, Recall=0.9513, F1=0.9407, ROC-AUC==0.9872, Time=1028.89s
# --- Starting Fold 3/5 ---
# Tokenizing training data...
# Tokenizing training data...
# Tokenizing training data...
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'bert.embeddings.position_ids', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertModel were not initialized from the PyTorch model and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Trainable params: 110,685,058
# Non-trainable params: 0
# Model: "model_17"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  attention_mask (InputLayer  [(None, 128)]                0         []
#  )
#
#  input_ids (InputLayer)      [(None, 128)]                0         []
#
#  token_type_ids (InputLayer  [(None, 128)]                0         []
#  )
#
#  tf_bert_model_2 (TFBertMod  TFBaseModelOutputWithPooli   1094822   ['attention_mask[0][0]',
#  el)                         ngAndCrossAttentions(last_   40         'input_ids[0][0]',
#                              hidden_state=(None, 128, 7              'token_type_ids[0][0]']
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  tf.expand_dims_12 (TFOpLam  (None, 1, 768)               0         ['tf_bert_model_2[0][1]']
#  bda)
#
#  spatial_dropout1d_17 (Spat  (None, 1, 768)               0         ['tf.expand_dims_12[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_17 (CuDNNLSTM)   (None, 1, 100)               348000    ['spatial_dropout1d_17[0][0]']
#
#  bidirectional_34 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_17[0][0]']
#  ional)
#
#  bidirectional_35 (Bidirect  (None, 1, 128)               254848    ['bidirectional_34[0][0]']
#  ional)
#
#  cust_attention_12 (CustAtt  (None, 1, 128)               129       ['bidirectional_35[0][0]']
#  ention)
#
#  global_average_pooling1d_1  (None, 128)                  0         ['cust_attention_12[0][0]']
#  7 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_17 (G  (None, 128)                  0         ['cust_attention_12[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_17 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_17[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_17[0][0
#                                                                     ]']
#
#  dense_34 (Dense)            (None, 16)                   4112      ['concatenate_17[0][0]']
#
#  dropout_128 (Dropout)       (None, 16)                   0         ['dense_34[0][0]']
#
#  dense_35 (Dense)            (None, 1)                    17        ['dropout_128[0][0]']
#
# ==================================================================================================
# Total params: 110685058 (422.23 MB)
# Trainable params: 110685058 (422.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 114s 721ms/step - loss: 0.6809 - accuracy: 0.5685 - val_loss: 0.6493 - val_accuracy: 0.7738
# Epoch 2/30
# 92/92 [==============================] - 61s 666ms/step - loss: 0.5653 - accuracy: 0.8199 - val_loss: 0.4525 - val_accuracy: 0.8869
# Epoch 3/30
# 92/92 [==============================] - 61s 666ms/step - loss: 0.3568 - accuracy: 0.8996 - val_loss: 0.2344 - val_accuracy: 0.9260
# Epoch 4/30
# 92/92 [==============================] - 61s 665ms/step - loss: 0.2435 - accuracy: 0.9208 - val_loss: 0.2188 - val_accuracy: 0.9171
# Epoch 5/30
# 92/92 [==============================] - 61s 665ms/step - loss: 0.1795 - accuracy: 0.9407 - val_loss: 0.1531 - val_accuracy: 0.9500
# Epoch 6/30
# 92/92 [==============================] - 61s 667ms/step - loss: 0.1583 - accuracy: 0.9493 - val_loss: 0.1372 - val_accuracy: 0.9500
# Epoch 7/30
# 92/92 [==============================] - 61s 665ms/step - loss: 0.1207 - accuracy: 0.9613 - val_loss: 0.1318 - val_accuracy: 0.9534
# Epoch 8/30
# 92/92 [==============================] - 61s 662ms/step - loss: 0.1097 - accuracy: 0.9671 - val_loss: 0.1539 - val_accuracy: 0.9500
# Epoch 9/30
# 92/92 [==============================] - 61s 666ms/step - loss: 0.0933 - accuracy: 0.9741 - val_loss: 0.1304 - val_accuracy: 0.9561
# Epoch 10/30
# 92/92 [==============================] - 61s 663ms/step - loss: 0.0820 - accuracy: 0.9767 - val_loss: 0.1796 - val_accuracy: 0.9431
# Epoch 11/30
# 92/92 [==============================] - 61s 662ms/step - loss: 0.0803 - accuracy: 0.9782 - val_loss: 0.1456 - val_accuracy: 0.9561
# Epoch 12/30
# 92/92 [==============================] - 61s 662ms/step - loss: 0.0607 - accuracy: 0.9844 - val_loss: 0.1542 - val_accuracy: 0.9548
# Epoch 13/30
# 92/92 [==============================] - 61s 663ms/step - loss: 0.0476 - accuracy: 0.9887 - val_loss: 0.1989 - val_accuracy: 0.9472
# Epoch 14/30
# 92/92 [==============================] - 61s 663ms/step - loss: 0.0421 - accuracy: 0.9902 - val_loss: 0.1614 - val_accuracy: 0.9541
# Epoch 15/30
# 92/92 [==============================] - 61s 663ms/step - loss: 0.0397 - accuracy: 0.9902 - val_loss: 0.1813 - val_accuracy: 0.9534
# Epoch 16/30
# 92/92 [==============================] - 61s 663ms/step - loss: 0.0293 - accuracy: 0.9926 - val_loss: 0.1750 - val_accuracy: 0.9548
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 29/29 [==============================] - 10s 198ms/step
# Fold 3 Results: Accuracy=0.9446, Precision=0.9452, Recall=0.9275, F1=0.9363, ROC-AUC==0.9842, Time=1031.90s
# --- Starting Fold 4/5 ---
# Tokenizing training data...
# Tokenizing training data...
# Tokenizing training data...
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'bert.embeddings.position_ids', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertModel were not initialized from the PyTorch model and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Trainable params: 110,685,058
# Non-trainable params: 0
# Model: "model_18"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  attention_mask (InputLayer  [(None, 128)]                0         []
#  )
#
#  input_ids (InputLayer)      [(None, 128)]                0         []
#
#  token_type_ids (InputLayer  [(None, 128)]                0         []
#  )
#
#  tf_bert_model_3 (TFBertMod  TFBaseModelOutputWithPooli   1094822   ['attention_mask[0][0]',
#  el)                         ngAndCrossAttentions(last_   40         'input_ids[0][0]',
#                              hidden_state=(None, 128, 7              'token_type_ids[0][0]']
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  tf.expand_dims_13 (TFOpLam  (None, 1, 768)               0         ['tf_bert_model_3[0][1]']
#  bda)
#
#  spatial_dropout1d_18 (Spat  (None, 1, 768)               0         ['tf.expand_dims_13[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_18 (CuDNNLSTM)   (None, 1, 100)               348000    ['spatial_dropout1d_18[0][0]']
#
#  bidirectional_36 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_18[0][0]']
#  ional)
#
#  bidirectional_37 (Bidirect  (None, 1, 128)               254848    ['bidirectional_36[0][0]']
#  ional)
#
#  cust_attention_13 (CustAtt  (None, 1, 128)               129       ['bidirectional_37[0][0]']
#  ention)
#
#  global_average_pooling1d_1  (None, 128)                  0         ['cust_attention_13[0][0]']
#  8 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_18 (G  (None, 128)                  0         ['cust_attention_13[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_18 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_18[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_18[0][0
#                                                                     ]']
#
#  dense_36 (Dense)            (None, 16)                   4112      ['concatenate_18[0][0]']
#
#  dropout_166 (Dropout)       (None, 16)                   0         ['dense_36[0][0]']
#
#  dense_37 (Dense)            (None, 1)                    17        ['dropout_166[0][0]']
#
# ==================================================================================================
# Total params: 110685058 (422.23 MB)
# Trainable params: 110685058 (422.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 115s 721ms/step - loss: 0.6389 - accuracy: 0.6016 - val_loss: 0.5424 - val_accuracy: 0.8842
# Epoch 2/30
# 92/92 [==============================] - 61s 662ms/step - loss: 0.4329 - accuracy: 0.8912 - val_loss: 0.6592 - val_accuracy: 0.5922
# Epoch 3/30
# 92/92 [==============================] - 61s 666ms/step - loss: 0.2996 - accuracy: 0.9046 - val_loss: 0.5314 - val_accuracy: 0.7526
# Epoch 4/30
# 92/92 [==============================] - 61s 665ms/step - loss: 0.2116 - accuracy: 0.9299 - val_loss: 0.3039 - val_accuracy: 0.8780
# Epoch 5/30
# 92/92 [==============================] - 61s 665ms/step - loss: 0.1743 - accuracy: 0.9445 - val_loss: 0.2494 - val_accuracy: 0.9061
# Epoch 6/30
# 92/92 [==============================] - 61s 663ms/step - loss: 0.1337 - accuracy: 0.9554 - val_loss: 0.2973 - val_accuracy: 0.8931
# Epoch 7/30
# 92/92 [==============================] - 61s 662ms/step - loss: 0.1277 - accuracy: 0.9565 - val_loss: 0.6580 - val_accuracy: 0.7670
# Epoch 8/30
# 92/92 [==============================] - 61s 665ms/step - loss: 0.1078 - accuracy: 0.9652 - val_loss: 0.1992 - val_accuracy: 0.9356
# Epoch 9/30
# 92/92 [==============================] - 61s 662ms/step - loss: 0.0818 - accuracy: 0.9764 - val_loss: 0.2045 - val_accuracy: 0.9417
# Epoch 10/30
# 92/92 [==============================] - 61s 662ms/step - loss: 0.0746 - accuracy: 0.9805 - val_loss: 0.4058 - val_accuracy: 0.8773
# Epoch 11/30
# 92/92 [==============================] - 61s 662ms/step - loss: 0.0699 - accuracy: 0.9789 - val_loss: 0.2561 - val_accuracy: 0.9328
# Epoch 12/30
# 92/92 [==============================] - 61s 662ms/step - loss: 0.0420 - accuracy: 0.9882 - val_loss: 0.2876 - val_accuracy: 0.9349
# Epoch 13/30
# 92/92 [==============================] - 61s 662ms/step - loss: 0.0404 - accuracy: 0.9887 - val_loss: 0.3343 - val_accuracy: 0.9301
# Epoch 14/30
# 92/92 [==============================] - 61s 663ms/step - loss: 0.0770 - accuracy: 0.9777 - val_loss: 0.2249 - val_accuracy: 0.9376
# Epoch 15/30
# 92/92 [==============================] - 61s 663ms/step - loss: 0.0379 - accuracy: 0.9897 - val_loss: 0.2340 - val_accuracy: 0.9363
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 29/29 [==============================] - 10s 199ms/step
# Fold 4 Results: Accuracy=0.9572, Precision=0.9569, Recall=0.9449, F1=0.9509, ROC-AUC==0.9907, Time=969.66s
# --- Starting Fold 5/5 ---
# Tokenizing training data...
# Tokenizing training data...
# Tokenizing training data...
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'bert.embeddings.position_ids', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertModel were not initialized from the PyTorch model and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Trainable params: 110,685,058
# Non-trainable params: 0
# Model: "model_19"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  attention_mask (InputLayer  [(None, 128)]                0         []
#  )
#
#  input_ids (InputLayer)      [(None, 128)]                0         []
#
#  token_type_ids (InputLayer  [(None, 128)]                0         []
#  )
#
#  tf_bert_model_4 (TFBertMod  TFBaseModelOutputWithPooli   1094822   ['attention_mask[0][0]',
#  el)                         ngAndCrossAttentions(last_   40         'input_ids[0][0]',
#                              hidden_state=(None, 128, 7              'token_type_ids[0][0]']
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  tf.expand_dims_14 (TFOpLam  (None, 1, 768)               0         ['tf_bert_model_4[0][1]']
#  bda)
#
#  spatial_dropout1d_19 (Spat  (None, 1, 768)               0         ['tf.expand_dims_14[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_19 (CuDNNLSTM)   (None, 1, 100)               348000    ['spatial_dropout1d_19[0][0]']
#
#  bidirectional_38 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_19[0][0]']
#  ional)
#
#  bidirectional_39 (Bidirect  (None, 1, 128)               254848    ['bidirectional_38[0][0]']
#  ional)
#
#  cust_attention_14 (CustAtt  (None, 1, 128)               129       ['bidirectional_39[0][0]']
#  ention)
#
#  global_average_pooling1d_1  (None, 128)                  0         ['cust_attention_14[0][0]']
#  9 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_19 (G  (None, 128)                  0         ['cust_attention_14[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_19 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_19[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_19[0][0
#                                                                     ]']
#
#  dense_38 (Dense)            (None, 16)                   4112      ['concatenate_19[0][0]']
#
#  dropout_204 (Dropout)       (None, 16)                   0         ['dense_38[0][0]']
#
#  dense_39 (Dense)            (None, 1)                    17        ['dropout_204[0][0]']
#
# ==================================================================================================
# Total params: 110685058 (422.23 MB)
# Trainable params: 110685058 (422.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 115s 720ms/step - loss: 0.6701 - accuracy: 0.5631 - val_loss: 0.6224 - val_accuracy: 0.5616
# Epoch 2/30
# 92/92 [==============================] - 61s 666ms/step - loss: 0.5240 - accuracy: 0.8110 - val_loss: 0.3706 - val_accuracy: 0.9260
# Epoch 3/30
# 92/92 [==============================] - 61s 665ms/step - loss: 0.3330 - accuracy: 0.8982 - val_loss: 0.2246 - val_accuracy: 0.9212
# Epoch 4/30
# 92/92 [==============================] - 61s 664ms/step - loss: 0.2310 - accuracy: 0.9200 - val_loss: 0.1783 - val_accuracy: 0.9342
# Epoch 5/30
# 92/92 [==============================] - 61s 665ms/step - loss: 0.1856 - accuracy: 0.9342 - val_loss: 0.1740 - val_accuracy: 0.9377
# Epoch 6/30
# 92/92 [==============================] - 61s 664ms/step - loss: 0.1523 - accuracy: 0.9447 - val_loss: 0.1368 - val_accuracy: 0.9521
# Epoch 7/30
# 92/92 [==============================] - 61s 661ms/step - loss: 0.1163 - accuracy: 0.9620 - val_loss: 0.1611 - val_accuracy: 0.9438
# Epoch 8/30
# 92/92 [==============================] - 61s 661ms/step - loss: 0.1128 - accuracy: 0.9601 - val_loss: 0.1820 - val_accuracy: 0.9363
# Epoch 9/30
# 92/92 [==============================] - 61s 661ms/step - loss: 0.0946 - accuracy: 0.9673 - val_loss: 0.1810 - val_accuracy: 0.9390
# Epoch 10/30
# 92/92 [==============================] - 61s 662ms/step - loss: 0.0761 - accuracy: 0.9731 - val_loss: 0.1727 - val_accuracy: 0.9473
# Epoch 11/30
# 92/92 [==============================] - 61s 661ms/step - loss: 0.0666 - accuracy: 0.9753 - val_loss: 0.1881 - val_accuracy: 0.9486
# Epoch 12/30
# 92/92 [==============================] - 61s 660ms/step - loss: 0.0539 - accuracy: 0.9805 - val_loss: 0.1949 - val_accuracy: 0.9493
# Epoch 13/30
# 92/92 [==============================] - 61s 661ms/step - loss: 0.0423 - accuracy: 0.9861 - val_loss: 0.2261 - val_accuracy: 0.9377
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 29/29 [==============================] - 10s 199ms/step
# Fold 5 Results: Accuracy=0.9375, Precision=0.9182, Recall=0.9412, F1=0.9295, ROC-AUC==0.9847, Time=847.19s
# --- Analysis for: tcn_model_fine_tune_mb_pool - Twitter ---
# --------------------------------------------------
#
# [Raw Results per Fold]
#    Fold  Accuracy  Precision    Recall  F1-Score   ROC-AUC  Training Time (s)  Dataset
# 0     1  0.954496   0.944238  0.952500  0.948351  0.988707         966.265458  Twitter
# 1     2  0.947368   0.930318  0.951250  0.940667  0.987241        1028.891036  Twitter
# 2     3  0.944627   0.945223  0.927500  0.936278  0.984231        1031.899612  Twitter
# 3     4  0.957237   0.956907  0.944931  0.950882  0.990718         969.659389  Twitter
# 4     5  0.937466   0.918193  0.941176  0.929543  0.984688         847.189808  Twitter
#
# [Summary Statistics]
#                          mean        std
# Accuracy             0.948239   0.007905
# Precision            0.938976   0.014960
# Recall               0.943472   0.010056
# F1-Score             0.941144   0.008736
# ROC-AUC              0.987117   0.002727
# Training Time (s)  968.781060  74.814258
# --------------------------------------------------
#
# [Total Training Time]: 4843.905302286148 seconds
# 51505

# %%
#tcn_model_fine_tune_mb_seqOut
result, history_list = run_cross_validation(FOLDS, X, y, tcn_model_fine_tune_mb_seqOut,True)
variant_name = "tcn_model_fine_tune_mb_seqOut"
result['Variant'] = variant_name
result['Dataset'] = 'Twitter'
all_results.append(result)
analyze_cv_results(result)

for hist in history_list:
    hist['Variant'] = variant_name
    all_histories.extend(history_list)

output_filename = f'/content/drive/MyDrive/final_FYP_results/{folder_name}/{variant_name}_twitter_result.csv'
result.to_csv(output_filename, index=False)
del output_filename
del history_list
del result
gc.collect()
# Out:
# --- Starting Fold 1/5 ---
# Tokenizing training data...
# Tokenizing training data...
# Tokenizing training data...
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'bert.embeddings.position_ids', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertModel were not initialized from the PyTorch model and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Trainable params: 110,685,185
# Non-trainable params: 0
# Model: "model_20"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  attention_mask (InputLayer  [(None, 128)]                0         []
#  )
#
#  input_ids (InputLayer)      [(None, 128)]                0         []
#
#  token_type_ids (InputLayer  [(None, 128)]                0         []
#  )
#
#  tf_bert_model_5 (TFBertMod  TFBaseModelOutputWithPooli   1094822   ['attention_mask[0][0]',
#  el)                         ngAndCrossAttentions(last_   40         'input_ids[0][0]',
#                              hidden_state=(None, 128, 7              'token_type_ids[0][0]']
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  spatial_dropout1d_20 (Spat  (None, 128, 768)             0         ['tf_bert_model_5[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_20 (CuDNNLSTM)   (None, 128, 100)             348000    ['spatial_dropout1d_20[0][0]']
#
#  bidirectional_40 (Bidirect  (None, 128, 256)             595712    ['cu_dnnlstm_20[0][0]']
#  ional)
#
#  bidirectional_41 (Bidirect  (None, 128, 128)             254848    ['bidirectional_40[0][0]']
#  ional)
#
#  cust_attention_15 (CustAtt  (None, 128, 128)             256       ['bidirectional_41[0][0]']
#  ention)
#
#  global_average_pooling1d_2  (None, 128)                  0         ['cust_attention_15[0][0]']
#  0 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_20 (G  (None, 128)                  0         ['cust_attention_15[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_20 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_20[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_20[0][0
#                                                                     ]']
#
#  dense_40 (Dense)            (None, 16)                   4112      ['concatenate_20[0][0]']
#
#  dropout_242 (Dropout)       (None, 16)                   0         ['dense_40[0][0]']
#
#  dense_41 (Dense)            (None, 1)                    17        ['dropout_242[0][0]']
#
# ==================================================================================================
# Total params: 110685185 (422.23 MB)
# Trainable params: 110685185 (422.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 113s 733ms/step - loss: 0.6620 - accuracy: 0.5617 - val_loss: 0.5745 - val_accuracy: 0.5613
# Epoch 2/30
# 92/92 [==============================] - 62s 680ms/step - loss: 0.4952 - accuracy: 0.7236 - val_loss: 0.4295 - val_accuracy: 0.9047
# Epoch 3/30
# 92/92 [==============================] - 62s 679ms/step - loss: 0.3941 - accuracy: 0.9100 - val_loss: 0.3800 - val_accuracy: 0.9260
# Epoch 4/30
# 92/92 [==============================] - 63s 681ms/step - loss: 0.3544 - accuracy: 0.9191 - val_loss: 0.3603 - val_accuracy: 0.9273
# Epoch 5/30
# 92/92 [==============================] - 63s 681ms/step - loss: 0.3055 - accuracy: 0.9349 - val_loss: 0.3328 - val_accuracy: 0.9349
# Epoch 6/30
# 92/92 [==============================] - 63s 681ms/step - loss: 0.2766 - accuracy: 0.9364 - val_loss: 0.3012 - val_accuracy: 0.9301
# Epoch 7/30
# 92/92 [==============================] - 62s 677ms/step - loss: 0.2304 - accuracy: 0.9481 - val_loss: 0.3072 - val_accuracy: 0.9267
# Epoch 8/30
# 92/92 [==============================] - 63s 680ms/step - loss: 0.1800 - accuracy: 0.9529 - val_loss: 0.2154 - val_accuracy: 0.9349
# Epoch 9/30
# 92/92 [==============================] - 63s 680ms/step - loss: 0.1472 - accuracy: 0.9561 - val_loss: 0.1907 - val_accuracy: 0.9404
# Epoch 10/30
# 92/92 [==============================] - 62s 677ms/step - loss: 0.1149 - accuracy: 0.9676 - val_loss: 0.2123 - val_accuracy: 0.9417
# Epoch 11/30
# 92/92 [==============================] - 62s 677ms/step - loss: 0.1050 - accuracy: 0.9709 - val_loss: 0.2368 - val_accuracy: 0.9411
# Epoch 12/30
# 92/92 [==============================] - 62s 677ms/step - loss: 0.0782 - accuracy: 0.9758 - val_loss: 0.2101 - val_accuracy: 0.9459
# Epoch 13/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0778 - accuracy: 0.9772 - val_loss: 0.2027 - val_accuracy: 0.9404
# Epoch 14/30
# 92/92 [==============================] - 62s 677ms/step - loss: 0.0569 - accuracy: 0.9842 - val_loss: 0.2112 - val_accuracy: 0.9438
# Epoch 15/30
# 92/92 [==============================] - 62s 677ms/step - loss: 0.0560 - accuracy: 0.9853 - val_loss: 0.2570 - val_accuracy: 0.9424
# Epoch 16/30
# 92/92 [==============================] - 62s 677ms/step - loss: 0.0363 - accuracy: 0.9911 - val_loss: 0.2267 - val_accuracy: 0.9452
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 29/29 [==============================] - 10s 199ms/step
# Fold 1 Results: Accuracy=0.9485, Precision=0.9424, Recall=0.9400, F1=0.9412, ROC-AUC==0.9868, Time=1050.76s
# --- Starting Fold 2/5 ---
# Tokenizing training data...
# Tokenizing training data...
# Tokenizing training data...
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'bert.embeddings.position_ids', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertModel were not initialized from the PyTorch model and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Trainable params: 110,685,185
# Non-trainable params: 0
# Model: "model_21"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  attention_mask (InputLayer  [(None, 128)]                0         []
#  )
#
#  input_ids (InputLayer)      [(None, 128)]                0         []
#
#  token_type_ids (InputLayer  [(None, 128)]                0         []
#  )
#
#  tf_bert_model_6 (TFBertMod  TFBaseModelOutputWithPooli   1094822   ['attention_mask[0][0]',
#  el)                         ngAndCrossAttentions(last_   40         'input_ids[0][0]',
#                              hidden_state=(None, 128, 7              'token_type_ids[0][0]']
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  spatial_dropout1d_21 (Spat  (None, 128, 768)             0         ['tf_bert_model_6[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_21 (CuDNNLSTM)   (None, 128, 100)             348000    ['spatial_dropout1d_21[0][0]']
#
#  bidirectional_42 (Bidirect  (None, 128, 256)             595712    ['cu_dnnlstm_21[0][0]']
#  ional)
#
#  bidirectional_43 (Bidirect  (None, 128, 128)             254848    ['bidirectional_42[0][0]']
#  ional)
#
#  cust_attention_16 (CustAtt  (None, 128, 128)             256       ['bidirectional_43[0][0]']
#  ention)
#
#  global_average_pooling1d_2  (None, 128)                  0         ['cust_attention_16[0][0]']
#  1 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_21 (G  (None, 128)                  0         ['cust_attention_16[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_21 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_21[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_21[0][0
#                                                                     ]']
#
#  dense_42 (Dense)            (None, 16)                   4112      ['concatenate_21[0][0]']
#
#  dropout_280 (Dropout)       (None, 16)                   0         ['dense_42[0][0]']
#
#  dense_43 (Dense)            (None, 1)                    17        ['dropout_280[0][0]']
#
# ==================================================================================================
# Total params: 110685185 (422.23 MB)
# Trainable params: 110685185 (422.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 116s 736ms/step - loss: 0.6315 - accuracy: 0.7221 - val_loss: 0.6032 - val_accuracy: 0.8115
# Epoch 2/30
# 92/92 [==============================] - 63s 680ms/step - loss: 0.4505 - accuracy: 0.8698 - val_loss: 0.5366 - val_accuracy: 0.8917
# Epoch 3/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.3773 - accuracy: 0.8953 - val_loss: 0.2615 - val_accuracy: 0.9095
# Epoch 4/30
# 92/92 [==============================] - 63s 681ms/step - loss: 0.2582 - accuracy: 0.9083 - val_loss: 0.1894 - val_accuracy: 0.9342
# Epoch 5/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.2168 - accuracy: 0.9205 - val_loss: 0.1729 - val_accuracy: 0.9376
# Epoch 6/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.1736 - accuracy: 0.9405 - val_loss: 0.1730 - val_accuracy: 0.9308
# Epoch 7/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.1596 - accuracy: 0.9467 - val_loss: 0.1469 - val_accuracy: 0.9438
# Epoch 8/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.1251 - accuracy: 0.9589 - val_loss: 0.1717 - val_accuracy: 0.9287
# Epoch 9/30
# 92/92 [==============================] - 62s 679ms/step - loss: 0.1075 - accuracy: 0.9626 - val_loss: 0.1673 - val_accuracy: 0.9363
# Epoch 10/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.1106 - accuracy: 0.9647 - val_loss: 0.1268 - val_accuracy: 0.9541
# Epoch 11/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0837 - accuracy: 0.9734 - val_loss: 0.1341 - val_accuracy: 0.9534
# Epoch 12/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0631 - accuracy: 0.9827 - val_loss: 0.1504 - val_accuracy: 0.9438
# Epoch 13/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0551 - accuracy: 0.9836 - val_loss: 0.1690 - val_accuracy: 0.9452
# Epoch 14/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0960 - accuracy: 0.9745 - val_loss: 0.1411 - val_accuracy: 0.9486
# Epoch 15/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0362 - accuracy: 0.9901 - val_loss: 0.1529 - val_accuracy: 0.9534
# Epoch 16/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0334 - accuracy: 0.9890 - val_loss: 0.1559 - val_accuracy: 0.9520
# Epoch 17/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0280 - accuracy: 0.9921 - val_loss: 0.1663 - val_accuracy: 0.9486
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 29/29 [==============================] - 10s 201ms/step
# Fold 2 Results: Accuracy=0.9512, Precision=0.9506, Recall=0.9375, F1=0.9440, ROC-AUC==0.9877, Time=1116.43s
# --- Starting Fold 3/5 ---
# Tokenizing training data...
# Tokenizing training data...
# Tokenizing training data...
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'bert.embeddings.position_ids', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertModel were not initialized from the PyTorch model and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Trainable params: 110,685,185
# Non-trainable params: 0
# Model: "model_22"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  attention_mask (InputLayer  [(None, 128)]                0         []
#  )
#
#  input_ids (InputLayer)      [(None, 128)]                0         []
#
#  token_type_ids (InputLayer  [(None, 128)]                0         []
#  )
#
#  tf_bert_model_7 (TFBertMod  TFBaseModelOutputWithPooli   1094822   ['attention_mask[0][0]',
#  el)                         ngAndCrossAttentions(last_   40         'input_ids[0][0]',
#                              hidden_state=(None, 128, 7              'token_type_ids[0][0]']
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  spatial_dropout1d_22 (Spat  (None, 128, 768)             0         ['tf_bert_model_7[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_22 (CuDNNLSTM)   (None, 128, 100)             348000    ['spatial_dropout1d_22[0][0]']
#
#  bidirectional_44 (Bidirect  (None, 128, 256)             595712    ['cu_dnnlstm_22[0][0]']
#  ional)
#
#  bidirectional_45 (Bidirect  (None, 128, 128)             254848    ['bidirectional_44[0][0]']
#  ional)
#
#  cust_attention_17 (CustAtt  (None, 128, 128)             256       ['bidirectional_45[0][0]']
#  ention)
#
#  global_average_pooling1d_2  (None, 128)                  0         ['cust_attention_17[0][0]']
#  2 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_22 (G  (None, 128)                  0         ['cust_attention_17[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_22 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_22[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_22[0][0
#                                                                     ]']
#
#  dense_44 (Dense)            (None, 16)                   4112      ['concatenate_22[0][0]']
#
#  dropout_318 (Dropout)       (None, 16)                   0         ['dense_44[0][0]']
#
#  dense_45 (Dense)            (None, 1)                    17        ['dropout_318[0][0]']
#
# ==================================================================================================
# Total params: 110685185 (422.23 MB)
# Trainable params: 110685185 (422.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 116s 739ms/step - loss: 0.6128 - accuracy: 0.6337 - val_loss: 0.5283 - val_accuracy: 0.8513
# Epoch 2/30
# 92/92 [==============================] - 63s 681ms/step - loss: 0.4650 - accuracy: 0.8662 - val_loss: 0.3714 - val_accuracy: 0.8369
# Epoch 3/30
# 92/92 [==============================] - 63s 681ms/step - loss: 0.3260 - accuracy: 0.8770 - val_loss: 0.2495 - val_accuracy: 0.9088
# Epoch 4/30
# 92/92 [==============================] - 63s 681ms/step - loss: 0.2189 - accuracy: 0.9261 - val_loss: 0.1667 - val_accuracy: 0.9335
# Epoch 5/30
# 92/92 [==============================] - 63s 681ms/step - loss: 0.1780 - accuracy: 0.9363 - val_loss: 0.1539 - val_accuracy: 0.9376
# Epoch 6/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.1651 - accuracy: 0.9443 - val_loss: 0.2184 - val_accuracy: 0.8938
# Epoch 7/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.1341 - accuracy: 0.9529 - val_loss: 0.1476 - val_accuracy: 0.9479
# Epoch 8/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.1106 - accuracy: 0.9637 - val_loss: 0.1519 - val_accuracy: 0.9445
# Epoch 9/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.1039 - accuracy: 0.9654 - val_loss: 0.2062 - val_accuracy: 0.9335
# Epoch 10/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0878 - accuracy: 0.9728 - val_loss: 0.1743 - val_accuracy: 0.9445
# Epoch 11/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0833 - accuracy: 0.9724 - val_loss: 0.1480 - val_accuracy: 0.9465
# Epoch 12/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0663 - accuracy: 0.9798 - val_loss: 0.1527 - val_accuracy: 0.9479
# Epoch 13/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0599 - accuracy: 0.9812 - val_loss: 0.1718 - val_accuracy: 0.9507
# Epoch 14/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0452 - accuracy: 0.9866 - val_loss: 0.1870 - val_accuracy: 0.9493
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 7.
# 29/29 [==============================] - 10s 200ms/step
# Fold 3 Results: Accuracy=0.9337, Precision=0.9260, Recall=0.9225, F1=0.9242, ROC-AUC==0.9839, Time=928.89s
# --- Starting Fold 4/5 ---
# Tokenizing training data...
# Tokenizing training data...
# Tokenizing training data...
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'bert.embeddings.position_ids', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertModel were not initialized from the PyTorch model and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Trainable params: 110,685,185
# Non-trainable params: 0
# Model: "model_23"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  attention_mask (InputLayer  [(None, 128)]                0         []
#  )
#
#  input_ids (InputLayer)      [(None, 128)]                0         []
#
#  token_type_ids (InputLayer  [(None, 128)]                0         []
#  )
#
#  tf_bert_model_8 (TFBertMod  TFBaseModelOutputWithPooli   1094822   ['attention_mask[0][0]',
#  el)                         ngAndCrossAttentions(last_   40         'input_ids[0][0]',
#                              hidden_state=(None, 128, 7              'token_type_ids[0][0]']
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  spatial_dropout1d_23 (Spat  (None, 128, 768)             0         ['tf_bert_model_8[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_23 (CuDNNLSTM)   (None, 128, 100)             348000    ['spatial_dropout1d_23[0][0]']
#
#  bidirectional_46 (Bidirect  (None, 128, 256)             595712    ['cu_dnnlstm_23[0][0]']
#  ional)
#
#  bidirectional_47 (Bidirect  (None, 128, 128)             254848    ['bidirectional_46[0][0]']
#  ional)
#
#  cust_attention_18 (CustAtt  (None, 128, 128)             256       ['bidirectional_47[0][0]']
#  ention)
#
#  global_average_pooling1d_2  (None, 128)                  0         ['cust_attention_18[0][0]']
#  3 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_23 (G  (None, 128)                  0         ['cust_attention_18[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_23 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_23[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_23[0][0
#                                                                     ]']
#
#  dense_46 (Dense)            (None, 16)                   4112      ['concatenate_23[0][0]']
#
#  dropout_356 (Dropout)       (None, 16)                   0         ['dense_46[0][0]']
#
#  dense_47 (Dense)            (None, 1)                    17        ['dropout_356[0][0]']
#
# ==================================================================================================
# Total params: 110685185 (422.23 MB)
# Trainable params: 110685185 (422.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 116s 739ms/step - loss: 0.6858 - accuracy: 0.5617 - val_loss: 0.6770 - val_accuracy: 0.5613
# Epoch 2/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.6162 - accuracy: 0.5620 - val_loss: 0.5845 - val_accuracy: 0.5785
# Epoch 3/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.4941 - accuracy: 0.8203 - val_loss: 0.6857 - val_accuracy: 0.4901
# Epoch 4/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.4107 - accuracy: 0.8914 - val_loss: 0.5540 - val_accuracy: 0.7073
# Epoch 5/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.3431 - accuracy: 0.9203 - val_loss: 0.3335 - val_accuracy: 0.8999
# Epoch 6/30
# 92/92 [==============================] - 63s 683ms/step - loss: 0.2617 - accuracy: 0.9251 - val_loss: 0.2547 - val_accuracy: 0.9013
# Epoch 7/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.1764 - accuracy: 0.9400 - val_loss: 0.2364 - val_accuracy: 0.9054
# Epoch 8/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.1526 - accuracy: 0.9467 - val_loss: 0.2073 - val_accuracy: 0.9150
# Epoch 9/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.1125 - accuracy: 0.9611 - val_loss: 0.2070 - val_accuracy: 0.9308
# Epoch 10/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.0941 - accuracy: 0.9681 - val_loss: 0.2033 - val_accuracy: 0.9232
# Epoch 11/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.0817 - accuracy: 0.9729 - val_loss: 0.1969 - val_accuracy: 0.9253
# Epoch 12/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0709 - accuracy: 0.9782 - val_loss: 0.2520 - val_accuracy: 0.9308
# Epoch 13/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0471 - accuracy: 0.9858 - val_loss: 0.2362 - val_accuracy: 0.9280
# Epoch 14/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.1507 - accuracy: 0.9548 - val_loss: 0.2143 - val_accuracy: 0.9191
# Epoch 15/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0621 - accuracy: 0.9832 - val_loss: 0.2341 - val_accuracy: 0.9349
# Epoch 16/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0422 - accuracy: 0.9901 - val_loss: 0.2172 - val_accuracy: 0.9417
# Epoch 17/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0261 - accuracy: 0.9937 - val_loss: 0.2987 - val_accuracy: 0.9328
# Epoch 18/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0243 - accuracy: 0.9931 - val_loss: 0.2749 - val_accuracy: 0.9369
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 11.
# 29/29 [==============================] - 10s 203ms/step
# Fold 4 Results: Accuracy=0.9479, Precision=0.9314, Recall=0.9512, F1=0.9412, ROC-AUC==0.9902, Time=1180.86s
# --- Starting Fold 5/5 ---
# Tokenizing training data...
# Tokenizing training data...
# Tokenizing training data...
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'bert.embeddings.position_ids', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertModel were not initialized from the PyTorch model and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Trainable params: 110,685,185
# Non-trainable params: 0
# Model: "model_24"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  attention_mask (InputLayer  [(None, 128)]                0         []
#  )
#
#  input_ids (InputLayer)      [(None, 128)]                0         []
#
#  token_type_ids (InputLayer  [(None, 128)]                0         []
#  )
#
#  tf_bert_model_9 (TFBertMod  TFBaseModelOutputWithPooli   1094822   ['attention_mask[0][0]',
#  el)                         ngAndCrossAttentions(last_   40         'input_ids[0][0]',
#                              hidden_state=(None, 128, 7              'token_type_ids[0][0]']
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  spatial_dropout1d_24 (Spat  (None, 128, 768)             0         ['tf_bert_model_9[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_24 (CuDNNLSTM)   (None, 128, 100)             348000    ['spatial_dropout1d_24[0][0]']
#
#  bidirectional_48 (Bidirect  (None, 128, 256)             595712    ['cu_dnnlstm_24[0][0]']
#  ional)
#
#  bidirectional_49 (Bidirect  (None, 128, 128)             254848    ['bidirectional_48[0][0]']
#  ional)
#
#  cust_attention_19 (CustAtt  (None, 128, 128)             256       ['bidirectional_49[0][0]']
#  ention)
#
#  global_average_pooling1d_2  (None, 128)                  0         ['cust_attention_19[0][0]']
#  4 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_24 (G  (None, 128)                  0         ['cust_attention_19[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_24 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_24[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_24[0][0
#                                                                     ]']
#
#  dense_48 (Dense)            (None, 16)                   4112      ['concatenate_24[0][0]']
#
#  dropout_394 (Dropout)       (None, 16)                   0         ['dense_48[0][0]']
#
#  dense_49 (Dense)            (None, 1)                    17        ['dropout_394[0][0]']
#
# ==================================================================================================
# Total params: 110685185 (422.23 MB)
# Trainable params: 110685185 (422.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 116s 740ms/step - loss: 0.6870 - accuracy: 0.5615 - val_loss: 0.6807 - val_accuracy: 0.5616
# Epoch 2/30
# 92/92 [==============================] - 63s 684ms/step - loss: 0.6558 - accuracy: 0.5615 - val_loss: 0.6253 - val_accuracy: 0.5616
# Epoch 3/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.5275 - accuracy: 0.6253 - val_loss: 0.4303 - val_accuracy: 0.9253
# Epoch 4/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.4218 - accuracy: 0.8982 - val_loss: 0.3591 - val_accuracy: 0.9267
# Epoch 5/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.3713 - accuracy: 0.9059 - val_loss: 0.3163 - val_accuracy: 0.9253
# Epoch 6/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.3150 - accuracy: 0.9135 - val_loss: 0.2511 - val_accuracy: 0.9370
# Epoch 7/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.2556 - accuracy: 0.9210 - val_loss: 0.1923 - val_accuracy: 0.9390
# Epoch 8/30
# 92/92 [==============================] - 63s 682ms/step - loss: 0.1784 - accuracy: 0.9462 - val_loss: 0.1904 - val_accuracy: 0.9363
# Epoch 9/30
# 92/92 [==============================] - 62s 679ms/step - loss: 0.1589 - accuracy: 0.9500 - val_loss: 0.2342 - val_accuracy: 0.9178
# Epoch 10/30
# 92/92 [==============================] - 62s 679ms/step - loss: 0.1168 - accuracy: 0.9628 - val_loss: 0.2036 - val_accuracy: 0.9301
# Epoch 11/30
# 92/92 [==============================] - 62s 679ms/step - loss: 0.1084 - accuracy: 0.9644 - val_loss: 0.2017 - val_accuracy: 0.9342
# Epoch 12/30
# 92/92 [==============================] - 62s 679ms/step - loss: 0.1143 - accuracy: 0.9632 - val_loss: 0.2304 - val_accuracy: 0.9240
# Epoch 13/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0817 - accuracy: 0.9736 - val_loss: 0.1975 - val_accuracy: 0.9390
# Epoch 14/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0607 - accuracy: 0.9824 - val_loss: 0.1973 - val_accuracy: 0.9411
# Epoch 15/30
# 92/92 [==============================] - 63s 683ms/step - loss: 0.0551 - accuracy: 0.9847 - val_loss: 0.1826 - val_accuracy: 0.9466
# Epoch 16/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0652 - accuracy: 0.9815 - val_loss: 0.1886 - val_accuracy: 0.9459
# Epoch 17/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0354 - accuracy: 0.9892 - val_loss: 0.2213 - val_accuracy: 0.9397
# Epoch 18/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0308 - accuracy: 0.9919 - val_loss: 0.2505 - val_accuracy: 0.9329
# Epoch 19/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0615 - accuracy: 0.9849 - val_loss: 0.2118 - val_accuracy: 0.9377
# Epoch 20/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0195 - accuracy: 0.9954 - val_loss: 0.2320 - val_accuracy: 0.9486
# Epoch 21/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0211 - accuracy: 0.9952 - val_loss: 0.2589 - val_accuracy: 0.9397
# Epoch 22/30
# 92/92 [==============================] - 62s 678ms/step - loss: 0.0435 - accuracy: 0.9899 - val_loss: 0.2008 - val_accuracy: 0.9548
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 15.
# 29/29 [==============================] - 10s 202ms/step
# Fold 5 Results: Accuracy=0.9364, Precision=0.9041, Recall=0.9562, F1=0.9294, ROC-AUC==0.9857, Time=1430.93s
# --- Analysis for: tcn_model_fine_tune_mb_seqOut - Twitter ---
# --------------------------------------------------
#
# [Raw Results per Fold]
#    Fold  Accuracy  Precision    Recall  F1-Score   ROC-AUC  Training Time (s)  Dataset
# 0     1  0.948465   0.942356  0.940000  0.941176  0.986821        1050.760271  Twitter
# 1     2  0.951206   0.950570  0.937500  0.943990  0.987743        1116.426562  Twitter
# 2     3  0.933662   0.925972  0.922500  0.924233  0.983925         928.887438  Twitter
# 3     4  0.947917   0.931373  0.951189  0.941176  0.990194        1180.864969  Twitter
# 4     5  0.936369   0.904142  0.956195  0.929440  0.985686        1430.932087  Twitter
#
# [Summary Statistics]
#                           mean         std
# Accuracy              0.943524    0.007924
# Precision             0.930883    0.017739
# Recall                0.941477    0.013125
# F1-Score              0.936003    0.008645
# ROC-AUC               0.986874    0.002339
# Training Time (s)  1141.574265  186.672831
# --------------------------------------------------
#
# [Total Training Time]: 5707.871326446533 seconds
# 51080

# %%
#tcn_model_sb_precompute_pool
print("Loading TF-Hub models...")
preprocessor = hub.KerasLayer(tfhub_handle_preprocess)
encoder = hub.KerasLayer(tfhub_handle_encoder, trainable=False)
print("Models loaded.")
X_embeddings = extract_feature_bert_pooled(preprocessor=preprocessor, encoder=encoder, texts=X)

result, history_list = run_cross_validation(FOLDS, X_embeddings, y, tcn_model_sb_precompute_pool,False)
variant_name = "tcn_model_sb_precompute_pool"
result['Variant'] = variant_name
result['Dataset'] = 'Twitter'
all_results.append(result)
analyze_cv_results(result)

for hist in history_list:
    hist['Variant'] = variant_name
    all_histories.extend(history_list)

output_filename = f'/content/drive/MyDrive/final_FYP_results/{folder_name}/{variant_name}_twitter_result.csv'
result.to_csv(output_filename, index=False)
del output_filename
del history_list
del result
gc.collect()
# Out:
# Loading TF-Hub models...
# Models loaded.
#
#  Starting BERT feature extraction...
# Done
# --- Starting Fold 1/5 ---
# Model: "model_25"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 512)]                0         []
#  r)
#
#  tf.expand_dims_15 (TFOpLam  (None, 1, 512)               0         ['embedding_input[0][0]']
#  bda)
#
#  spatial_dropout1d_25 (Spat  (None, 1, 512)               0         ['tf.expand_dims_15[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_25 (CuDNNLSTM)   (None, 1, 100)               245600    ['spatial_dropout1d_25[0][0]']
#
#  bidirectional_50 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_25[0][0]']
#  ional)
#
#  bidirectional_51 (Bidirect  (None, 1, 128)               254848    ['bidirectional_50[0][0]']
#  ional)
#
#  cust_attention_20 (CustAtt  (None, 1, 128)               129       ['bidirectional_51[0][0]']
#  ention)
#
#  global_average_pooling1d_2  (None, 128)                  0         ['cust_attention_20[0][0]']
#  5 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_25 (G  (None, 128)                  0         ['cust_attention_20[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_25 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_25[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_25[0][0
#                                                                     ]']
#
#  dense_50 (Dense)            (None, 16)                   4112      ['concatenate_25[0][0]']
#
#  dropout_395 (Dropout)       (None, 16)                   0         ['dense_50[0][0]']
#
#  dense_51 (Dense)            (None, 1)                    17        ['dropout_395[0][0]']
#
# ==================================================================================================
# Total params: 1100418 (4.20 MB)
# Trainable params: 1100418 (4.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 13s 29ms/step - loss: 0.6701 - accuracy: 0.5620 - val_loss: 0.6428 - val_accuracy: 0.5613
# Epoch 2/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.6000 - accuracy: 0.6719 - val_loss: 0.5345 - val_accuracy: 0.8286
# Epoch 3/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.4688 - accuracy: 0.8396 - val_loss: 0.4339 - val_accuracy: 0.8259
# Epoch 4/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.3784 - accuracy: 0.8542 - val_loss: 0.3827 - val_accuracy: 0.8300
# Epoch 5/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.3444 - accuracy: 0.8636 - val_loss: 0.3546 - val_accuracy: 0.8520
# Epoch 6/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.3298 - accuracy: 0.8703 - val_loss: 0.3446 - val_accuracy: 0.8561
# Epoch 7/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.3165 - accuracy: 0.8746 - val_loss: 0.3289 - val_accuracy: 0.8622
# Epoch 8/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.3077 - accuracy: 0.8783 - val_loss: 0.3185 - val_accuracy: 0.8643
# Epoch 9/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.3026 - accuracy: 0.8746 - val_loss: 0.3098 - val_accuracy: 0.8711
# Epoch 10/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2954 - accuracy: 0.8835 - val_loss: 0.3015 - val_accuracy: 0.8718
# Epoch 11/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2884 - accuracy: 0.8807 - val_loss: 0.3372 - val_accuracy: 0.8629
# Epoch 12/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2861 - accuracy: 0.8855 - val_loss: 0.2910 - val_accuracy: 0.8739
# Epoch 13/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2796 - accuracy: 0.8876 - val_loss: 0.2872 - val_accuracy: 0.8746
# Epoch 14/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2754 - accuracy: 0.8874 - val_loss: 0.3119 - val_accuracy: 0.8698
# Epoch 15/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2720 - accuracy: 0.8881 - val_loss: 0.2934 - val_accuracy: 0.8766
# Epoch 16/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2684 - accuracy: 0.8897 - val_loss: 0.2772 - val_accuracy: 0.8801
# Epoch 17/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2720 - accuracy: 0.8879 - val_loss: 0.2872 - val_accuracy: 0.8759
# Epoch 18/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2660 - accuracy: 0.8900 - val_loss: 0.2715 - val_accuracy: 0.8842
# Epoch 19/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2598 - accuracy: 0.8922 - val_loss: 0.2680 - val_accuracy: 0.8835
# Epoch 20/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2585 - accuracy: 0.8924 - val_loss: 0.2887 - val_accuracy: 0.8773
# Epoch 21/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2562 - accuracy: 0.8950 - val_loss: 0.2770 - val_accuracy: 0.8821
# Epoch 22/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2547 - accuracy: 0.8960 - val_loss: 0.2660 - val_accuracy: 0.8842
# Epoch 23/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2494 - accuracy: 0.8958 - val_loss: 0.2613 - val_accuracy: 0.8821
# Epoch 24/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2497 - accuracy: 0.9008 - val_loss: 0.2739 - val_accuracy: 0.8801
# Epoch 25/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2444 - accuracy: 0.8986 - val_loss: 0.2590 - val_accuracy: 0.8883
# Epoch 26/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2455 - accuracy: 0.8986 - val_loss: 0.2590 - val_accuracy: 0.8862
# Epoch 27/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2490 - accuracy: 0.9013 - val_loss: 0.2575 - val_accuracy: 0.8897
# Epoch 28/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2449 - accuracy: 0.9013 - val_loss: 0.2526 - val_accuracy: 0.8903
# Epoch 29/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2450 - accuracy: 0.8998 - val_loss: 0.2636 - val_accuracy: 0.8855
# Epoch 30/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2382 - accuracy: 0.9001 - val_loss: 0.3108 - val_accuracy: 0.8677
# Restoring model weights from the end of the best epoch: 28.
# 29/29 [==============================] - 1s 5ms/step
# Fold 1 Results: Accuracy=0.8975, Precision=0.9081, Recall=0.8525, F1=0.8794, ROC-AUC==0.9661, Time=64.19s
# --- Starting Fold 2/5 ---
# Model: "model_26"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 512)]                0         []
#  r)
#
#  tf.expand_dims_16 (TFOpLam  (None, 1, 512)               0         ['embedding_input[0][0]']
#  bda)
#
#  spatial_dropout1d_26 (Spat  (None, 1, 512)               0         ['tf.expand_dims_16[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_26 (CuDNNLSTM)   (None, 1, 100)               245600    ['spatial_dropout1d_26[0][0]']
#
#  bidirectional_52 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_26[0][0]']
#  ional)
#
#  bidirectional_53 (Bidirect  (None, 1, 128)               254848    ['bidirectional_52[0][0]']
#  ional)
#
#  cust_attention_21 (CustAtt  (None, 1, 128)               129       ['bidirectional_53[0][0]']
#  ention)
#
#  global_average_pooling1d_2  (None, 128)                  0         ['cust_attention_21[0][0]']
#  6 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_26 (G  (None, 128)                  0         ['cust_attention_21[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_26 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_26[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_26[0][0
#                                                                     ]']
#
#  dense_52 (Dense)            (None, 16)                   4112      ['concatenate_26[0][0]']
#
#  dropout_396 (Dropout)       (None, 16)                   0         ['dense_52[0][0]']
#
#  dense_53 (Dense)            (None, 1)                    17        ['dropout_396[0][0]']
#
# ==================================================================================================
# Total params: 1100418 (4.20 MB)
# Trainable params: 1100418 (4.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 12s 29ms/step - loss: 0.6788 - accuracy: 0.5529 - val_loss: 0.6587 - val_accuracy: 0.5970
# Epoch 2/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.6326 - accuracy: 0.6941 - val_loss: 0.5725 - val_accuracy: 0.8259
# Epoch 3/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.5099 - accuracy: 0.8252 - val_loss: 0.4167 - val_accuracy: 0.8355
# Epoch 4/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.3960 - accuracy: 0.8449 - val_loss: 0.3550 - val_accuracy: 0.8533
# Epoch 5/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.3553 - accuracy: 0.8590 - val_loss: 0.3263 - val_accuracy: 0.8698
# Epoch 6/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.3341 - accuracy: 0.8682 - val_loss: 0.3060 - val_accuracy: 0.8705
# Epoch 7/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.3182 - accuracy: 0.8734 - val_loss: 0.2891 - val_accuracy: 0.8780
# Epoch 8/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.3004 - accuracy: 0.8801 - val_loss: 0.2793 - val_accuracy: 0.8821
# Epoch 9/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2968 - accuracy: 0.8801 - val_loss: 0.2728 - val_accuracy: 0.8801
# Epoch 10/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2908 - accuracy: 0.8782 - val_loss: 0.2657 - val_accuracy: 0.8835
# Epoch 11/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2867 - accuracy: 0.8804 - val_loss: 0.2603 - val_accuracy: 0.8842
# Epoch 12/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2750 - accuracy: 0.8837 - val_loss: 0.2534 - val_accuracy: 0.8903
# Epoch 13/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2736 - accuracy: 0.8888 - val_loss: 0.2571 - val_accuracy: 0.8883
# Epoch 14/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2692 - accuracy: 0.8852 - val_loss: 0.2497 - val_accuracy: 0.8876
# Epoch 15/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2659 - accuracy: 0.8876 - val_loss: 0.2441 - val_accuracy: 0.8910
# Epoch 16/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2624 - accuracy: 0.8873 - val_loss: 0.2396 - val_accuracy: 0.8924
# Epoch 17/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2608 - accuracy: 0.8917 - val_loss: 0.2398 - val_accuracy: 0.8944
# Epoch 18/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2594 - accuracy: 0.8862 - val_loss: 0.2367 - val_accuracy: 0.8924
# Epoch 19/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2559 - accuracy: 0.8867 - val_loss: 0.2381 - val_accuracy: 0.8958
# Epoch 20/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2524 - accuracy: 0.8917 - val_loss: 0.2319 - val_accuracy: 0.8924
# Epoch 21/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2501 - accuracy: 0.8922 - val_loss: 0.2321 - val_accuracy: 0.8986
# Epoch 22/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2464 - accuracy: 0.8951 - val_loss: 0.2294 - val_accuracy: 0.8986
# Epoch 23/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2491 - accuracy: 0.8950 - val_loss: 0.2268 - val_accuracy: 0.8958
# Epoch 24/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2461 - accuracy: 0.8979 - val_loss: 0.2252 - val_accuracy: 0.8992
# Epoch 25/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2433 - accuracy: 0.8962 - val_loss: 0.2235 - val_accuracy: 0.8999
# Epoch 26/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2410 - accuracy: 0.8962 - val_loss: 0.2249 - val_accuracy: 0.9006
# Epoch 27/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2412 - accuracy: 0.8968 - val_loss: 0.2211 - val_accuracy: 0.9054
# Epoch 28/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2374 - accuracy: 0.8965 - val_loss: 0.2224 - val_accuracy: 0.9027
# Epoch 29/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2386 - accuracy: 0.8998 - val_loss: 0.2214 - val_accuracy: 0.9082
# Epoch 30/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2318 - accuracy: 0.9018 - val_loss: 0.2201 - val_accuracy: 0.9088
# Restoring model weights from the end of the best epoch: 30.
# 29/29 [==============================] - 1s 4ms/step
# Fold 2 Results: Accuracy=0.8997, Precision=0.9075, Recall=0.8588, F1=0.8825, ROC-AUC==0.9572, Time=63.84s
# --- Starting Fold 3/5 ---
# Model: "model_27"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 512)]                0         []
#  r)
#
#  tf.expand_dims_17 (TFOpLam  (None, 1, 512)               0         ['embedding_input[0][0]']
#  bda)
#
#  spatial_dropout1d_27 (Spat  (None, 1, 512)               0         ['tf.expand_dims_17[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_27 (CuDNNLSTM)   (None, 1, 100)               245600    ['spatial_dropout1d_27[0][0]']
#
#  bidirectional_54 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_27[0][0]']
#  ional)
#
#  bidirectional_55 (Bidirect  (None, 1, 128)               254848    ['bidirectional_54[0][0]']
#  ional)
#
#  cust_attention_22 (CustAtt  (None, 1, 128)               129       ['bidirectional_55[0][0]']
#  ention)
#
#  global_average_pooling1d_2  (None, 128)                  0         ['cust_attention_22[0][0]']
#  7 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_27 (G  (None, 128)                  0         ['cust_attention_22[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_27 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_27[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_27[0][0
#                                                                     ]']
#
#  dense_54 (Dense)            (None, 16)                   4112      ['concatenate_27[0][0]']
#
#  dropout_397 (Dropout)       (None, 16)                   0         ['dense_54[0][0]']
#
#  dense_55 (Dense)            (None, 1)                    17        ['dropout_397[0][0]']
#
# ==================================================================================================
# Total params: 1100418 (4.20 MB)
# Trainable params: 1100418 (4.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 13s 29ms/step - loss: 0.6478 - accuracy: 0.6679 - val_loss: 0.5847 - val_accuracy: 0.8225
# Epoch 2/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.5037 - accuracy: 0.8401 - val_loss: 0.4339 - val_accuracy: 0.8300
# Epoch 3/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.3938 - accuracy: 0.8463 - val_loss: 0.3833 - val_accuracy: 0.8369
# Epoch 4/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.3473 - accuracy: 0.8586 - val_loss: 0.3474 - val_accuracy: 0.8465
# Epoch 5/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.3245 - accuracy: 0.8662 - val_loss: 0.3323 - val_accuracy: 0.8506
# Epoch 6/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.3072 - accuracy: 0.8711 - val_loss: 0.3343 - val_accuracy: 0.8663
# Epoch 7/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2977 - accuracy: 0.8775 - val_loss: 0.3047 - val_accuracy: 0.8835
# Epoch 8/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2831 - accuracy: 0.8828 - val_loss: 0.3036 - val_accuracy: 0.8766
# Epoch 9/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2809 - accuracy: 0.8830 - val_loss: 0.3223 - val_accuracy: 0.8677
# Epoch 10/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2725 - accuracy: 0.8864 - val_loss: 0.2881 - val_accuracy: 0.8794
# Epoch 11/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2697 - accuracy: 0.8891 - val_loss: 0.2719 - val_accuracy: 0.8924
# Epoch 12/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2676 - accuracy: 0.8886 - val_loss: 0.2622 - val_accuracy: 0.8938
# Epoch 13/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2589 - accuracy: 0.8898 - val_loss: 0.2830 - val_accuracy: 0.8801
# Epoch 14/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2592 - accuracy: 0.8922 - val_loss: 0.2956 - val_accuracy: 0.8753
# Epoch 15/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2553 - accuracy: 0.8931 - val_loss: 0.3086 - val_accuracy: 0.8732
# Epoch 16/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2495 - accuracy: 0.8955 - val_loss: 0.2879 - val_accuracy: 0.8766
# Epoch 17/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2490 - accuracy: 0.8939 - val_loss: 0.2505 - val_accuracy: 0.8972
# Epoch 18/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2498 - accuracy: 0.8970 - val_loss: 0.3026 - val_accuracy: 0.8698
# Epoch 19/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2468 - accuracy: 0.8974 - val_loss: 0.2472 - val_accuracy: 0.8979
# Epoch 20/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2431 - accuracy: 0.8944 - val_loss: 0.2403 - val_accuracy: 0.8992
# Epoch 21/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2413 - accuracy: 0.8977 - val_loss: 0.2418 - val_accuracy: 0.8972
# Epoch 22/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2329 - accuracy: 0.9047 - val_loss: 0.2425 - val_accuracy: 0.8965
# Epoch 23/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2328 - accuracy: 0.9042 - val_loss: 0.3167 - val_accuracy: 0.8568
# Epoch 24/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2355 - accuracy: 0.9022 - val_loss: 0.2547 - val_accuracy: 0.8958
# Epoch 25/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2364 - accuracy: 0.9018 - val_loss: 0.2413 - val_accuracy: 0.8972
# Epoch 26/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2299 - accuracy: 0.9058 - val_loss: 0.2380 - val_accuracy: 0.9020
# Epoch 27/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2316 - accuracy: 0.9011 - val_loss: 0.2611 - val_accuracy: 0.8883
# Epoch 28/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2251 - accuracy: 0.9056 - val_loss: 0.2581 - val_accuracy: 0.8897
# Epoch 29/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2266 - accuracy: 0.9052 - val_loss: 0.2364 - val_accuracy: 0.9013
# Epoch 30/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2253 - accuracy: 0.9073 - val_loss: 0.3314 - val_accuracy: 0.8485
# Restoring model weights from the end of the best epoch: 29.
# 29/29 [==============================] - 1s 5ms/step
# Fold 3 Results: Accuracy=0.8975, Precision=0.8885, Recall=0.8762, F1=0.8823, ROC-AUC==0.9609, Time=66.15s
# --- Starting Fold 4/5 ---
# Model: "model_28"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 512)]                0         []
#  r)
#
#  tf.expand_dims_18 (TFOpLam  (None, 1, 512)               0         ['embedding_input[0][0]']
#  bda)
#
#  spatial_dropout1d_28 (Spat  (None, 1, 512)               0         ['tf.expand_dims_18[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_28 (CuDNNLSTM)   (None, 1, 100)               245600    ['spatial_dropout1d_28[0][0]']
#
#  bidirectional_56 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_28[0][0]']
#  ional)
#
#  bidirectional_57 (Bidirect  (None, 1, 128)               254848    ['bidirectional_56[0][0]']
#  ional)
#
#  cust_attention_23 (CustAtt  (None, 1, 128)               129       ['bidirectional_57[0][0]']
#  ention)
#
#  global_average_pooling1d_2  (None, 128)                  0         ['cust_attention_23[0][0]']
#  8 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_28 (G  (None, 128)                  0         ['cust_attention_23[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_28 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_28[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_28[0][0
#                                                                     ]']
#
#  dense_56 (Dense)            (None, 16)                   4112      ['concatenate_28[0][0]']
#
#  dropout_398 (Dropout)       (None, 16)                   0         ['dense_56[0][0]']
#
#  dense_57 (Dense)            (None, 1)                    17        ['dropout_398[0][0]']
#
# ==================================================================================================
# Total params: 1100418 (4.20 MB)
# Trainable params: 1100418 (4.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 13s 30ms/step - loss: 0.6637 - accuracy: 0.5677 - val_loss: 0.6257 - val_accuracy: 0.7005
# Epoch 2/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.5752 - accuracy: 0.7498 - val_loss: 0.5137 - val_accuracy: 0.8273
# Epoch 3/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.4657 - accuracy: 0.8388 - val_loss: 0.4313 - val_accuracy: 0.8273
# Epoch 4/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.3944 - accuracy: 0.8480 - val_loss: 0.3758 - val_accuracy: 0.8382
# Epoch 5/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.3467 - accuracy: 0.8626 - val_loss: 0.3572 - val_accuracy: 0.8451
# Epoch 6/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.3259 - accuracy: 0.8694 - val_loss: 0.3460 - val_accuracy: 0.8540
# Epoch 7/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.3150 - accuracy: 0.8717 - val_loss: 0.3530 - val_accuracy: 0.8581
# Epoch 8/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.3043 - accuracy: 0.8773 - val_loss: 0.3679 - val_accuracy: 0.8492
# Epoch 9/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2950 - accuracy: 0.8789 - val_loss: 0.3230 - val_accuracy: 0.8677
# Epoch 10/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2874 - accuracy: 0.8823 - val_loss: 0.3681 - val_accuracy: 0.8506
# Epoch 11/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2854 - accuracy: 0.8823 - val_loss: 0.3129 - val_accuracy: 0.8698
# Epoch 12/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2807 - accuracy: 0.8855 - val_loss: 0.3597 - val_accuracy: 0.8533
# Epoch 13/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2780 - accuracy: 0.8855 - val_loss: 0.3504 - val_accuracy: 0.8472
# Epoch 14/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2695 - accuracy: 0.8830 - val_loss: 0.2866 - val_accuracy: 0.8807
# Epoch 15/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2630 - accuracy: 0.8885 - val_loss: 0.3740 - val_accuracy: 0.8369
# Epoch 16/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2599 - accuracy: 0.8890 - val_loss: 0.3053 - val_accuracy: 0.8746
# Epoch 17/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2621 - accuracy: 0.8888 - val_loss: 0.3041 - val_accuracy: 0.8705
# Epoch 18/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2595 - accuracy: 0.8905 - val_loss: 0.3384 - val_accuracy: 0.8492
# Epoch 19/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2527 - accuracy: 0.8932 - val_loss: 0.3727 - val_accuracy: 0.8430
# Epoch 20/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2550 - accuracy: 0.8893 - val_loss: 0.3658 - val_accuracy: 0.8430
# Epoch 21/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2486 - accuracy: 0.8962 - val_loss: 0.3386 - val_accuracy: 0.8499
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 14.
# 29/29 [==============================] - 1s 5ms/step
# Fold 4 Results: Accuracy=0.9079, Precision=0.9103, Recall=0.8761, F1=0.8929, ROC-AUC==0.9647, Time=49.45s
# --- Starting Fold 5/5 ---
# Model: "model_29"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 512)]                0         []
#  r)
#
#  tf.expand_dims_19 (TFOpLam  (None, 1, 512)               0         ['embedding_input[0][0]']
#  bda)
#
#  spatial_dropout1d_29 (Spat  (None, 1, 512)               0         ['tf.expand_dims_19[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_29 (CuDNNLSTM)   (None, 1, 100)               245600    ['spatial_dropout1d_29[0][0]']
#
#  bidirectional_58 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_29[0][0]']
#  ional)
#
#  bidirectional_59 (Bidirect  (None, 1, 128)               254848    ['bidirectional_58[0][0]']
#  ional)
#
#  cust_attention_24 (CustAtt  (None, 1, 128)               129       ['bidirectional_59[0][0]']
#  ention)
#
#  global_average_pooling1d_2  (None, 128)                  0         ['cust_attention_24[0][0]']
#  9 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_29 (G  (None, 128)                  0         ['cust_attention_24[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_29 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_29[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_29[0][0
#                                                                     ]']
#
#  dense_58 (Dense)            (None, 16)                   4112      ['concatenate_29[0][0]']
#
#  dropout_399 (Dropout)       (None, 16)                   0         ['dense_58[0][0]']
#
#  dense_59 (Dense)            (None, 1)                    17        ['dropout_399[0][0]']
#
# ==================================================================================================
# Total params: 1100418 (4.20 MB)
# Trainable params: 1100418 (4.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 13s 29ms/step - loss: 0.6706 - accuracy: 0.7012 - val_loss: 0.6390 - val_accuracy: 0.8253
# Epoch 2/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.5866 - accuracy: 0.8286 - val_loss: 0.5027 - val_accuracy: 0.8260
# Epoch 3/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.4382 - accuracy: 0.8406 - val_loss: 0.4020 - val_accuracy: 0.8315
# Epoch 4/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.3707 - accuracy: 0.8513 - val_loss: 0.3635 - val_accuracy: 0.8466
# Epoch 5/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.3399 - accuracy: 0.8662 - val_loss: 0.3542 - val_accuracy: 0.8555
# Epoch 6/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.3255 - accuracy: 0.8689 - val_loss: 0.3416 - val_accuracy: 0.8658
# Epoch 7/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.3142 - accuracy: 0.8732 - val_loss: 0.3572 - val_accuracy: 0.8527
# Epoch 8/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.3031 - accuracy: 0.8773 - val_loss: 0.3096 - val_accuracy: 0.8774
# Epoch 9/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2967 - accuracy: 0.8775 - val_loss: 0.3276 - val_accuracy: 0.8699
# Epoch 10/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2896 - accuracy: 0.8782 - val_loss: 0.2878 - val_accuracy: 0.8815
# Epoch 11/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2860 - accuracy: 0.8794 - val_loss: 0.2772 - val_accuracy: 0.8897
# Epoch 12/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2806 - accuracy: 0.8843 - val_loss: 0.3055 - val_accuracy: 0.8747
# Epoch 13/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2781 - accuracy: 0.8843 - val_loss: 0.3003 - val_accuracy: 0.8747
# Epoch 14/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2740 - accuracy: 0.8866 - val_loss: 0.2703 - val_accuracy: 0.8918
# Epoch 15/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2747 - accuracy: 0.8869 - val_loss: 0.2853 - val_accuracy: 0.8788
# Epoch 16/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2647 - accuracy: 0.8922 - val_loss: 0.2880 - val_accuracy: 0.8753
# Epoch 17/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2641 - accuracy: 0.8914 - val_loss: 0.2872 - val_accuracy: 0.8795
# Epoch 18/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2619 - accuracy: 0.8903 - val_loss: 0.2838 - val_accuracy: 0.8801
# Epoch 19/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2578 - accuracy: 0.8927 - val_loss: 0.2828 - val_accuracy: 0.8829
# Epoch 20/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2568 - accuracy: 0.8963 - val_loss: 0.2709 - val_accuracy: 0.8856
# Epoch 21/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2548 - accuracy: 0.8926 - val_loss: 0.3043 - val_accuracy: 0.8644
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 14.
# 29/29 [==============================] - 1s 5ms/step
# Fold 5 Results: Accuracy=0.8755, Precision=0.8479, Recall=0.8723, F1=0.8600, ROC-AUC==0.9525, Time=48.70s
# --- Analysis for: tcn_model_sb_precompute_pool - Twitter ---
# --------------------------------------------------
#
# [Raw Results per Fold]
#    Fold  Accuracy  Precision    Recall  F1-Score   ROC-AUC  Training Time (s)  Dataset
# 0     1  0.897478   0.908123  0.852500  0.879433  0.966143          64.186728  Twitter
# 1     2  0.899671   0.907530  0.858750  0.882466  0.957196          63.844421  Twitter
# 2     3  0.897478   0.888466  0.876250  0.882316  0.960918          66.153586  Twitter
# 3     4  0.907895   0.910273  0.876095  0.892857  0.964716          49.447752  Twitter
# 4     5  0.875480   0.847932  0.872340  0.859963  0.952459          48.698824  Twitter
#
# [Summary Statistics]
#                         mean       std
# Accuracy            0.895600  0.012037
# Precision           0.892465  0.026403
# Recall              0.867187  0.010897
# F1-Score            0.879407  0.012008
# ROC-AUC             0.960286  0.005593
# Training Time (s)  58.466262  8.623799
# --------------------------------------------------
#
# [Total Training Time]: 292.3313114643097 seconds
# 18931

# %%
#tcn_model_sb_precompute_seqOut
print("Loading TF-Hub models...")
preprocessor = hub.KerasLayer(tfhub_handle_preprocess)
encoder = hub.KerasLayer(tfhub_handle_encoder, trainable=False)
print("Models loaded.")
X_embeddings = extract_feature_bert_sequence(preprocessor=preprocessor, encoder=encoder, texts=X)

result, history_list = run_cross_validation(FOLDS, X_embeddings, y, tcn_model_sb_precompute_seqOut,False)
variant_name = "tcn_model_sb_precompute_seqOut"
result['Variant'] = variant_name
result['Dataset'] = 'Twitter'
all_results.append(result)
analyze_cv_results(result)

for hist in history_list:
    hist['Variant'] = variant_name
    all_histories.extend(history_list)

output_filename = f'/content/drive/MyDrive/final_FYP_results/{folder_name}/{variant_name}_twitter_result.csv'
result.to_csv(output_filename, index=False)
del output_filename
del history_list
del result
gc.collect()
# Out:
# Loading TF-Hub models...
# Models loaded.
#
#  Starting BERT feature extraction...
# Done
# --- Starting Fold 1/5 ---
# Model: "model_30"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 128, 512)]           0         []
#  r)
#
#  spatial_dropout1d_30 (Spat  (None, 128, 512)             0         ['embedding_input[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_30 (CuDNNLSTM)   (None, 128, 100)             245600    ['spatial_dropout1d_30[0][0]']
#
#  bidirectional_60 (Bidirect  (None, 128, 256)             595712    ['cu_dnnlstm_30[0][0]']
#  ional)
#
#  bidirectional_61 (Bidirect  (None, 128, 128)             254848    ['bidirectional_60[0][0]']
#  ional)
#
#  cust_attention_25 (CustAtt  (None, 128, 128)             256       ['bidirectional_61[0][0]']
#  ention)
#
#  global_average_pooling1d_3  (None, 128)                  0         ['cust_attention_25[0][0]']
#  0 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_30 (G  (None, 128)                  0         ['cust_attention_25[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_30 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_30[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_30[0][0
#                                                                     ]']
#
#  dense_60 (Dense)            (None, 16)                   4112      ['concatenate_30[0][0]']
#
#  dropout_400 (Dropout)       (None, 16)                   0         ['dense_60[0][0]']
#
#  dense_61 (Dense)            (None, 1)                    17        ['dropout_400[0][0]']
#
# ==================================================================================================
# Total params: 1100545 (4.20 MB)
# Trainable params: 1100545 (4.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 15s 60ms/step - loss: 0.6774 - accuracy: 0.5619 - val_loss: 0.6569 - val_accuracy: 0.5613
# Epoch 2/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.6264 - accuracy: 0.5639 - val_loss: 0.6271 - val_accuracy: 0.5613
# Epoch 3/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.5462 - accuracy: 0.7291 - val_loss: 0.5126 - val_accuracy: 0.8334
# Epoch 4/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.4853 - accuracy: 0.8460 - val_loss: 0.4795 - val_accuracy: 0.8273
# Epoch 5/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.4521 - accuracy: 0.8492 - val_loss: 0.4544 - val_accuracy: 0.8348
# Epoch 6/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.4326 - accuracy: 0.8506 - val_loss: 0.4406 - val_accuracy: 0.8451
# Epoch 7/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.4200 - accuracy: 0.8523 - val_loss: 0.4174 - val_accuracy: 0.8437
# Epoch 8/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.3879 - accuracy: 0.8677 - val_loss: 0.4071 - val_accuracy: 0.8547
# Epoch 9/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.3697 - accuracy: 0.8713 - val_loss: 0.3914 - val_accuracy: 0.8547
# Epoch 10/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.3487 - accuracy: 0.8739 - val_loss: 0.3579 - val_accuracy: 0.8759
# Epoch 11/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.3241 - accuracy: 0.8830 - val_loss: 0.3051 - val_accuracy: 0.8849
# Epoch 12/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.3007 - accuracy: 0.8845 - val_loss: 0.3118 - val_accuracy: 0.8869
# Epoch 13/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2800 - accuracy: 0.8895 - val_loss: 0.3724 - val_accuracy: 0.8458
# Epoch 14/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2668 - accuracy: 0.8989 - val_loss: 0.3004 - val_accuracy: 0.8876
# Epoch 15/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2645 - accuracy: 0.8927 - val_loss: 0.3052 - val_accuracy: 0.8814
# Epoch 16/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2515 - accuracy: 0.9003 - val_loss: 0.2455 - val_accuracy: 0.8965
# Epoch 17/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2468 - accuracy: 0.9020 - val_loss: 0.2464 - val_accuracy: 0.8979
# Epoch 18/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2385 - accuracy: 0.9032 - val_loss: 0.2438 - val_accuracy: 0.9020
# Epoch 19/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2300 - accuracy: 0.9023 - val_loss: 0.2383 - val_accuracy: 0.9034
# Epoch 20/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2323 - accuracy: 0.9025 - val_loss: 0.2319 - val_accuracy: 0.9027
# Epoch 21/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2205 - accuracy: 0.9099 - val_loss: 0.2836 - val_accuracy: 0.8951
# Epoch 22/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2170 - accuracy: 0.9097 - val_loss: 0.2370 - val_accuracy: 0.9075
# Epoch 23/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2146 - accuracy: 0.9100 - val_loss: 0.2353 - val_accuracy: 0.9164
# Epoch 24/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2123 - accuracy: 0.9145 - val_loss: 0.2184 - val_accuracy: 0.9130
# Epoch 25/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2082 - accuracy: 0.9124 - val_loss: 0.2282 - val_accuracy: 0.9130
# Epoch 26/30
# 92/92 [==============================] - 3s 31ms/step - loss: 0.2040 - accuracy: 0.9142 - val_loss: 0.2244 - val_accuracy: 0.9164
# Epoch 27/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2011 - accuracy: 0.9157 - val_loss: 0.2392 - val_accuracy: 0.9109
# Epoch 28/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1957 - accuracy: 0.9186 - val_loss: 0.2269 - val_accuracy: 0.9143
# Epoch 29/30
# 92/92 [==============================] - 3s 31ms/step - loss: 0.1962 - accuracy: 0.9183 - val_loss: 0.2410 - val_accuracy: 0.9109
# Epoch 30/30
# 92/92 [==============================] - 3s 31ms/step - loss: 0.1954 - accuracy: 0.9217 - val_loss: 0.2190 - val_accuracy: 0.9198
# Restoring model weights from the end of the best epoch: 24.
# 29/29 [==============================] - 2s 11ms/step
# Fold 1 Results: Accuracy=0.9216, Precision=0.9494, Recall=0.8675, F1=0.9066, ROC-AUC==0.9761, Time=111.82s
# --- Starting Fold 2/5 ---
# Model: "model_31"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 128, 512)]           0         []
#  r)
#
#  spatial_dropout1d_31 (Spat  (None, 128, 512)             0         ['embedding_input[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_31 (CuDNNLSTM)   (None, 128, 100)             245600    ['spatial_dropout1d_31[0][0]']
#
#  bidirectional_62 (Bidirect  (None, 128, 256)             595712    ['cu_dnnlstm_31[0][0]']
#  ional)
#
#  bidirectional_63 (Bidirect  (None, 128, 128)             254848    ['bidirectional_62[0][0]']
#  ional)
#
#  cust_attention_26 (CustAtt  (None, 128, 128)             256       ['bidirectional_63[0][0]']
#  ention)
#
#  global_average_pooling1d_3  (None, 128)                  0         ['cust_attention_26[0][0]']
#  1 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_31 (G  (None, 128)                  0         ['cust_attention_26[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_31 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_31[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_31[0][0
#                                                                     ]']
#
#  dense_62 (Dense)            (None, 16)                   4112      ['concatenate_31[0][0]']
#
#  dropout_401 (Dropout)       (None, 16)                   0         ['dense_62[0][0]']
#
#  dense_63 (Dense)            (None, 1)                    17        ['dropout_401[0][0]']
#
# ==================================================================================================
# Total params: 1100545 (4.20 MB)
# Trainable params: 1100545 (4.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 15s 45ms/step - loss: 0.6674 - accuracy: 0.5632 - val_loss: 0.6365 - val_accuracy: 0.5613
# Epoch 2/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.6023 - accuracy: 0.5778 - val_loss: 0.5524 - val_accuracy: 0.6100
# Epoch 3/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.5321 - accuracy: 0.7754 - val_loss: 0.4860 - val_accuracy: 0.8389
# Epoch 4/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.5958 - accuracy: 0.7399 - val_loss: 0.5192 - val_accuracy: 0.8163
# Epoch 5/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.4232 - accuracy: 0.8322 - val_loss: 0.3580 - val_accuracy: 0.8622
# Epoch 6/30
# 92/92 [==============================] - 3s 34ms/step - loss: 0.3534 - accuracy: 0.8586 - val_loss: 0.3166 - val_accuracy: 0.8732
# Epoch 7/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.3260 - accuracy: 0.8706 - val_loss: 0.2952 - val_accuracy: 0.8821
# Epoch 8/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.3058 - accuracy: 0.8753 - val_loss: 0.2940 - val_accuracy: 0.8753
# Epoch 9/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2896 - accuracy: 0.8780 - val_loss: 0.2706 - val_accuracy: 0.8855
# Epoch 10/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2816 - accuracy: 0.8819 - val_loss: 0.3203 - val_accuracy: 0.8643
# Epoch 11/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2687 - accuracy: 0.8898 - val_loss: 0.2555 - val_accuracy: 0.8938
# Epoch 12/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2623 - accuracy: 0.8919 - val_loss: 0.2505 - val_accuracy: 0.8883
# Epoch 13/30
# 92/92 [==============================] - 3s 34ms/step - loss: 0.2547 - accuracy: 0.8941 - val_loss: 0.2391 - val_accuracy: 0.8931
# Epoch 14/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2514 - accuracy: 0.8902 - val_loss: 0.2403 - val_accuracy: 0.8944
# Epoch 15/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2459 - accuracy: 0.8920 - val_loss: 0.2316 - val_accuracy: 0.8951
# Epoch 16/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2366 - accuracy: 0.8956 - val_loss: 0.2213 - val_accuracy: 0.8992
# Epoch 17/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2258 - accuracy: 0.9028 - val_loss: 0.2174 - val_accuracy: 0.9034
# Epoch 18/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2271 - accuracy: 0.9030 - val_loss: 0.2162 - val_accuracy: 0.9020
# Epoch 19/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2223 - accuracy: 0.9037 - val_loss: 0.2132 - val_accuracy: 0.9006
# Epoch 20/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2209 - accuracy: 0.9095 - val_loss: 0.2113 - val_accuracy: 0.9061
# Epoch 21/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2168 - accuracy: 0.9094 - val_loss: 0.2084 - val_accuracy: 0.9061
# Epoch 22/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2164 - accuracy: 0.9121 - val_loss: 0.2068 - val_accuracy: 0.9116
# Epoch 23/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2146 - accuracy: 0.9090 - val_loss: 0.2058 - val_accuracy: 0.9171
# Epoch 24/30
# 92/92 [==============================] - 3s 34ms/step - loss: 0.2098 - accuracy: 0.9111 - val_loss: 0.2003 - val_accuracy: 0.9150
# Epoch 25/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1969 - accuracy: 0.9214 - val_loss: 0.1980 - val_accuracy: 0.9171
# Epoch 26/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2009 - accuracy: 0.9160 - val_loss: 0.1933 - val_accuracy: 0.9191
# Epoch 27/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1957 - accuracy: 0.9191 - val_loss: 0.1929 - val_accuracy: 0.9184
# Epoch 28/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.1927 - accuracy: 0.9178 - val_loss: 0.1905 - val_accuracy: 0.9212
# Epoch 29/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1893 - accuracy: 0.9243 - val_loss: 0.1971 - val_accuracy: 0.9123
# Epoch 30/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1898 - accuracy: 0.9214 - val_loss: 0.1863 - val_accuracy: 0.9184
# Restoring model weights from the end of the best epoch: 30.
# 29/29 [==============================] - 2s 12ms/step
# Fold 2 Results: Accuracy=0.9161, Precision=0.9273, Recall=0.8775, F1=0.9017, ROC-AUC==0.9700, Time=112.43s
# --- Starting Fold 3/5 ---
# Model: "model_32"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 128, 512)]           0         []
#  r)
#
#  spatial_dropout1d_32 (Spat  (None, 128, 512)             0         ['embedding_input[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_32 (CuDNNLSTM)   (None, 128, 100)             245600    ['spatial_dropout1d_32[0][0]']
#
#  bidirectional_64 (Bidirect  (None, 128, 256)             595712    ['cu_dnnlstm_32[0][0]']
#  ional)
#
#  bidirectional_65 (Bidirect  (None, 128, 128)             254848    ['bidirectional_64[0][0]']
#  ional)
#
#  cust_attention_27 (CustAtt  (None, 128, 128)             256       ['bidirectional_65[0][0]']
#  ention)
#
#  global_average_pooling1d_3  (None, 128)                  0         ['cust_attention_27[0][0]']
#  2 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_32 (G  (None, 128)                  0         ['cust_attention_27[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_32 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_32[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_32[0][0
#                                                                     ]']
#
#  dense_64 (Dense)            (None, 16)                   4112      ['concatenate_32[0][0]']
#
#  dropout_402 (Dropout)       (None, 16)                   0         ['dense_64[0][0]']
#
#  dense_65 (Dense)            (None, 1)                    17        ['dropout_402[0][0]']
#
# ==================================================================================================
# Total params: 1100545 (4.20 MB)
# Trainable params: 1100545 (4.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 15s 44ms/step - loss: 0.6893 - accuracy: 0.5960 - val_loss: 0.6761 - val_accuracy: 0.7896
# Epoch 2/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.6564 - accuracy: 0.7594 - val_loss: 0.6141 - val_accuracy: 0.7855
# Epoch 3/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.5802 - accuracy: 0.8194 - val_loss: 0.4712 - val_accuracy: 0.8520
# Epoch 4/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.4504 - accuracy: 0.8511 - val_loss: 0.3765 - val_accuracy: 0.8568
# Epoch 5/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.3759 - accuracy: 0.8621 - val_loss: 0.9384 - val_accuracy: 0.4859
# Epoch 6/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.3982 - accuracy: 0.8569 - val_loss: 0.3497 - val_accuracy: 0.8513
# Epoch 7/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.3154 - accuracy: 0.8739 - val_loss: 0.2969 - val_accuracy: 0.8753
# Epoch 8/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2869 - accuracy: 0.8864 - val_loss: 0.2597 - val_accuracy: 0.8910
# Epoch 9/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2751 - accuracy: 0.8900 - val_loss: 0.2823 - val_accuracy: 0.8869
# Epoch 10/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2624 - accuracy: 0.8927 - val_loss: 0.3103 - val_accuracy: 0.8677
# Epoch 11/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2521 - accuracy: 0.9008 - val_loss: 0.2821 - val_accuracy: 0.8869
# Epoch 12/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2511 - accuracy: 0.8984 - val_loss: 0.2285 - val_accuracy: 0.9109
# Epoch 13/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2391 - accuracy: 0.9049 - val_loss: 0.2694 - val_accuracy: 0.8876
# Epoch 14/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2382 - accuracy: 0.9030 - val_loss: 0.2159 - val_accuracy: 0.9164
# Epoch 15/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2322 - accuracy: 0.9068 - val_loss: 0.2364 - val_accuracy: 0.9013
# Epoch 16/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2284 - accuracy: 0.9066 - val_loss: 0.2668 - val_accuracy: 0.8897
# Epoch 17/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2152 - accuracy: 0.9145 - val_loss: 0.2152 - val_accuracy: 0.9178
# Epoch 18/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2155 - accuracy: 0.9148 - val_loss: 0.2120 - val_accuracy: 0.9164
# Epoch 19/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2098 - accuracy: 0.9169 - val_loss: 0.2515 - val_accuracy: 0.8992
# Epoch 20/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2093 - accuracy: 0.9179 - val_loss: 0.2181 - val_accuracy: 0.9095
# Epoch 21/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2112 - accuracy: 0.9150 - val_loss: 0.2125 - val_accuracy: 0.9191
# Epoch 22/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2019 - accuracy: 0.9145 - val_loss: 0.2060 - val_accuracy: 0.9205
# Epoch 23/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2036 - accuracy: 0.9188 - val_loss: 0.2014 - val_accuracy: 0.9239
# Epoch 24/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1954 - accuracy: 0.9239 - val_loss: 0.2025 - val_accuracy: 0.9239
# Epoch 25/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1932 - accuracy: 0.9267 - val_loss: 0.2059 - val_accuracy: 0.9198
# Epoch 26/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1930 - accuracy: 0.9249 - val_loss: 0.2164 - val_accuracy: 0.9123
# Epoch 27/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1864 - accuracy: 0.9258 - val_loss: 0.2025 - val_accuracy: 0.9205
# Epoch 28/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1861 - accuracy: 0.9263 - val_loss: 0.2018 - val_accuracy: 0.9212
# Epoch 29/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.1862 - accuracy: 0.9275 - val_loss: 0.2035 - val_accuracy: 0.9225
# Epoch 30/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1815 - accuracy: 0.9294 - val_loss: 0.2044 - val_accuracy: 0.9232
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 23.
# 29/29 [==============================] - 1s 11ms/step
# Fold 3 Results: Accuracy=0.9161, Precision=0.9251, Recall=0.8800, F1=0.9020, ROC-AUC==0.9712, Time=110.57s
# --- Starting Fold 4/5 ---
# Model: "model_33"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 128, 512)]           0         []
#  r)
#
#  spatial_dropout1d_33 (Spat  (None, 128, 512)             0         ['embedding_input[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_33 (CuDNNLSTM)   (None, 128, 100)             245600    ['spatial_dropout1d_33[0][0]']
#
#  bidirectional_66 (Bidirect  (None, 128, 256)             595712    ['cu_dnnlstm_33[0][0]']
#  ional)
#
#  bidirectional_67 (Bidirect  (None, 128, 128)             254848    ['bidirectional_66[0][0]']
#  ional)
#
#  cust_attention_28 (CustAtt  (None, 128, 128)             256       ['bidirectional_67[0][0]']
#  ention)
#
#  global_average_pooling1d_3  (None, 128)                  0         ['cust_attention_28[0][0]']
#  3 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_33 (G  (None, 128)                  0         ['cust_attention_28[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_33 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_33[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_33[0][0
#                                                                     ]']
#
#  dense_66 (Dense)            (None, 16)                   4112      ['concatenate_33[0][0]']
#
#  dropout_403 (Dropout)       (None, 16)                   0         ['dense_66[0][0]']
#
#  dense_67 (Dense)            (None, 1)                    17        ['dropout_403[0][0]']
#
# ==================================================================================================
# Total params: 1100545 (4.20 MB)
# Trainable params: 1100545 (4.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 15s 46ms/step - loss: 0.6617 - accuracy: 0.5617 - val_loss: 0.6585 - val_accuracy: 0.5613
# Epoch 2/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.5666 - accuracy: 0.6959 - val_loss: 0.5863 - val_accuracy: 0.7759
# Epoch 3/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.4883 - accuracy: 0.8275 - val_loss: 0.4544 - val_accuracy: 0.8348
# Epoch 4/30
# 92/92 [==============================] - 3s 34ms/step - loss: 0.4435 - accuracy: 0.8463 - val_loss: 0.4182 - val_accuracy: 0.8472
# Epoch 5/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.4022 - accuracy: 0.8588 - val_loss: 0.3846 - val_accuracy: 0.8581
# Epoch 6/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.3685 - accuracy: 0.8686 - val_loss: 0.4833 - val_accuracy: 0.7868
# Epoch 7/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.3329 - accuracy: 0.8703 - val_loss: 0.3754 - val_accuracy: 0.8341
# Epoch 8/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.3043 - accuracy: 0.8742 - val_loss: 0.3665 - val_accuracy: 0.8286
# Epoch 9/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2882 - accuracy: 0.8787 - val_loss: 0.3910 - val_accuracy: 0.8211
# Epoch 10/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2716 - accuracy: 0.8891 - val_loss: 0.3452 - val_accuracy: 0.8451
# Epoch 11/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2603 - accuracy: 0.8938 - val_loss: 0.4321 - val_accuracy: 0.7992
# Epoch 12/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2558 - accuracy: 0.8958 - val_loss: 0.3879 - val_accuracy: 0.8245
# Epoch 13/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2397 - accuracy: 0.9034 - val_loss: 0.3190 - val_accuracy: 0.8588
# Epoch 14/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2330 - accuracy: 0.9028 - val_loss: 0.2931 - val_accuracy: 0.8691
# Epoch 15/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2277 - accuracy: 0.9087 - val_loss: 0.3643 - val_accuracy: 0.8286
# Epoch 16/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2229 - accuracy: 0.9112 - val_loss: 0.3603 - val_accuracy: 0.8396
# Epoch 17/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2187 - accuracy: 0.9111 - val_loss: 0.3913 - val_accuracy: 0.8252
# Epoch 18/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2132 - accuracy: 0.9147 - val_loss: 0.3595 - val_accuracy: 0.8513
# Epoch 19/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2060 - accuracy: 0.9186 - val_loss: 0.3326 - val_accuracy: 0.8547
# Epoch 20/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2100 - accuracy: 0.9142 - val_loss: 0.2844 - val_accuracy: 0.8849
# Epoch 21/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1991 - accuracy: 0.9210 - val_loss: 0.3056 - val_accuracy: 0.8739
# Epoch 22/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1958 - accuracy: 0.9217 - val_loss: 0.3280 - val_accuracy: 0.8691
# Epoch 23/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.1878 - accuracy: 0.9231 - val_loss: 0.2482 - val_accuracy: 0.8951
# Epoch 24/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1867 - accuracy: 0.9210 - val_loss: 0.2775 - val_accuracy: 0.8849
# Epoch 25/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1829 - accuracy: 0.9270 - val_loss: 0.4587 - val_accuracy: 0.8430
# Epoch 26/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.1871 - accuracy: 0.9241 - val_loss: 0.2379 - val_accuracy: 0.8979
# Epoch 27/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1847 - accuracy: 0.9301 - val_loss: 0.2252 - val_accuracy: 0.8999
# Epoch 28/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1785 - accuracy: 0.9275 - val_loss: 0.2523 - val_accuracy: 0.8931
# Epoch 29/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1787 - accuracy: 0.9289 - val_loss: 0.2671 - val_accuracy: 0.8903
# Epoch 30/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.1713 - accuracy: 0.9323 - val_loss: 0.2199 - val_accuracy: 0.9075
# Restoring model weights from the end of the best epoch: 30.
# 29/29 [==============================] - 1s 11ms/step
# Fold 4 Results: Accuracy=0.9331, Precision=0.9312, Recall=0.9149, F1=0.9230, ROC-AUC==0.9784, Time=112.44s
# --- Starting Fold 5/5 ---
# Model: "model_34"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 128, 512)]           0         []
#  r)
#
#  spatial_dropout1d_34 (Spat  (None, 128, 512)             0         ['embedding_input[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_34 (CuDNNLSTM)   (None, 128, 100)             245600    ['spatial_dropout1d_34[0][0]']
#
#  bidirectional_68 (Bidirect  (None, 128, 256)             595712    ['cu_dnnlstm_34[0][0]']
#  ional)
#
#  bidirectional_69 (Bidirect  (None, 128, 128)             254848    ['bidirectional_68[0][0]']
#  ional)
#
#  cust_attention_29 (CustAtt  (None, 128, 128)             256       ['bidirectional_69[0][0]']
#  ention)
#
#  global_average_pooling1d_3  (None, 128)                  0         ['cust_attention_29[0][0]']
#  4 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_34 (G  (None, 128)                  0         ['cust_attention_29[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_34 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_34[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_34[0][0
#                                                                     ]']
#
#  dense_68 (Dense)            (None, 16)                   4112      ['concatenate_34[0][0]']
#
#  dropout_404 (Dropout)       (None, 16)                   0         ['dense_68[0][0]']
#
#  dense_69 (Dense)            (None, 1)                    17        ['dropout_404[0][0]']
#
# ==================================================================================================
# Total params: 1100545 (4.20 MB)
# Trainable params: 1100545 (4.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 15s 45ms/step - loss: 0.6926 - accuracy: 0.5221 - val_loss: 0.6887 - val_accuracy: 0.5616
# Epoch 2/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.6869 - accuracy: 0.5658 - val_loss: 0.6847 - val_accuracy: 0.5616
# Epoch 3/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.6834 - accuracy: 0.5615 - val_loss: 0.6813 - val_accuracy: 0.5616
# Epoch 4/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.6801 - accuracy: 0.5615 - val_loss: 0.6774 - val_accuracy: 0.5616
# Epoch 5/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.6763 - accuracy: 0.5615 - val_loss: 0.6714 - val_accuracy: 0.5616
# Epoch 6/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.6686 - accuracy: 0.5704 - val_loss: 0.6600 - val_accuracy: 0.5836
# Epoch 7/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.6531 - accuracy: 0.7274 - val_loss: 0.6339 - val_accuracy: 0.8541
# Epoch 8/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.6133 - accuracy: 0.8367 - val_loss: 0.5709 - val_accuracy: 0.8253
# Epoch 9/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.5379 - accuracy: 0.8326 - val_loss: 0.4865 - val_accuracy: 0.8295
# Epoch 10/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.4630 - accuracy: 0.8400 - val_loss: 0.4207 - val_accuracy: 0.8486
# Epoch 11/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.4005 - accuracy: 0.8508 - val_loss: 0.3650 - val_accuracy: 0.8562
# Epoch 12/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.3564 - accuracy: 0.8631 - val_loss: 0.3349 - val_accuracy: 0.8733
# Epoch 13/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.3243 - accuracy: 0.8753 - val_loss: 0.3007 - val_accuracy: 0.8760
# Epoch 14/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.3098 - accuracy: 0.8780 - val_loss: 0.3110 - val_accuracy: 0.8808
# Epoch 15/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2974 - accuracy: 0.8825 - val_loss: 0.3353 - val_accuracy: 0.8651
# Epoch 16/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2840 - accuracy: 0.8864 - val_loss: 0.3110 - val_accuracy: 0.8753
# Epoch 17/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2720 - accuracy: 0.8895 - val_loss: 0.3094 - val_accuracy: 0.8822
# Epoch 18/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2624 - accuracy: 0.8932 - val_loss: 0.2774 - val_accuracy: 0.8836
# Epoch 19/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2568 - accuracy: 0.8965 - val_loss: 0.2347 - val_accuracy: 0.8993
# Epoch 20/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2477 - accuracy: 0.8972 - val_loss: 0.2716 - val_accuracy: 0.8877
# Epoch 21/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2434 - accuracy: 0.8994 - val_loss: 0.2066 - val_accuracy: 0.9205
# Epoch 22/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2379 - accuracy: 0.9046 - val_loss: 0.2800 - val_accuracy: 0.8849
# Epoch 23/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2303 - accuracy: 0.9025 - val_loss: 0.1959 - val_accuracy: 0.9158
# Epoch 24/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2291 - accuracy: 0.9044 - val_loss: 0.1865 - val_accuracy: 0.9233
# Epoch 25/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2182 - accuracy: 0.9104 - val_loss: 0.2409 - val_accuracy: 0.9014
# Epoch 26/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2161 - accuracy: 0.9145 - val_loss: 0.1842 - val_accuracy: 0.9219
# Epoch 27/30
# 92/92 [==============================] - 3s 33ms/step - loss: 0.2114 - accuracy: 0.9152 - val_loss: 0.1856 - val_accuracy: 0.9219
# Epoch 28/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2089 - accuracy: 0.9154 - val_loss: 0.1845 - val_accuracy: 0.9226
# Epoch 29/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.2089 - accuracy: 0.9116 - val_loss: 0.1787 - val_accuracy: 0.9253
# Epoch 30/30
# 92/92 [==============================] - 3s 32ms/step - loss: 0.1995 - accuracy: 0.9171 - val_loss: 0.1767 - val_accuracy: 0.9260
# Restoring model weights from the end of the best epoch: 30.
# 29/29 [==============================] - 1s 12ms/step
# Fold 5 Results: Accuracy=0.9155, Precision=0.8977, Recall=0.9111, F1=0.9043, ROC-AUC==0.9727, Time=111.26s
# --- Analysis for: tcn_model_sb_precompute_seqOut - Twitter ---
# --------------------------------------------------
#
# [Raw Results per Fold]
#    Fold  Accuracy  Precision    Recall  F1-Score   ROC-AUC  Training Time (s)  Dataset
# 0     1  0.921601   0.949384  0.867500  0.906597  0.976146         111.816015  Twitter
# 1     2  0.916118   0.927345  0.877500  0.901734  0.970026         112.428130  Twitter
# 2     3  0.916118   0.925099  0.880000  0.901986  0.971206         110.568349  Twitter
# 3     4  0.933114   0.931210  0.914894  0.922980  0.978447         112.441074  Twitter
# 4     5  0.915524   0.897657  0.911139  0.904348  0.972734         111.261928  Twitter
#
# [Summary Statistics]
#                          mean       std
# Accuracy             0.920495  0.007475
# Precision            0.926139  0.018573
# Recall               0.890207  0.021382
# F1-Score             0.907529  0.008860
# ROC-AUC              0.973712  0.003506
# Training Time (s)  111.703099  0.800830
# --------------------------------------------------
#
# [Total Training Time]: 558.5154957771301 seconds
# 18826

# %%
#tcn_model_mb_precompute_pool
tokenizer = AutoTokenizer.from_pretrained("mental/mental-bert-base-uncased")
model = AutoModel.from_pretrained("mental/mental-bert-base-uncased")
X_embeddings = extract_feature_mb_pooled(tokenizer=tokenizer, model=model, texts=X)

result, history_list = run_cross_validation(FOLDS, X_embeddings, y, tcn_model_mb_precompute_pool,False)
variant_name = "tcn_model_mb_precompute_pool"
result['Variant'] = variant_name
result['Dataset'] = 'Twitter'
all_results.append(result)
analyze_cv_results(result)

for hist in history_list:
    hist['Variant'] = variant_name
    all_histories.extend(history_list)

output_filename = f'/content/drive/MyDrive/final_FYP_results/{folder_name}/{variant_name}_twitter_result.csv'
result.to_csv(output_filename, index=False)
del output_filename
del history_list
del result
gc.collect()
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at mental/mental-bert-base-uncased and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Starting BERT feature extraction...
# Processed 9119/9119 texts
# Done
# --- Starting Fold 1/5 ---
# Model: "model_35"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 768)]                0         []
#  r)
#
#  tf.expand_dims_20 (TFOpLam  (None, 1, 768)               0         ['embedding_input[0][0]']
#  bda)
#
#  spatial_dropout1d_35 (Spat  (None, 1, 768)               0         ['tf.expand_dims_20[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_35 (CuDNNLSTM)   (None, 1, 100)               348000    ['spatial_dropout1d_35[0][0]']
#
#  bidirectional_70 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_35[0][0]']
#  ional)
#
#  bidirectional_71 (Bidirect  (None, 1, 128)               254848    ['bidirectional_70[0][0]']
#  ional)
#
#  cust_attention_30 (CustAtt  (None, 1, 128)               129       ['bidirectional_71[0][0]']
#  ention)
#
#  global_average_pooling1d_3  (None, 128)                  0         ['cust_attention_30[0][0]']
#  5 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_35 (G  (None, 128)                  0         ['cust_attention_30[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_35 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_35[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_35[0][0
#                                                                     ]']
#
#  dense_70 (Dense)            (None, 16)                   4112      ['concatenate_35[0][0]']
#
#  dropout_405 (Dropout)       (None, 16)                   0         ['dense_70[0][0]']
#
#  dense_71 (Dense)            (None, 1)                    17        ['dropout_405[0][0]']
#
# ==================================================================================================
# Total params: 1202818 (4.59 MB)
# Trainable params: 1202818 (4.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 14s 32ms/step - loss: 0.6777 - accuracy: 0.5759 - val_loss: 0.6529 - val_accuracy: 0.8376
# Epoch 2/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.6096 - accuracy: 0.8173 - val_loss: 0.5397 - val_accuracy: 0.8883
# Epoch 3/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.4370 - accuracy: 0.8917 - val_loss: 0.3380 - val_accuracy: 0.8821
# Epoch 4/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2935 - accuracy: 0.8989 - val_loss: 0.2811 - val_accuracy: 0.8931
# Epoch 5/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2641 - accuracy: 0.9039 - val_loss: 0.2627 - val_accuracy: 0.8958
# Epoch 6/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2509 - accuracy: 0.9027 - val_loss: 0.2606 - val_accuracy: 0.9006
# Epoch 7/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2455 - accuracy: 0.9034 - val_loss: 0.2500 - val_accuracy: 0.9006
# Epoch 8/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2371 - accuracy: 0.9075 - val_loss: 0.2384 - val_accuracy: 0.9020
# Epoch 9/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2294 - accuracy: 0.9083 - val_loss: 0.2339 - val_accuracy: 0.9027
# Epoch 10/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2217 - accuracy: 0.9128 - val_loss: 0.2366 - val_accuracy: 0.9040
# Epoch 11/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2223 - accuracy: 0.9100 - val_loss: 0.2252 - val_accuracy: 0.9116
# Epoch 12/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2158 - accuracy: 0.9135 - val_loss: 0.2205 - val_accuracy: 0.9143
# Epoch 13/30
# 92/92 [==============================] - 2s 21ms/step - loss: 0.2123 - accuracy: 0.9147 - val_loss: 0.2140 - val_accuracy: 0.9150
# Epoch 14/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2062 - accuracy: 0.9174 - val_loss: 0.2266 - val_accuracy: 0.9116
# Epoch 15/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2077 - accuracy: 0.9186 - val_loss: 0.2532 - val_accuracy: 0.9006
# Epoch 16/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2020 - accuracy: 0.9219 - val_loss: 0.2631 - val_accuracy: 0.8958
# Epoch 17/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.1965 - accuracy: 0.9232 - val_loss: 0.2066 - val_accuracy: 0.9157
# Epoch 18/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1945 - accuracy: 0.9205 - val_loss: 0.2345 - val_accuracy: 0.9075
# Epoch 19/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.1962 - accuracy: 0.9220 - val_loss: 0.2280 - val_accuracy: 0.9082
# Epoch 20/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.1891 - accuracy: 0.9251 - val_loss: 0.2130 - val_accuracy: 0.9184
# Epoch 21/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1874 - accuracy: 0.9260 - val_loss: 0.2097 - val_accuracy: 0.9198
# Epoch 22/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1806 - accuracy: 0.9289 - val_loss: 0.2107 - val_accuracy: 0.9184
# Epoch 23/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1816 - accuracy: 0.9289 - val_loss: 0.2104 - val_accuracy: 0.9191
# Epoch 24/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1795 - accuracy: 0.9287 - val_loss: 0.2027 - val_accuracy: 0.9184
# Epoch 25/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1778 - accuracy: 0.9280 - val_loss: 0.1939 - val_accuracy: 0.9219
# Epoch 26/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.1681 - accuracy: 0.9287 - val_loss: 0.2691 - val_accuracy: 0.8972
# Epoch 27/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1721 - accuracy: 0.9306 - val_loss: 0.1865 - val_accuracy: 0.9294
# Epoch 28/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1693 - accuracy: 0.9325 - val_loss: 0.1985 - val_accuracy: 0.9219
# Epoch 29/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.1662 - accuracy: 0.9347 - val_loss: 0.2613 - val_accuracy: 0.9013
# Epoch 30/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1659 - accuracy: 0.9357 - val_loss: 0.2113 - val_accuracy: 0.9184
# Restoring model weights from the end of the best epoch: 27.
# 29/29 [==============================] - 1s 5ms/step
# Fold 1 Results: Accuracy=0.9298, Precision=0.9578, Recall=0.8788, F1=0.9166, ROC-AUC==0.9825, Time=68.23s
# --- Starting Fold 2/5 ---
# Model: "model_36"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 768)]                0         []
#  r)
#
#  tf.expand_dims_21 (TFOpLam  (None, 1, 768)               0         ['embedding_input[0][0]']
#  bda)
#
#  spatial_dropout1d_36 (Spat  (None, 1, 768)               0         ['tf.expand_dims_21[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_36 (CuDNNLSTM)   (None, 1, 100)               348000    ['spatial_dropout1d_36[0][0]']
#
#  bidirectional_72 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_36[0][0]']
#  ional)
#
#  bidirectional_73 (Bidirect  (None, 1, 128)               254848    ['bidirectional_72[0][0]']
#  ional)
#
#  cust_attention_31 (CustAtt  (None, 1, 128)               129       ['bidirectional_73[0][0]']
#  ention)
#
#  global_average_pooling1d_3  (None, 128)                  0         ['cust_attention_31[0][0]']
#  6 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_36 (G  (None, 128)                  0         ['cust_attention_31[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_36 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_36[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_36[0][0
#                                                                     ]']
#
#  dense_72 (Dense)            (None, 16)                   4112      ['concatenate_36[0][0]']
#
#  dropout_406 (Dropout)       (None, 16)                   0         ['dense_72[0][0]']
#
#  dense_73 (Dense)            (None, 1)                    17        ['dropout_406[0][0]']
#
# ==================================================================================================
# Total params: 1202818 (4.59 MB)
# Trainable params: 1202818 (4.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 13s 30ms/step - loss: 0.6703 - accuracy: 0.5960 - val_loss: 0.6370 - val_accuracy: 0.8533
# Epoch 2/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.5814 - accuracy: 0.8415 - val_loss: 0.4882 - val_accuracy: 0.8958
# Epoch 3/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.4011 - accuracy: 0.8910 - val_loss: 0.3102 - val_accuracy: 0.8951
# Epoch 4/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2982 - accuracy: 0.8968 - val_loss: 0.2610 - val_accuracy: 0.9034
# Epoch 5/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2698 - accuracy: 0.9006 - val_loss: 0.2441 - val_accuracy: 0.9075
# Epoch 6/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2591 - accuracy: 0.9042 - val_loss: 0.2338 - val_accuracy: 0.9088
# Epoch 7/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2486 - accuracy: 0.9061 - val_loss: 0.2256 - val_accuracy: 0.9123
# Epoch 8/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2448 - accuracy: 0.9099 - val_loss: 0.2194 - val_accuracy: 0.9109
# Epoch 9/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2370 - accuracy: 0.9111 - val_loss: 0.2131 - val_accuracy: 0.9164
# Epoch 10/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2317 - accuracy: 0.9109 - val_loss: 0.2083 - val_accuracy: 0.9198
# Epoch 11/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2231 - accuracy: 0.9164 - val_loss: 0.2028 - val_accuracy: 0.9212
# Epoch 12/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2253 - accuracy: 0.9143 - val_loss: 0.1990 - val_accuracy: 0.9225
# Epoch 13/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2199 - accuracy: 0.9166 - val_loss: 0.1958 - val_accuracy: 0.9232
# Epoch 14/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2135 - accuracy: 0.9179 - val_loss: 0.1934 - val_accuracy: 0.9225
# Epoch 15/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2107 - accuracy: 0.9195 - val_loss: 0.1904 - val_accuracy: 0.9260
# Epoch 16/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2060 - accuracy: 0.9217 - val_loss: 0.1884 - val_accuracy: 0.9219
# Epoch 17/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2064 - accuracy: 0.9220 - val_loss: 0.1861 - val_accuracy: 0.9212
# Epoch 18/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1984 - accuracy: 0.9234 - val_loss: 0.1861 - val_accuracy: 0.9253
# Epoch 19/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2011 - accuracy: 0.9205 - val_loss: 0.1820 - val_accuracy: 0.9246
# Epoch 20/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1982 - accuracy: 0.9220 - val_loss: 0.1821 - val_accuracy: 0.9239
# Epoch 21/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.1968 - accuracy: 0.9239 - val_loss: 0.1795 - val_accuracy: 0.9267
# Epoch 22/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1929 - accuracy: 0.9232 - val_loss: 0.1778 - val_accuracy: 0.9273
# Epoch 23/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1924 - accuracy: 0.9270 - val_loss: 0.1772 - val_accuracy: 0.9321
# Epoch 24/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.1830 - accuracy: 0.9282 - val_loss: 0.1749 - val_accuracy: 0.9280
# Epoch 25/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1882 - accuracy: 0.9272 - val_loss: 0.1729 - val_accuracy: 0.9315
# Epoch 26/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1797 - accuracy: 0.9306 - val_loss: 0.1776 - val_accuracy: 0.9294
# Epoch 27/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.1847 - accuracy: 0.9327 - val_loss: 0.1699 - val_accuracy: 0.9383
# Epoch 28/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.1807 - accuracy: 0.9285 - val_loss: 0.1694 - val_accuracy: 0.9315
# Epoch 29/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1757 - accuracy: 0.9311 - val_loss: 0.1732 - val_accuracy: 0.9321
# Epoch 30/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1769 - accuracy: 0.9327 - val_loss: 0.1686 - val_accuracy: 0.9363
# Restoring model weights from the end of the best epoch: 30.
# 29/29 [==============================] - 1s 5ms/step
# Fold 2 Results: Accuracy=0.9408, Precision=0.9482, Recall=0.9150, F1=0.9313, ROC-AUC==0.9805, Time=67.27s
# --- Starting Fold 3/5 ---
# Model: "model_37"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 768)]                0         []
#  r)
#
#  tf.expand_dims_22 (TFOpLam  (None, 1, 768)               0         ['embedding_input[0][0]']
#  bda)
#
#  spatial_dropout1d_37 (Spat  (None, 1, 768)               0         ['tf.expand_dims_22[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_37 (CuDNNLSTM)   (None, 1, 100)               348000    ['spatial_dropout1d_37[0][0]']
#
#  bidirectional_74 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_37[0][0]']
#  ional)
#
#  bidirectional_75 (Bidirect  (None, 1, 128)               254848    ['bidirectional_74[0][0]']
#  ional)
#
#  cust_attention_32 (CustAtt  (None, 1, 128)               129       ['bidirectional_75[0][0]']
#  ention)
#
#  global_average_pooling1d_3  (None, 128)                  0         ['cust_attention_32[0][0]']
#  7 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_37 (G  (None, 128)                  0         ['cust_attention_32[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_37 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_37[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_37[0][0
#                                                                     ]']
#
#  dense_74 (Dense)            (None, 16)                   4112      ['concatenate_37[0][0]']
#
#  dropout_407 (Dropout)       (None, 16)                   0         ['dense_74[0][0]']
#
#  dense_75 (Dense)            (None, 1)                    17        ['dropout_407[0][0]']
#
# ==================================================================================================
# Total params: 1202818 (4.59 MB)
# Trainable params: 1202818 (4.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 14s 32ms/step - loss: 0.6776 - accuracy: 0.6986 - val_loss: 0.6519 - val_accuracy: 0.8828
# Epoch 2/30
# 92/92 [==============================] - 2s 21ms/step - loss: 0.6136 - accuracy: 0.8744 - val_loss: 0.5470 - val_accuracy: 0.8801
# Epoch 3/30
# 92/92 [==============================] - 2s 21ms/step - loss: 0.4566 - accuracy: 0.8898 - val_loss: 0.3498 - val_accuracy: 0.8924
# Epoch 4/30
# 92/92 [==============================] - 2s 21ms/step - loss: 0.3108 - accuracy: 0.9020 - val_loss: 0.2697 - val_accuracy: 0.9047
# Epoch 5/30
# 92/92 [==============================] - 2s 21ms/step - loss: 0.2739 - accuracy: 0.9035 - val_loss: 0.2619 - val_accuracy: 0.9095
# Epoch 6/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2631 - accuracy: 0.9061 - val_loss: 0.2551 - val_accuracy: 0.9116
# Epoch 7/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2553 - accuracy: 0.9068 - val_loss: 0.2427 - val_accuracy: 0.8897
# Epoch 8/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2420 - accuracy: 0.9083 - val_loss: 0.2449 - val_accuracy: 0.8849
# Epoch 9/30
# 92/92 [==============================] - 2s 22ms/step - loss: 0.2403 - accuracy: 0.9087 - val_loss: 0.2231 - val_accuracy: 0.9184
# Epoch 10/30
# 92/92 [==============================] - 2s 21ms/step - loss: 0.2317 - accuracy: 0.9124 - val_loss: 0.2136 - val_accuracy: 0.9191
# Epoch 11/30
# 92/92 [==============================] - 2s 21ms/step - loss: 0.2276 - accuracy: 0.9131 - val_loss: 0.2109 - val_accuracy: 0.9219
# Epoch 12/30
# 92/92 [==============================] - 2s 21ms/step - loss: 0.2251 - accuracy: 0.9142 - val_loss: 0.1991 - val_accuracy: 0.9267
# Epoch 13/30
# 92/92 [==============================] - 2s 21ms/step - loss: 0.2186 - accuracy: 0.9178 - val_loss: 0.1916 - val_accuracy: 0.9301
# Epoch 14/30
# 92/92 [==============================] - 2s 21ms/step - loss: 0.2133 - accuracy: 0.9202 - val_loss: 0.1978 - val_accuracy: 0.9328
# Epoch 15/30
# 92/92 [==============================] - 2s 21ms/step - loss: 0.2146 - accuracy: 0.9202 - val_loss: 0.1829 - val_accuracy: 0.9369
# Epoch 16/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2061 - accuracy: 0.9217 - val_loss: 0.1855 - val_accuracy: 0.9363
# Epoch 17/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2080 - accuracy: 0.9219 - val_loss: 0.1778 - val_accuracy: 0.9390
# Epoch 18/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2056 - accuracy: 0.9237 - val_loss: 0.1772 - val_accuracy: 0.9363
# Epoch 19/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2013 - accuracy: 0.9246 - val_loss: 0.1804 - val_accuracy: 0.9376
# Epoch 20/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1963 - accuracy: 0.9229 - val_loss: 0.1724 - val_accuracy: 0.9383
# Epoch 21/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1974 - accuracy: 0.9234 - val_loss: 0.1842 - val_accuracy: 0.9349
# Epoch 22/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.1925 - accuracy: 0.9267 - val_loss: 0.1646 - val_accuracy: 0.9424
# Epoch 23/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1926 - accuracy: 0.9284 - val_loss: 0.1647 - val_accuracy: 0.9424
# Epoch 24/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1862 - accuracy: 0.9282 - val_loss: 0.1632 - val_accuracy: 0.9411
# Epoch 25/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1898 - accuracy: 0.9272 - val_loss: 0.1619 - val_accuracy: 0.9404
# Epoch 26/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.1828 - accuracy: 0.9296 - val_loss: 0.1636 - val_accuracy: 0.9390
# Epoch 27/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1857 - accuracy: 0.9296 - val_loss: 0.1578 - val_accuracy: 0.9445
# Epoch 28/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1815 - accuracy: 0.9275 - val_loss: 0.1616 - val_accuracy: 0.9417
# Epoch 29/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1784 - accuracy: 0.9315 - val_loss: 0.1552 - val_accuracy: 0.9438
# Epoch 30/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1751 - accuracy: 0.9347 - val_loss: 0.1547 - val_accuracy: 0.9452
# Restoring model weights from the end of the best epoch: 30.
# 29/29 [==============================] - 1s 5ms/step
# Fold 3 Results: Accuracy=0.9265, Precision=0.9302, Recall=0.9000, F1=0.9149, ROC-AUC==0.9772, Time=68.66s
# --- Starting Fold 4/5 ---
# Model: "model_38"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 768)]                0         []
#  r)
#
#  tf.expand_dims_23 (TFOpLam  (None, 1, 768)               0         ['embedding_input[0][0]']
#  bda)
#
#  spatial_dropout1d_38 (Spat  (None, 1, 768)               0         ['tf.expand_dims_23[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_38 (CuDNNLSTM)   (None, 1, 100)               348000    ['spatial_dropout1d_38[0][0]']
#
#  bidirectional_76 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_38[0][0]']
#  ional)
#
#  bidirectional_77 (Bidirect  (None, 1, 128)               254848    ['bidirectional_76[0][0]']
#  ional)
#
#  cust_attention_33 (CustAtt  (None, 1, 128)               129       ['bidirectional_77[0][0]']
#  ention)
#
#  global_average_pooling1d_3  (None, 128)                  0         ['cust_attention_33[0][0]']
#  8 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_38 (G  (None, 128)                  0         ['cust_attention_33[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_38 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_38[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_38[0][0
#                                                                     ]']
#
#  dense_76 (Dense)            (None, 16)                   4112      ['concatenate_38[0][0]']
#
#  dropout_408 (Dropout)       (None, 16)                   0         ['dense_76[0][0]']
#
#  dense_77 (Dense)            (None, 1)                    17        ['dropout_408[0][0]']
#
# ==================================================================================================
# Total params: 1202818 (4.59 MB)
# Trainable params: 1202818 (4.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 13s 30ms/step - loss: 0.6591 - accuracy: 0.7534 - val_loss: 0.6029 - val_accuracy: 0.8705
# Epoch 2/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.5209 - accuracy: 0.8806 - val_loss: 0.4223 - val_accuracy: 0.8759
# Epoch 3/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.3484 - accuracy: 0.8927 - val_loss: 0.3121 - val_accuracy: 0.8876
# Epoch 4/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2832 - accuracy: 0.8987 - val_loss: 0.2984 - val_accuracy: 0.8951
# Epoch 5/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2685 - accuracy: 0.9004 - val_loss: 0.2954 - val_accuracy: 0.8725
# Epoch 6/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2549 - accuracy: 0.9047 - val_loss: 0.2903 - val_accuracy: 0.8746
# Epoch 7/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2427 - accuracy: 0.9111 - val_loss: 0.3286 - val_accuracy: 0.8602
# Epoch 8/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2398 - accuracy: 0.9080 - val_loss: 0.3246 - val_accuracy: 0.8643
# Epoch 9/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2305 - accuracy: 0.9157 - val_loss: 0.3239 - val_accuracy: 0.8663
# Epoch 10/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2329 - accuracy: 0.9118 - val_loss: 0.2796 - val_accuracy: 0.8780
# Epoch 11/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2240 - accuracy: 0.9124 - val_loss: 0.3315 - val_accuracy: 0.8588
# Epoch 12/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2203 - accuracy: 0.9159 - val_loss: 0.3011 - val_accuracy: 0.8670
# Epoch 13/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2172 - accuracy: 0.9207 - val_loss: 0.3070 - val_accuracy: 0.8615
# Epoch 14/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2112 - accuracy: 0.9208 - val_loss: 0.3591 - val_accuracy: 0.8465
# Epoch 15/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2086 - accuracy: 0.9248 - val_loss: 0.3078 - val_accuracy: 0.8595
# Epoch 16/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2077 - accuracy: 0.9169 - val_loss: 0.3384 - val_accuracy: 0.8561
# Epoch 17/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2037 - accuracy: 0.9258 - val_loss: 0.2840 - val_accuracy: 0.8670
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 29/29 [==============================] - 1s 5ms/step
# Fold 4 Results: Accuracy=0.8980, Precision=0.8495, Recall=0.9324, F1=0.8890, ROC-AUC==0.9748, Time=42.32s
# --- Starting Fold 5/5 ---
# Model: "model_39"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 768)]                0         []
#  r)
#
#  tf.expand_dims_24 (TFOpLam  (None, 1, 768)               0         ['embedding_input[0][0]']
#  bda)
#
#  spatial_dropout1d_39 (Spat  (None, 1, 768)               0         ['tf.expand_dims_24[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_39 (CuDNNLSTM)   (None, 1, 100)               348000    ['spatial_dropout1d_39[0][0]']
#
#  bidirectional_78 (Bidirect  (None, 1, 256)               595712    ['cu_dnnlstm_39[0][0]']
#  ional)
#
#  bidirectional_79 (Bidirect  (None, 1, 128)               254848    ['bidirectional_78[0][0]']
#  ional)
#
#  cust_attention_34 (CustAtt  (None, 1, 128)               129       ['bidirectional_79[0][0]']
#  ention)
#
#  global_average_pooling1d_3  (None, 128)                  0         ['cust_attention_34[0][0]']
#  9 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_39 (G  (None, 128)                  0         ['cust_attention_34[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_39 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_39[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_39[0][0
#                                                                     ]']
#
#  dense_78 (Dense)            (None, 16)                   4112      ['concatenate_39[0][0]']
#
#  dropout_409 (Dropout)       (None, 16)                   0         ['dense_78[0][0]']
#
#  dense_79 (Dense)            (None, 1)                    17        ['dropout_409[0][0]']
#
# ==================================================================================================
# Total params: 1202818 (4.59 MB)
# Trainable params: 1202818 (4.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 13s 30ms/step - loss: 0.6657 - accuracy: 0.7440 - val_loss: 0.6218 - val_accuracy: 0.7712
# Epoch 2/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.5515 - accuracy: 0.8497 - val_loss: 0.4677 - val_accuracy: 0.8322
# Epoch 3/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.4071 - accuracy: 0.8835 - val_loss: 0.3453 - val_accuracy: 0.8986
# Epoch 4/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.3212 - accuracy: 0.8927 - val_loss: 0.2739 - val_accuracy: 0.9164
# Epoch 5/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2851 - accuracy: 0.8982 - val_loss: 0.2537 - val_accuracy: 0.9178
# Epoch 6/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2708 - accuracy: 0.8979 - val_loss: 0.2391 - val_accuracy: 0.9199
# Epoch 7/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2621 - accuracy: 0.8992 - val_loss: 0.2395 - val_accuracy: 0.9240
# Epoch 8/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2508 - accuracy: 0.9046 - val_loss: 0.2213 - val_accuracy: 0.9281
# Epoch 9/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2448 - accuracy: 0.9075 - val_loss: 0.2129 - val_accuracy: 0.9342
# Epoch 10/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2357 - accuracy: 0.9102 - val_loss: 0.2192 - val_accuracy: 0.9082
# Epoch 11/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2336 - accuracy: 0.9088 - val_loss: 0.2057 - val_accuracy: 0.9342
# Epoch 12/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2309 - accuracy: 0.9104 - val_loss: 0.2205 - val_accuracy: 0.9062
# Epoch 13/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2252 - accuracy: 0.9152 - val_loss: 0.1981 - val_accuracy: 0.9404
# Epoch 14/30
# 92/92 [==============================] - 2s 18ms/step - loss: 0.2201 - accuracy: 0.9183 - val_loss: 0.1993 - val_accuracy: 0.9116
# Epoch 15/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2178 - accuracy: 0.9169 - val_loss: 0.1994 - val_accuracy: 0.9110
# Epoch 16/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2118 - accuracy: 0.9215 - val_loss: 0.2126 - val_accuracy: 0.9062
# Epoch 17/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2100 - accuracy: 0.9198 - val_loss: 0.1966 - val_accuracy: 0.9137
# Epoch 18/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2066 - accuracy: 0.9214 - val_loss: 0.2109 - val_accuracy: 0.9055
# Epoch 19/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.2076 - accuracy: 0.9208 - val_loss: 0.1993 - val_accuracy: 0.9103
# Epoch 20/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2005 - accuracy: 0.9220 - val_loss: 0.1793 - val_accuracy: 0.9445
# Epoch 21/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.2018 - accuracy: 0.9244 - val_loss: 0.1759 - val_accuracy: 0.9432
# Epoch 22/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1968 - accuracy: 0.9239 - val_loss: 0.1751 - val_accuracy: 0.9425
# Epoch 23/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1917 - accuracy: 0.9285 - val_loss: 0.1716 - val_accuracy: 0.9438
# Epoch 24/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1915 - accuracy: 0.9236 - val_loss: 0.1836 - val_accuracy: 0.9356
# Epoch 25/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.1911 - accuracy: 0.9301 - val_loss: 0.1722 - val_accuracy: 0.9432
# Epoch 26/30
# 92/92 [==============================] - 2s 20ms/step - loss: 0.1831 - accuracy: 0.9299 - val_loss: 0.1899 - val_accuracy: 0.9075
# Epoch 27/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1849 - accuracy: 0.9277 - val_loss: 0.1695 - val_accuracy: 0.9404
# Epoch 28/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1773 - accuracy: 0.9301 - val_loss: 0.1764 - val_accuracy: 0.9370
# Epoch 29/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1784 - accuracy: 0.9321 - val_loss: 0.1663 - val_accuracy: 0.9397
# Epoch 30/30
# 92/92 [==============================] - 2s 19ms/step - loss: 0.1767 - accuracy: 0.9330 - val_loss: 0.1690 - val_accuracy: 0.9390
# Restoring model weights from the end of the best epoch: 29.
# 29/29 [==============================] - 1s 5ms/step
# Fold 5 Results: Accuracy=0.9227, Precision=0.8889, Recall=0.9412, F1=0.9143, ROC-AUC==0.9775, Time=66.48s
# --- Analysis for: tcn_model_mb_precompute_pool - Twitter ---
# --------------------------------------------------
#
# [Raw Results per Fold]
#    Fold  Accuracy  Precision    Recall  F1-Score   ROC-AUC  Training Time (s)  Dataset
# 0     1  0.929825   0.957766  0.878750  0.916558  0.982493          68.232956  Twitter
# 1     2  0.940789   0.948187  0.915000  0.931298  0.980543          67.269093  Twitter
# 2     3  0.926535   0.930233  0.900000  0.914867  0.977196          68.658186  Twitter
# 3     4  0.898026   0.849487  0.932416  0.889021  0.974787          42.318593  Twitter
# 4     5  0.922655   0.888889  0.941176  0.914286  0.977511          66.480725  Twitter
#
# [Summary Statistics]
#                         mean        std
# Accuracy            0.923566   0.015794
# Precision           0.914912   0.045100
# Recall              0.913468   0.025079
# F1-Score            0.913206   0.015226
# ROC-AUC             0.978506   0.003024
# Training Time (s)  62.591911  11.364720
# --------------------------------------------------
#
# [Total Training Time]: 312.9595527648926 seconds
# 19139

# %%
#tcn_model_mb_precompute_seqOut
tokenizer = AutoTokenizer.from_pretrained("mental/mental-bert-base-uncased")
model = AutoModel.from_pretrained("mental/mental-bert-base-uncased")
X_embeddings = extract_feature_mb_sequence(tokenizer=tokenizer, model=model, texts=X)

result, history_list = run_cross_validation(FOLDS, X_embeddings, y, tcn_model_mb_precompute_seqOut,False)
variant_name = "tcn_model_mb_precompute_seqOut"
result['Variant'] = variant_name
result['Dataset'] = 'Twitter'
all_results.append(result)
analyze_cv_results(result)

for hist in history_list:
    hist['Variant'] = variant_name
    all_histories.extend(history_list)

output_filename = f'/content/drive/MyDrive/final_FYP_results/{folder_name}/{variant_name}_twitter_result.csv'
result.to_csv(output_filename, index=False)
del output_filename
del history_list
del result
gc.collect()
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at mental/mental-bert-base-uncased and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Starting BERT feature extraction...
# Processed 9119/9119 texts
# Done
# --- Starting Fold 1/5 ---
# Model: "model_40"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 128, 768)]           0         []
#  r)
#
#  spatial_dropout1d_40 (Spat  (None, 128, 768)             0         ['embedding_input[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_40 (CuDNNLSTM)   (None, 128, 100)             348000    ['spatial_dropout1d_40[0][0]']
#
#  bidirectional_80 (Bidirect  (None, 128, 256)             595712    ['cu_dnnlstm_40[0][0]']
#  ional)
#
#  bidirectional_81 (Bidirect  (None, 128, 128)             254848    ['bidirectional_80[0][0]']
#  ional)
#
#  cust_attention_35 (CustAtt  (None, 128, 128)             256       ['bidirectional_81[0][0]']
#  ention)
#
#  global_average_pooling1d_4  (None, 128)                  0         ['cust_attention_35[0][0]']
#  0 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_40 (G  (None, 128)                  0         ['cust_attention_35[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_40 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_40[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_40[0][0
#                                                                     ]']
#
#  dense_80 (Dense)            (None, 16)                   4112      ['concatenate_40[0][0]']
#
#  dropout_410 (Dropout)       (None, 16)                   0         ['dense_80[0][0]']
#
#  dense_81 (Dense)            (None, 1)                    17        ['dropout_410[0][0]']
#
# ==================================================================================================
# Total params: 1202945 (4.59 MB)
# Trainable params: 1202945 (4.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 16s 52ms/step - loss: 0.6883 - accuracy: 0.5613 - val_loss: 0.6857 - val_accuracy: 0.5613
# Epoch 2/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.6838 - accuracy: 0.5617 - val_loss: 0.6807 - val_accuracy: 0.5613
# Epoch 3/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.6778 - accuracy: 0.5617 - val_loss: 0.6728 - val_accuracy: 0.5613
# Epoch 4/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.6671 - accuracy: 0.5617 - val_loss: 0.6547 - val_accuracy: 0.5613
# Epoch 5/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.6006 - accuracy: 0.5641 - val_loss: 0.5488 - val_accuracy: 0.5620
# Epoch 6/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.5142 - accuracy: 0.7916 - val_loss: 0.4839 - val_accuracy: 0.8526
# Epoch 7/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.4499 - accuracy: 0.8727 - val_loss: 0.4450 - val_accuracy: 0.8650
# Epoch 8/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.4021 - accuracy: 0.8747 - val_loss: 0.3967 - val_accuracy: 0.8732
# Epoch 9/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.3613 - accuracy: 0.8739 - val_loss: 0.3601 - val_accuracy: 0.8807
# Epoch 10/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.3340 - accuracy: 0.8826 - val_loss: 0.2984 - val_accuracy: 0.8869
# Epoch 11/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.3124 - accuracy: 0.8910 - val_loss: 0.2718 - val_accuracy: 0.9027
# Epoch 12/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.2757 - accuracy: 0.8970 - val_loss: 0.2562 - val_accuracy: 0.9020
# Epoch 13/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2482 - accuracy: 0.9080 - val_loss: 0.2328 - val_accuracy: 0.9088
# Epoch 14/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2472 - accuracy: 0.9099 - val_loss: 0.2342 - val_accuracy: 0.9102
# Epoch 15/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.2327 - accuracy: 0.9123 - val_loss: 0.2338 - val_accuracy: 0.9123
# Epoch 16/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2238 - accuracy: 0.9157 - val_loss: 0.2418 - val_accuracy: 0.9130
# Epoch 17/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2095 - accuracy: 0.9210 - val_loss: 0.2370 - val_accuracy: 0.9136
# Epoch 18/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2106 - accuracy: 0.9208 - val_loss: 0.2744 - val_accuracy: 0.9013
# Epoch 19/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2034 - accuracy: 0.9232 - val_loss: 0.2413 - val_accuracy: 0.9130
# Epoch 20/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1941 - accuracy: 0.9263 - val_loss: 0.2109 - val_accuracy: 0.9205
# Epoch 21/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1983 - accuracy: 0.9246 - val_loss: 0.2146 - val_accuracy: 0.9191
# Epoch 22/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.1830 - accuracy: 0.9287 - val_loss: 0.1967 - val_accuracy: 0.9280
# Epoch 23/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1841 - accuracy: 0.9294 - val_loss: 0.2375 - val_accuracy: 0.9130
# Epoch 24/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1836 - accuracy: 0.9320 - val_loss: 0.2615 - val_accuracy: 0.9109
# Epoch 25/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1763 - accuracy: 0.9316 - val_loss: 0.2132 - val_accuracy: 0.9253
# Epoch 26/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1742 - accuracy: 0.9347 - val_loss: 0.2149 - val_accuracy: 0.9239
# Epoch 27/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1690 - accuracy: 0.9380 - val_loss: 0.2202 - val_accuracy: 0.9225
# Epoch 28/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.1702 - accuracy: 0.9345 - val_loss: 0.2154 - val_accuracy: 0.9253
# Epoch 29/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1668 - accuracy: 0.9349 - val_loss: 0.2270 - val_accuracy: 0.9239
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 22.
# 29/29 [==============================] - 2s 13ms/step
# Fold 1 Results: Accuracy=0.9353, Precision=0.9596, Recall=0.8900, F1=0.9235, ROC-AUC==0.9838, Time=123.38s
# --- Starting Fold 2/5 ---
# Model: "model_41"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 128, 768)]           0         []
#  r)
#
#  spatial_dropout1d_41 (Spat  (None, 128, 768)             0         ['embedding_input[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_41 (CuDNNLSTM)   (None, 128, 100)             348000    ['spatial_dropout1d_41[0][0]']
#
#  bidirectional_82 (Bidirect  (None, 128, 256)             595712    ['cu_dnnlstm_41[0][0]']
#  ional)
#
#  bidirectional_83 (Bidirect  (None, 128, 128)             254848    ['bidirectional_82[0][0]']
#  ional)
#
#  cust_attention_36 (CustAtt  (None, 128, 128)             256       ['bidirectional_83[0][0]']
#  ention)
#
#  global_average_pooling1d_4  (None, 128)                  0         ['cust_attention_36[0][0]']
#  1 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_41 (G  (None, 128)                  0         ['cust_attention_36[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_41 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_41[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_41[0][0
#                                                                     ]']
#
#  dense_82 (Dense)            (None, 16)                   4112      ['concatenate_41[0][0]']
#
#  dropout_411 (Dropout)       (None, 16)                   0         ['dense_82[0][0]']
#
#  dense_83 (Dense)            (None, 1)                    17        ['dropout_411[0][0]']
#
# ==================================================================================================
# Total params: 1202945 (4.59 MB)
# Trainable params: 1202945 (4.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 14s 47ms/step - loss: 0.6874 - accuracy: 0.5619 - val_loss: 0.6829 - val_accuracy: 0.5613
# Epoch 2/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.6782 - accuracy: 0.5617 - val_loss: 0.6650 - val_accuracy: 0.5613
# Epoch 3/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.6330 - accuracy: 0.5619 - val_loss: 0.5688 - val_accuracy: 0.5613
# Epoch 4/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.5427 - accuracy: 0.7346 - val_loss: 0.4845 - val_accuracy: 0.8732
# Epoch 5/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.5066 - accuracy: 0.8381 - val_loss: 0.4391 - val_accuracy: 0.8801
# Epoch 6/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.3850 - accuracy: 0.8615 - val_loss: 0.3092 - val_accuracy: 0.8780
# Epoch 7/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.3145 - accuracy: 0.8804 - val_loss: 0.2456 - val_accuracy: 0.9040
# Epoch 8/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.2770 - accuracy: 0.8929 - val_loss: 0.2249 - val_accuracy: 0.9116
# Epoch 9/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2514 - accuracy: 0.9032 - val_loss: 0.2069 - val_accuracy: 0.9130
# Epoch 10/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2311 - accuracy: 0.9094 - val_loss: 0.1964 - val_accuracy: 0.9205
# Epoch 11/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.2165 - accuracy: 0.9159 - val_loss: 0.2119 - val_accuracy: 0.9178
# Epoch 12/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2082 - accuracy: 0.9186 - val_loss: 0.1795 - val_accuracy: 0.9287
# Epoch 13/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.1983 - accuracy: 0.9203 - val_loss: 0.1676 - val_accuracy: 0.9253
# Epoch 14/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1942 - accuracy: 0.9248 - val_loss: 0.1686 - val_accuracy: 0.9315
# Epoch 15/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1919 - accuracy: 0.9258 - val_loss: 0.1689 - val_accuracy: 0.9273
# Epoch 16/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1785 - accuracy: 0.9284 - val_loss: 0.1581 - val_accuracy: 0.9328
# Epoch 17/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1719 - accuracy: 0.9308 - val_loss: 0.1655 - val_accuracy: 0.9280
# Epoch 18/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1698 - accuracy: 0.9347 - val_loss: 0.1521 - val_accuracy: 0.9335
# Epoch 19/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1636 - accuracy: 0.9361 - val_loss: 0.1711 - val_accuracy: 0.9301
# Epoch 20/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1588 - accuracy: 0.9383 - val_loss: 0.1479 - val_accuracy: 0.9376
# Epoch 21/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1545 - accuracy: 0.9387 - val_loss: 0.1489 - val_accuracy: 0.9383
# Epoch 22/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1525 - accuracy: 0.9395 - val_loss: 0.1656 - val_accuracy: 0.9315
# Epoch 23/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1545 - accuracy: 0.9385 - val_loss: 0.1619 - val_accuracy: 0.9349
# Epoch 24/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1471 - accuracy: 0.9443 - val_loss: 0.1464 - val_accuracy: 0.9411
# Epoch 25/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1425 - accuracy: 0.9445 - val_loss: 0.1597 - val_accuracy: 0.9369
# Epoch 26/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1406 - accuracy: 0.9455 - val_loss: 0.1395 - val_accuracy: 0.9390
# Epoch 27/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1442 - accuracy: 0.9433 - val_loss: 0.1508 - val_accuracy: 0.9404
# Epoch 28/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1464 - accuracy: 0.9424 - val_loss: 0.1503 - val_accuracy: 0.9397
# Epoch 29/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1350 - accuracy: 0.9450 - val_loss: 0.1495 - val_accuracy: 0.9417
# Epoch 30/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1326 - accuracy: 0.9459 - val_loss: 0.1444 - val_accuracy: 0.9431
# Restoring model weights from the end of the best epoch: 26.
# 29/29 [==============================] - 2s 13ms/step
# Fold 2 Results: Accuracy=0.9413, Precision=0.9471, Recall=0.9175, F1=0.9321, ROC-AUC==0.9846, Time=123.77s
# --- Starting Fold 3/5 ---
# Model: "model_42"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 128, 768)]           0         []
#  r)
#
#  spatial_dropout1d_42 (Spat  (None, 128, 768)             0         ['embedding_input[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_42 (CuDNNLSTM)   (None, 128, 100)             348000    ['spatial_dropout1d_42[0][0]']
#
#  bidirectional_84 (Bidirect  (None, 128, 256)             595712    ['cu_dnnlstm_42[0][0]']
#  ional)
#
#  bidirectional_85 (Bidirect  (None, 128, 128)             254848    ['bidirectional_84[0][0]']
#  ional)
#
#  cust_attention_37 (CustAtt  (None, 128, 128)             256       ['bidirectional_85[0][0]']
#  ention)
#
#  global_average_pooling1d_4  (None, 128)                  0         ['cust_attention_37[0][0]']
#  2 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_42 (G  (None, 128)                  0         ['cust_attention_37[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_42 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_42[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_42[0][0
#                                                                     ]']
#
#  dense_84 (Dense)            (None, 16)                   4112      ['concatenate_42[0][0]']
#
#  dropout_412 (Dropout)       (None, 16)                   0         ['dense_84[0][0]']
#
#  dense_85 (Dense)            (None, 1)                    17        ['dropout_412[0][0]']
#
# ==================================================================================================
# Total params: 1202945 (4.59 MB)
# Trainable params: 1202945 (4.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 15s 49ms/step - loss: 0.6906 - accuracy: 0.5627 - val_loss: 0.6851 - val_accuracy: 0.5751
# Epoch 2/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.6794 - accuracy: 0.6206 - val_loss: 0.6691 - val_accuracy: 0.7951
# Epoch 3/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.6503 - accuracy: 0.8153 - val_loss: 0.6200 - val_accuracy: 0.7279
# Epoch 4/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.5113 - accuracy: 0.8345 - val_loss: 0.4972 - val_accuracy: 0.8163
# Epoch 5/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.4218 - accuracy: 0.8727 - val_loss: 0.3671 - val_accuracy: 0.8746
# Epoch 6/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.3889 - accuracy: 0.8794 - val_loss: 0.3622 - val_accuracy: 0.8807
# Epoch 7/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.3412 - accuracy: 0.8837 - val_loss: 0.3049 - val_accuracy: 0.8951
# Epoch 8/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.3085 - accuracy: 0.8915 - val_loss: 0.2752 - val_accuracy: 0.9034
# Epoch 9/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.3251 - accuracy: 0.8778 - val_loss: 0.2779 - val_accuracy: 0.9027
# Epoch 10/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2711 - accuracy: 0.9010 - val_loss: 0.2823 - val_accuracy: 0.9082
# Epoch 11/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2935 - accuracy: 0.8938 - val_loss: 0.2607 - val_accuracy: 0.9040
# Epoch 12/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2616 - accuracy: 0.9051 - val_loss: 0.2304 - val_accuracy: 0.9184
# Epoch 13/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2511 - accuracy: 0.9076 - val_loss: 0.2201 - val_accuracy: 0.9239
# Epoch 14/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2395 - accuracy: 0.9133 - val_loss: 0.2029 - val_accuracy: 0.9267
# Epoch 15/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2415 - accuracy: 0.9109 - val_loss: 0.2064 - val_accuracy: 0.9246
# Epoch 16/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2468 - accuracy: 0.9095 - val_loss: 0.2140 - val_accuracy: 0.9116
# Epoch 17/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2353 - accuracy: 0.9159 - val_loss: 0.1953 - val_accuracy: 0.9280
# Epoch 18/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.2379 - accuracy: 0.9138 - val_loss: 0.2318 - val_accuracy: 0.9287
# Epoch 19/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2230 - accuracy: 0.9166 - val_loss: 0.2033 - val_accuracy: 0.9198
# Epoch 20/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2085 - accuracy: 0.9222 - val_loss: 0.1778 - val_accuracy: 0.9411
# Epoch 21/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.2106 - accuracy: 0.9229 - val_loss: 0.2054 - val_accuracy: 0.9356
# Epoch 22/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2019 - accuracy: 0.9253 - val_loss: 0.1748 - val_accuracy: 0.9445
# Epoch 23/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1966 - accuracy: 0.9270 - val_loss: 0.1883 - val_accuracy: 0.9397
# Epoch 24/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2027 - accuracy: 0.9227 - val_loss: 0.1690 - val_accuracy: 0.9397
# Epoch 25/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1857 - accuracy: 0.9330 - val_loss: 0.1631 - val_accuracy: 0.9438
# Epoch 26/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.3032 - accuracy: 0.8891 - val_loss: 0.2145 - val_accuracy: 0.9184
# Epoch 27/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2116 - accuracy: 0.9190 - val_loss: 0.1753 - val_accuracy: 0.9486
# Epoch 28/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2064 - accuracy: 0.9207 - val_loss: 0.1680 - val_accuracy: 0.9459
# Epoch 29/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1926 - accuracy: 0.9255 - val_loss: 0.1580 - val_accuracy: 0.9500
# Epoch 30/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.1887 - accuracy: 0.9277 - val_loss: 0.1575 - val_accuracy: 0.9479
# Restoring model weights from the end of the best epoch: 30.
# 29/29 [==============================] - 2s 13ms/step
# Fold 3 Results: Accuracy=0.9172, Precision=0.9113, Recall=0.8988, F1=0.9050, ROC-AUC==0.9707, Time=125.23s
# --- Starting Fold 4/5 ---
# Model: "model_43"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 128, 768)]           0         []
#  r)
#
#  spatial_dropout1d_43 (Spat  (None, 128, 768)             0         ['embedding_input[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_43 (CuDNNLSTM)   (None, 128, 100)             348000    ['spatial_dropout1d_43[0][0]']
#
#  bidirectional_86 (Bidirect  (None, 128, 256)             595712    ['cu_dnnlstm_43[0][0]']
#  ional)
#
#  bidirectional_87 (Bidirect  (None, 128, 128)             254848    ['bidirectional_86[0][0]']
#  ional)
#
#  cust_attention_38 (CustAtt  (None, 128, 128)             256       ['bidirectional_87[0][0]']
#  ention)
#
#  global_average_pooling1d_4  (None, 128)                  0         ['cust_attention_38[0][0]']
#  3 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_43 (G  (None, 128)                  0         ['cust_attention_38[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_43 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_43[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_43[0][0
#                                                                     ]']
#
#  dense_86 (Dense)            (None, 16)                   4112      ['concatenate_43[0][0]']
#
#  dropout_413 (Dropout)       (None, 16)                   0         ['dense_86[0][0]']
#
#  dense_87 (Dense)            (None, 1)                    17        ['dropout_413[0][0]']
#
# ==================================================================================================
# Total params: 1202945 (4.59 MB)
# Trainable params: 1202945 (4.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 15s 49ms/step - loss: 0.6548 - accuracy: 0.5619 - val_loss: 0.5985 - val_accuracy: 0.5613
# Epoch 2/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.5349 - accuracy: 0.7135 - val_loss: 0.5277 - val_accuracy: 0.7916
# Epoch 3/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.4471 - accuracy: 0.8741 - val_loss: 0.4438 - val_accuracy: 0.8341
# Epoch 4/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.3817 - accuracy: 0.8890 - val_loss: 0.4672 - val_accuracy: 0.7868
# Epoch 5/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.3242 - accuracy: 0.8950 - val_loss: 0.3847 - val_accuracy: 0.8465
# Epoch 6/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.2696 - accuracy: 0.9061 - val_loss: 0.4308 - val_accuracy: 0.8095
# Epoch 7/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2446 - accuracy: 0.9087 - val_loss: 0.5826 - val_accuracy: 0.7402
# Epoch 8/30
# 92/92 [==============================] - 4s 38ms/step - loss: 0.2301 - accuracy: 0.9159 - val_loss: 0.5154 - val_accuracy: 0.7724
# Epoch 9/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.2152 - accuracy: 0.9195 - val_loss: 0.5026 - val_accuracy: 0.7786
# Epoch 10/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.2153 - accuracy: 0.9184 - val_loss: 0.3471 - val_accuracy: 0.8458
# Epoch 11/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2033 - accuracy: 0.9229 - val_loss: 0.2968 - val_accuracy: 0.8821
# Epoch 12/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1932 - accuracy: 0.9255 - val_loss: 0.5398 - val_accuracy: 0.7608
# Epoch 13/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.1902 - accuracy: 0.9284 - val_loss: 0.3990 - val_accuracy: 0.8478
# Epoch 14/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1792 - accuracy: 0.9337 - val_loss: 0.3338 - val_accuracy: 0.8753
# Epoch 15/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1775 - accuracy: 0.9323 - val_loss: 0.3133 - val_accuracy: 0.8801
# Epoch 16/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1662 - accuracy: 0.9361 - val_loss: 0.3047 - val_accuracy: 0.8828
# Epoch 17/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1673 - accuracy: 0.9395 - val_loss: 0.4140 - val_accuracy: 0.8341
# Epoch 18/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1654 - accuracy: 0.9366 - val_loss: 0.2256 - val_accuracy: 0.9082
# Epoch 19/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1578 - accuracy: 0.9404 - val_loss: 0.3391 - val_accuracy: 0.8657
# Epoch 20/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.1519 - accuracy: 0.9409 - val_loss: 0.2167 - val_accuracy: 0.9143
# Epoch 21/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1554 - accuracy: 0.9402 - val_loss: 0.2255 - val_accuracy: 0.9047
# Epoch 22/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1476 - accuracy: 0.9448 - val_loss: 0.2666 - val_accuracy: 0.8938
# Epoch 23/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1438 - accuracy: 0.9476 - val_loss: 0.2789 - val_accuracy: 0.8821
# Epoch 24/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1414 - accuracy: 0.9450 - val_loss: 0.5708 - val_accuracy: 0.7711
# Epoch 25/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1418 - accuracy: 0.9467 - val_loss: 0.2221 - val_accuracy: 0.9075
# Epoch 26/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.1375 - accuracy: 0.9464 - val_loss: 0.1961 - val_accuracy: 0.9239
# Epoch 27/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.1390 - accuracy: 0.9479 - val_loss: 0.2016 - val_accuracy: 0.9212
# Epoch 28/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1271 - accuracy: 0.9513 - val_loss: 0.4702 - val_accuracy: 0.7999
# Epoch 29/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1300 - accuracy: 0.9493 - val_loss: 0.2408 - val_accuracy: 0.9082
# Epoch 30/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1287 - accuracy: 0.9489 - val_loss: 0.2078 - val_accuracy: 0.9212
# Restoring model weights from the end of the best epoch: 26.
# 29/29 [==============================] - 2s 13ms/step
# Fold 4 Results: Accuracy=0.9496, Precision=0.9447, Recall=0.9399, F1=0.9423, ROC-AUC==0.9879, Time=125.35s
# --- Starting Fold 5/5 ---
# Model: "model_44"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  embedding_input (InputLaye  [(None, 128, 768)]           0         []
#  r)
#
#  spatial_dropout1d_44 (Spat  (None, 128, 768)             0         ['embedding_input[0][0]']
#  ialDropout1D)
#
#  cu_dnnlstm_44 (CuDNNLSTM)   (None, 128, 100)             348000    ['spatial_dropout1d_44[0][0]']
#
#  bidirectional_88 (Bidirect  (None, 128, 256)             595712    ['cu_dnnlstm_44[0][0]']
#  ional)
#
#  bidirectional_89 (Bidirect  (None, 128, 128)             254848    ['bidirectional_88[0][0]']
#  ional)
#
#  cust_attention_39 (CustAtt  (None, 128, 128)             256       ['bidirectional_89[0][0]']
#  ention)
#
#  global_average_pooling1d_4  (None, 128)                  0         ['cust_attention_39[0][0]']
#  4 (GlobalAveragePooling1D)
#
#  global_max_pooling1d_44 (G  (None, 128)                  0         ['cust_attention_39[0][0]']
#  lobalMaxPooling1D)
#
#  concatenate_44 (Concatenat  (None, 256)                  0         ['global_average_pooling1d_44[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling1d_44[0][0
#                                                                     ]']
#
#  dense_88 (Dense)            (None, 16)                   4112      ['concatenate_44[0][0]']
#
#  dropout_414 (Dropout)       (None, 16)                   0         ['dense_88[0][0]']
#
#  dense_89 (Dense)            (None, 1)                    17        ['dropout_414[0][0]']
#
# ==================================================================================================
# Total params: 1202945 (4.59 MB)
# Trainable params: 1202945 (4.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/30
# 92/92 [==============================] - 15s 49ms/step - loss: 0.6860 - accuracy: 0.5689 - val_loss: 0.6774 - val_accuracy: 0.5616
# Epoch 2/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.6661 - accuracy: 0.6343 - val_loss: 0.6413 - val_accuracy: 0.8733
# Epoch 3/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.5602 - accuracy: 0.8511 - val_loss: 0.5883 - val_accuracy: 0.7329
# Epoch 4/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.4900 - accuracy: 0.8518 - val_loss: 0.4081 - val_accuracy: 0.8295
# Epoch 5/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.3824 - accuracy: 0.8520 - val_loss: 0.3819 - val_accuracy: 0.8486
# Epoch 6/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.3256 - accuracy: 0.8741 - val_loss: 0.3018 - val_accuracy: 0.8733
# Epoch 7/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.2710 - accuracy: 0.8984 - val_loss: 0.2541 - val_accuracy: 0.9110
# Epoch 8/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.2525 - accuracy: 0.9040 - val_loss: 0.2603 - val_accuracy: 0.9000
# Epoch 9/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2663 - accuracy: 0.8980 - val_loss: 0.2416 - val_accuracy: 0.9116
# Epoch 10/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.2326 - accuracy: 0.9135 - val_loss: 0.2106 - val_accuracy: 0.9288
# Epoch 11/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2266 - accuracy: 0.9167 - val_loss: 0.2034 - val_accuracy: 0.9295
# Epoch 12/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2205 - accuracy: 0.9162 - val_loss: 0.1918 - val_accuracy: 0.9322
# Epoch 13/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2072 - accuracy: 0.9239 - val_loss: 0.1942 - val_accuracy: 0.9377
# Epoch 14/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2056 - accuracy: 0.9212 - val_loss: 0.1972 - val_accuracy: 0.9349
# Epoch 15/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2047 - accuracy: 0.9222 - val_loss: 0.1713 - val_accuracy: 0.9377
# Epoch 16/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1931 - accuracy: 0.9267 - val_loss: 0.1722 - val_accuracy: 0.9404
# Epoch 17/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2306 - accuracy: 0.9131 - val_loss: 0.1849 - val_accuracy: 0.9336
# Epoch 18/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1911 - accuracy: 0.9260 - val_loss: 0.1754 - val_accuracy: 0.9370
# Epoch 19/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1849 - accuracy: 0.9265 - val_loss: 0.1621 - val_accuracy: 0.9445
# Epoch 20/30
# 92/92 [==============================] - 3s 37ms/step - loss: 0.1816 - accuracy: 0.9285 - val_loss: 0.1487 - val_accuracy: 0.9445
# Epoch 21/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1754 - accuracy: 0.9311 - val_loss: 0.1515 - val_accuracy: 0.9466
# Epoch 22/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1708 - accuracy: 0.9327 - val_loss: 0.2107 - val_accuracy: 0.9274
# Epoch 23/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1752 - accuracy: 0.9327 - val_loss: 0.1572 - val_accuracy: 0.9404
# Epoch 24/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1668 - accuracy: 0.9351 - val_loss: 0.1416 - val_accuracy: 0.9445
# Epoch 25/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1630 - accuracy: 0.9354 - val_loss: 0.1555 - val_accuracy: 0.9418
# Epoch 26/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1641 - accuracy: 0.9381 - val_loss: 0.1460 - val_accuracy: 0.9445
# Epoch 27/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1578 - accuracy: 0.9397 - val_loss: 0.1581 - val_accuracy: 0.9438
# Epoch 28/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1560 - accuracy: 0.9387 - val_loss: 0.1382 - val_accuracy: 0.9493
# Epoch 29/30
# 92/92 [==============================] - 3s 35ms/step - loss: 0.1504 - accuracy: 0.9459 - val_loss: 0.1480 - val_accuracy: 0.9445
# Epoch 30/30
# 92/92 [==============================] - 3s 36ms/step - loss: 0.1532 - accuracy: 0.9393 - val_loss: 0.1454 - val_accuracy: 0.9445
# Restoring model weights from the end of the best epoch: 28.
# 29/29 [==============================] - 2s 13ms/step
# Fold 5 Results: Accuracy=0.9303, Precision=0.9275, Recall=0.9124, F1=0.9199, ROC-AUC==0.9820, Time=124.71s
# --- Analysis for: tcn_model_mb_precompute_seqOut - Twitter ---
# --------------------------------------------------
#
# [Raw Results per Fold]
#    Fold  Accuracy  Precision    Recall  F1-Score   ROC-AUC  Training Time (s)  Dataset
# 0     1  0.935307   0.959569  0.890000  0.923476  0.983844         123.380901  Twitter
# 1     2  0.941338   0.947097  0.917500  0.932063  0.984572         123.770805  Twitter
# 2     3  0.917215   0.911280  0.898750  0.904972  0.970723         125.233026  Twitter
# 3     4  0.949561   0.944654  0.939925  0.942284  0.987872         125.350754  Twitter
# 4     5  0.930335   0.927481  0.912390  0.919874  0.981977         124.710778  Twitter
#
# [Summary Statistics]
#                          mean       std
# Accuracy             0.934751  0.012146
# Precision            0.938016  0.018820
# Recall               0.911713  0.019166
# F1-Score             0.924534  0.013940
# ROC-AUC              0.981797  0.006547
# Training Time (s)  124.489253  0.878787
# --------------------------------------------------
#
# [Total Training Time]: 622.4462645053864 seconds
# 18828

# %%
def analyze_model_performance(all_results_list):
    """
    Analyzes and visualizes the performance of model variants from a list of result DataFrames.

    Args:
        all_results_list (list): A list of pandas DataFrames, each containing the results
                                 of a cross-validation run for a specific model variant.
    """
    all_results = pd.concat(all_results_list, ignore_index=True)
    print(all_results)
    # --- Summary Statistics ---
    print("--- Summary Statistics (Mean and Standard Deviation) ---")
    summary_stats = all_results.groupby(['Dataset', 'Variant']).agg({
        'Accuracy': ['mean', 'std'],
        'Precision': ['mean', 'std'],
        'Recall': ['mean', 'std'],
        'F1-Score': ['mean', 'std'],
        'ROC-AUC': ['mean','std'],
        'Training Time (s)': ['mean', 'std']
    })
    print(tabulate(summary_stats, headers='keys', tablefmt='psql'))
    print("\n" + "="*80 + "\n")

    # --- Total Training Time Statistics ---
    print("--- Total Training Time per Variant ---")
    total_time_stats = all_results.groupby(['Dataset', 'Variant'])['Training Time (s)'].sum().reset_index()
    total_time_stats = total_time_stats.rename(columns={'Training Time (s)': 'Total Training Time (s)'})
    print(tabulate(total_time_stats, headers='keys', tablefmt='psql', showindex=False))
    print("\n" + "="*80 + "\n")

    datasets = all_results['Dataset'].unique()
    metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score', 'Training Time (s)']

    for dataset in datasets:
        print(f"--- Analysis for {dataset} Dataset ---")
        dataset_results = all_results[all_results['Dataset'] == dataset]

        # --- Line Plots ---
        print(f"\n--- Line Plots for {dataset} Dataset ---")
        for metric in metrics:
            plt.figure(figsize=(15, 8))
            sns.lineplot(data=dataset_results, x='Fold', y=metric, hue='Variant', marker='o')
            plt.title(f'Line Plot of {metric} for {dataset} Dataset')
            plt.ylabel(metric)
            plt.xlabel('Fold')
            plt.grid(True)
            plt.legend(loc='lower right')
            plt.show()
            print("")

        # --- Box Plots ---
        print(f"\n--- Box Plots for {dataset} Dataset ---")
        for metric in metrics:
            plt.figure(figsize=(15, 8))
            sns.boxplot(data=dataset_results, x='Variant', y=metric)
            plt.title(f'Box Plot of {metric} for {dataset} Dataset')
            plt.ylabel(metric)
            plt.xlabel('Variant')
            plt.xticks(rotation=15)
            plt.grid(True)
            plt.show()
            print("")

        print("\n" + "="*80 + "\n")

    # --- Overall Bar Charts for Training Time ---
    print(f"\n--- Overall Bar Charts for Training Time Comparison ---")

    # --- Bar Chart for Mean Training Time ---
    mean_time_stats = summary_stats['Training Time (s)']['mean'].reset_index()
    plt.figure(figsize=(18, 10))
    ax = sns.barplot(data=mean_time_stats, x='Variant', y='mean', hue='Dataset', dodge=True)
    for container in ax.containers:
      ax.bar_label(container, fmt='%.2f')
    plt.title('Mean Training Time per Fold (Twitter Datasets)')
    plt.ylabel('Mean Training Time (s)')
    plt.xlabel('Variant')
    plt.xticks(rotation=25, ha='right')
    plt.grid(axis='y', linestyle='--')
    plt.show()
    print("")

    # --- Bar Chart for Total Training Time ---
    plt.figure(figsize=(18, 10))
    ax = sns.barplot(data=total_time_stats, x='Variant', y='Total Training Time (s)', hue='Dataset', dodge=True)
    for container in ax.containers:
      ax.bar_label(container, fmt='%.2f')
    plt.title('Total Training Time (Twitter Datasets)')
    plt.ylabel('Total Training Time (s)')
    plt.xlabel('Variant')
    plt.xticks(rotation=25, ha='right')
    plt.grid(axis='y', linestyle='--')
    plt.show()

    return summary_stats

# %%
summary_stats = analyze_model_performance(all_results)

output_filename = f'/content/drive/MyDrive/final_FYP_results/{folder_name}/twitter_results_preprocess.csv'
all_results_pd = pd.concat(all_results, ignore_index=True)
all_results_pd.to_csv(output_filename, index=False)
summary_stats.to_csv(f'/content/drive/MyDrive/final_FYP_results/{folder_name}/twitter_summary_stats_preprocess.csv')
# Out:
#     Fold  Accuracy  Precision    Recall  F1-Score   ROC-AUC  \
# 0      1  0.942434   0.959049  0.907500  0.932563  0.982930
# 1      2  0.935855   0.932826  0.920000  0.926369  0.978029
# 2      3  0.926535   0.926923  0.903750  0.915190  0.971073
# 3      4  0.949561   0.969456  0.913642  0.940722  0.987701
# 4      5  0.928140   0.905340  0.933667  0.919285  0.982559
# 5      1  0.944627   0.962914  0.908750  0.935048  0.984243
# 6      2  0.919956   0.900735  0.918750  0.909653  0.975398
# 7      3  0.924890   0.933333  0.892500  0.912460  0.975658
# 8      4  0.939145   0.926799  0.934919  0.930841  0.986774
# 9      5  0.930883   0.928662  0.912390  0.920455  0.977920
# 10     1  0.940241   0.952818  0.908750  0.930262  0.985233
# 11     2  0.929276   0.913687  0.926250  0.919926  0.979431
# 12     3  0.934759   0.946265  0.902500  0.923864  0.979288
# 13     4  0.949561   0.970706  0.912390  0.940645  0.988370
# 14     5  0.934723   0.934783  0.914894  0.924731  0.979814
# 15     1  0.954496   0.944238  0.952500  0.948351  0.988707
# 16     2  0.947368   0.930318  0.951250  0.940667  0.987241
# 17     3  0.944627   0.945223  0.927500  0.936278  0.984231
# 18     4  0.957237   0.956907  0.944931  0.950882  0.990718
# 19     5  0.937466   0.918193  0.941176  0.929543  0.984688
# 20     1  0.948465   0.942356  0.940000  0.941176  0.986821
# 21     2  0.951206   0.950570  0.937500  0.943990  0.987743
# 22     3  0.933662   0.925972  0.922500  0.924233  0.983925
# 23     4  0.947917   0.931373  0.951189  0.941176  0.990194
# 24     5  0.936369   0.904142  0.956195  0.929440  0.985686
# 25     1  0.897478   0.908123  0.852500  0.879433  0.966143
# 26     2  0.899671   0.907530  0.858750  0.882466  0.957196
# 27     3  0.897478   0.888466  0.876250  0.882316  0.960918
# 28     4  0.907895   0.910273  0.876095  0.892857  0.964716
# 29     5  0.875480   0.847932  0.872340  0.859963  0.952459
# 30     1  0.921601   0.949384  0.867500  0.906597  0.976146
# 31     2  0.916118   0.927345  0.877500  0.901734  0.970026
# 32     3  0.916118   0.925099  0.880000  0.901986  0.971206
# 33     4  0.933114   0.931210  0.914894  0.922980  0.978447
# 34     5  0.915524   0.897657  0.911139  0.904348  0.972734
# 35     1  0.929825   0.957766  0.878750  0.916558  0.982493
# 36     2  0.940789   0.948187  0.915000  0.931298  0.980543
# 37     3  0.926535   0.930233  0.900000  0.914867  0.977196
# 38     4  0.898026   0.849487  0.932416  0.889021  0.974787
# 39     5  0.922655   0.888889  0.941176  0.914286  0.977511
# 40     1  0.935307   0.959569  0.890000  0.923476  0.983844
# 41     2  0.941338   0.947097  0.917500  0.932063  0.984572
# 42     3  0.917215   0.911280  0.898750  0.904972  0.970723
# 43     4  0.949561   0.944654  0.939925  0.942284  0.987872
# 44     5  0.930335   0.927481  0.912390  0.919874  0.981977
#
#     Training Time (s)                                            Variant  \
# 0          615.173294  baseline_tcn_model_fine_tune_sb_pool_no_early_...
# 1          612.334074  baseline_tcn_model_fine_tune_sb_pool_no_early_...
# 2          610.044009  baseline_tcn_model_fine_tune_sb_pool_no_early_...
# 3          610.243202  baseline_tcn_model_fine_tune_sb_pool_no_early_...
# 4          614.550603  baseline_tcn_model_fine_tune_sb_pool_no_early_...
# 5          340.937136                        tcn_model_fine_tune_sb_pool
# 6          321.783820                        tcn_model_fine_tune_sb_pool
# 7          325.248180                        tcn_model_fine_tune_sb_pool
# 8          382.972803                        tcn_model_fine_tune_sb_pool
# 9          381.025045                        tcn_model_fine_tune_sb_pool
# 10         414.360306                      tcn_model_fine_tune_sb_seqOut
# 11         397.065814                      tcn_model_fine_tune_sb_seqOut
# 12         478.980929                      tcn_model_fine_tune_sb_seqOut
# 13         480.564809                      tcn_model_fine_tune_sb_seqOut
# 14         439.865971                      tcn_model_fine_tune_sb_seqOut
# 15         966.265458                        tcn_model_fine_tune_mb_pool
# 16        1028.891036                        tcn_model_fine_tune_mb_pool
# 17        1031.899612                        tcn_model_fine_tune_mb_pool
# 18         969.659389                        tcn_model_fine_tune_mb_pool
# 19         847.189808                        tcn_model_fine_tune_mb_pool
# 20        1050.760271                      tcn_model_fine_tune_mb_seqOut
# 21        1116.426562                      tcn_model_fine_tune_mb_seqOut
# 22         928.887438                      tcn_model_fine_tune_mb_seqOut
# 23        1180.864969                      tcn_model_fine_tune_mb_seqOut
# 24        1430.932087                      tcn_model_fine_tune_mb_seqOut
# 25          64.186728                       tcn_model_sb_precompute_pool
# 26          63.844421                       tcn_model_sb_precompute_pool
# 27          66.153586                       tcn_model_sb_precompute_pool
# 28          49.447752                       tcn_model_sb_precompute_pool
# 29          48.698824                       tcn_model_sb_precompute_pool
# 30         111.816015                     tcn_model_sb_precompute_seqOut
# 31         112.428130                     tcn_model_sb_precompute_seqOut
# 32         110.568349                     tcn_model_sb_precompute_seqOut
# 33         112.441074                     tcn_model_sb_precompute_seqOut
# 34         111.261928                     tcn_model_sb_precompute_seqOut
# 35          68.232956                       tcn_model_mb_precompute_pool
# 36          67.269093                       tcn_model_mb_precompute_pool
# 37          68.658186                       tcn_model_mb_precompute_pool
# 38          42.318593                       tcn_model_mb_precompute_pool
# 39          66.480725                       tcn_model_mb_precompute_pool
# 40         123.380901                     tcn_model_mb_precompute_seqOut
# 41         123.770805                     tcn_model_mb_precompute_seqOut
# 42         125.233026                     tcn_model_mb_precompute_seqOut
# 43         125.350754                     tcn_model_mb_precompute_seqOut
# 44         124.710778                     tcn_model_mb_precompute_seqOut
#
#     Dataset
# 0   Twitter
# 1   Twitter
# 2   Twitter
# 3   Twitter
# 4   Twitter
# 5   Twitter
# 6   Twitter
# 7   Twitter
# 8   Twitter
# 9   Twitter
# 10  Twitter
# 11  Twitter
# 12  Twitter
# 13  Twitter
# 14  Twitter
# 15  Twitter
# 16  Twitter
# 17  Twitter
# 18  Twitter
# 19  Twitter
# 20  Twitter
# 21  Twitter
# 22  Twitter
# 23  Twitter
# 24  Twitter
# 25  Twitter
# 26  Twitter
# 27  Twitter
# 28  Twitter
# 29  Twitter
# 30  Twitter
# 31  Twitter
# 32  Twitter
# 33  Twitter
# 34  Twitter
# 35  Twitter
# 36  Twitter
# 37  Twitter
# 38  Twitter
# 39  Twitter
# 40  Twitter
# 41  Twitter
# 42  Twitter
# 43  Twitter
# 44  Twitter
# --- Summary Statistics (Mean and Standard Deviation) ---
# +-------------------------------------------------------------------+------------------------+-----------------------+-------------------------+------------------------+----------------------+---------------------+------------------------+-----------------------+-----------------------+----------------------+---------------------------------+--------------------------------+
# |                                                                   |   ('Accuracy', 'mean') |   ('Accuracy', 'std') |   ('Precision', 'mean') |   ('Precision', 'std') |   ('Recall', 'mean') |   ('Recall', 'std') |   ('F1-Score', 'mean') |   ('F1-Score', 'std') |   ('ROC-AUC', 'mean') |   ('ROC-AUC', 'std') |   ('Training Time (s)', 'mean') |   ('Training Time (s)', 'std') |
# |-------------------------------------------------------------------+------------------------+-----------------------+-------------------------+------------------------+----------------------+---------------------+------------------------+-----------------------+-----------------------+----------------------+---------------------------------+--------------------------------|
# | ('Twitter', 'baseline_tcn_model_fine_tune_sb_pool_no_early_stop') |               0.936505 |            0.00968778 |                0.938719 |              0.02572   |             0.915712 |          0.0117854  |               0.926826 |            0.0102283  |              0.980458 |           0.00626429 |                        612.469  |                       2.37167  |
# | ('Twitter', 'tcn_model_fine_tune_mb_pool')                        |               0.948239 |            0.00790527 |                0.938976 |              0.0149595 |             0.943472 |          0.0100562  |               0.941144 |            0.00873587 |              0.987117 |           0.00272688 |                        968.781  |                      74.8143   |
# | ('Twitter', 'tcn_model_fine_tune_mb_seqOut')                      |               0.943524 |            0.00792427 |                0.930883 |              0.0177387 |             0.941477 |          0.0131251  |               0.936003 |            0.00864469 |              0.986874 |           0.00233948 |                       1141.57   |                     186.673    |
# | ('Twitter', 'tcn_model_fine_tune_sb_pool')                        |               0.9319   |            0.0100907  |                0.930489 |              0.0221455 |             0.913462 |          0.01542    |               0.921691 |            0.0111106  |              0.979999 |           0.00520223 |                        350.393  |                      29.7486   |
# | ('Twitter', 'tcn_model_fine_tune_sb_seqOut')                      |               0.937712 |            0.00767499 |                0.943652 |              0.0212092 |             0.912957 |          0.00877244 |               0.927886 |            0.00803024 |              0.982427 |           0.00414887 |                        442.168  |                      37.5576   |
# | ('Twitter', 'tcn_model_mb_precompute_pool')                       |               0.923566 |            0.0157935  |                0.914912 |              0.0450999 |             0.913468 |          0.0250791  |               0.913206 |            0.0152263  |              0.978506 |           0.00302399 |                         62.5919 |                      11.3647   |
# | ('Twitter', 'tcn_model_mb_precompute_seqOut')                     |               0.934751 |            0.0121456  |                0.938016 |              0.0188205 |             0.911713 |          0.0191661  |               0.924534 |            0.0139397  |              0.981797 |           0.00654728 |                        124.489  |                       0.878787 |
# | ('Twitter', 'tcn_model_sb_precompute_pool')                       |               0.8956   |            0.0120375  |                0.892465 |              0.0264027 |             0.867187 |          0.0108966  |               0.879407 |            0.0120083  |              0.960286 |           0.00559325 |                         58.4663 |                       8.6238   |
# | ('Twitter', 'tcn_model_sb_precompute_seqOut')                     |               0.920495 |            0.00747469 |                0.926139 |              0.0185729 |             0.890207 |          0.0213824  |               0.907529 |            0.00886034 |              0.973712 |           0.00350602 |                        111.703  |                       0.80083  |
# +-------------------------------------------------------------------+------------------------+-----------------------+-------------------------+------------------------+----------------------+---------------------+------------------------+-----------------------+-----------------------+----------------------+---------------------------------+--------------------------------+
#
# ================================================================================
#
# --- Total Training Time per Variant ---
# +-----------+----------------------------------------------------+---------------------------+
# | Dataset   | Variant                                            |   Total Training Time (s) |
# |-----------+----------------------------------------------------+---------------------------|
# | Twitter   | baseline_tcn_model_fine_tune_sb_pool_no_early_stop |                  3062.35  |
# | Twitter   | tcn_model_fine_tune_mb_pool                        |                  4843.91  |
# | Twitter   | tcn_model_fine_tune_mb_seqOut                      |                  5707.87  |
# | Twitter   | tcn_model_fine_tune_sb_pool                        |                  1751.97  |
# | Twitter   | tcn_model_fine_tune_sb_seqOut                      |                  2210.84  |
# | Twitter   | tcn_model_mb_precompute_pool                       |                   312.96  |
# | Twitter   | tcn_model_mb_precompute_seqOut                     |                   622.446 |
# | Twitter   | tcn_model_sb_precompute_pool                       |                   292.331 |
# | Twitter   | tcn_model_sb_precompute_seqOut                     |                   558.515 |
# +-----------+----------------------------------------------------+---------------------------+
#
# ================================================================================
#
# --- Analysis for Twitter Dataset ---
#
# --- Line Plots for Twitter Dataset ---
# --- Box Plots for Twitter Dataset ---
# ================================================================================
#
#
# --- Overall Bar Charts for Training Time Comparison ---

# %%
print(history_list)
print('=================================================================================================================================================================================================================')
print(history_df)
history_df = pd.DataFrame(history_list)
history_df.to_excel(f'/content/drive/MyDrive/final_FYP_results/{folder_name}/history.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2174259717.py in <cell line: 0>()
# ----> 1 print(history_list)
#       2 print('=================================================================================================================================================================================================================')
#       3 print(history_df)
#       4 history_df = pd.DataFrame(history_list)
#       5 history_df.to_excel(f'/content/drive/MyDrive/final_FYP_results/{folder_name}/history.xlsx', index=False)
#
# NameError: name 'history_list' is not defined

# %%
print(all_histories)
print('=================================================================================================================================================================================================================')
history_df = pd.DataFrame(all_histories)
print(history_df)
history_df.to_excel(f'/content/drive/MyDrive/final_FYP_results/{folder_name}/history.xlsx', index=False)
# Out:
# [{'fold': 1, 'train_loss': [0.5911473631858826, 0.3687628209590912, 0.30686768889427185, 0.2680218517780304, 0.23191110789775848, 0.19699278473854065, 0.2008591741323471, 0.15778414905071259, 0.1399327963590622, 0.11557294428348541, 0.12430915236473083, 0.09443975239992142, 0.09947731345891953, 0.0837145671248436, 0.07397535443305969, 0.07093340903520584, 0.052082497626543045, 0.0447695292532444, 0.042370352894067764, 0.04699309542775154, 0.05103712156414986, 0.028704872354865074, 0.04504730924963951, 0.029311394318938255, 0.022082898765802383, 0.07023481279611588, 0.02825002372264862, 0.023924775421619415, 0.01983918622136116, 0.014904612675309181], 'val_loss': [0.45832520723342896, 0.30765092372894287, 0.25709840655326843, 0.24701592326164246, 0.21825678646564484, 0.20616640150547028, 0.20830997824668884, 0.20052951574325562, 0.19278113543987274, 0.20278367400169373, 0.19962677359580994, 0.2794557213783264, 0.22040851414203644, 0.23068495094776154, 0.2772350013256073, 0.20962725579738617, 0.23359103500843048, 0.26428183913230896, 0.27518028020858765, 0.2345505803823471, 0.2403458207845688, 0.3227001130580902, 0.2695764899253845, 0.2876757085323334, 0.31661587953567505, 0.2848644256591797, 0.2607463002204895, 0.29651159048080444, 0.3176552355289459, 0.3664032518863678], 'train_accuracy': [0.807573676109314, 0.863433837890625, 0.880226194858551, 0.891706645488739, 0.9076422452926636, 0.925119936466217, 0.9258053302764893, 0.9422549605369568, 0.9485949277877808, 0.9566484093666077, 0.9557916522026062, 0.9671007394790649, 0.964873194694519, 0.9715558886528015, 0.9749828577041626, 0.976353645324707, 0.9830363392829895, 0.9852638840675354, 0.9871487617492676, 0.9857779145240784, 0.9845784902572632, 0.9917752146720886, 0.9854352474212646, 0.9902330636978149, 0.9929746389389038, 0.9818368554115295, 0.9921178817749023, 0.9922892451286316, 0.994859516620636, 0.9955449104309082], 'val_accuracy': [0.8197395205497742, 0.8677176237106323, 0.8855380415916443, 0.8944482803344727, 0.9184373021125793, 0.9225496649742126, 0.9211788773536682, 0.9280328750610352, 0.9307745099067688, 0.9294037222862244, 0.9342014789581299, 0.9218642711639404, 0.9259766936302185, 0.9348869323730469, 0.931459903717041, 0.9362577199935913, 0.9410555362701416, 0.938313901424408, 0.9355723261833191, 0.9348869323730469, 0.9369431138038635, 0.9239205121994019, 0.9369431138038635, 0.9307745099067688, 0.931459903717041, 0.9342014789581299, 0.9321452975273132, 0.938313901424408, 0.9321452975273132, 0.9389992952346802], 'Variant': 'baseline_tcn_model_fine_tune_sb_pool_no_early_stop'}, {'fold': 2, 'train_loss': [0.567293643951416, 0.3744669556617737, 0.3072343170642853, 0.26710858941078186, 0.21788975596427917, 0.19130049645900726, 0.18282204866409302, 0.15031182765960693, 0.13819831609725952, 0.1185738742351532, 0.11340264976024628, 0.08848123997449875, 0.10137584060430527, 0.0785621777176857, 0.07103973627090454, 0.05504969507455826, 0.06317907571792603, 0.0449933260679245, 0.04679448530077934, 0.03866254910826683, 0.03791546821594238, 0.03371585160493851, 0.02955462411046028, 0.05077144876122475, 0.08522886782884598, 0.021672483533620834, 0.01794108748435974, 0.021202510222792625, 0.0257138442248106, 0.01074625551700592], 'val_loss': [0.40726855397224426, 0.27331072092056274, 0.2175651639699936, 0.18375198543071747, 0.18273720145225525, 0.15453559160232544, 0.15533070266246796, 0.14573277533054352, 0.13994525372982025, 0.14297954738140106, 0.1582939475774765, 0.1587561070919037, 0.16953547298908234, 0.16571128368377686, 0.17558731138706207, 0.1857130527496338, 0.20424379408359528, 0.2636316120624542, 0.21772883832454681, 0.22364678978919983, 0.2690785229206085, 0.23538094758987427, 0.2189958542585373, 0.19285307824611664, 0.1768936663866043, 0.22534708678722382, 0.26009953022003174, 0.276510626077652, 0.2356642633676529, 0.2650611102581024], 'train_accuracy': [0.7299520373344421, 0.8627484440803528, 0.8790267109870911, 0.8896504640579224, 0.9129540920257568, 0.92460590600 ...
# =================================================================================================================================================================================================================
#      fold                                         train_loss  \
# 0       1  [0.5911473631858826, 0.3687628209590912, 0.306...
# 1       2  [0.567293643951416, 0.3744669556617737, 0.3072...
# 2       3  [0.5060751438140869, 0.3511335253715515, 0.288...
# 3       4  [0.5932727456092834, 0.4053136110305786, 0.321...
# 4       5  [0.6068081855773926, 0.43104231357574463, 0.34...
# ..    ...                                                ...
# 220     1  [0.6882638931274414, 0.6838489174842834, 0.677...
# 221     2  [0.6873559951782227, 0.6782068014144897, 0.632...
# 222     3  [0.6906444430351257, 0.6793757677078247, 0.650...
# 223     4  [0.6547876596450806, 0.5348842740058899, 0.447...
# 224     5  [0.6859668493270874, 0.6660921573638916, 0.560...
#
#                                               val_loss  \
# 0    [0.45832520723342896, 0.30765092372894287, 0.2...
# 1    [0.40726855397224426, 0.27331072092056274, 0.2...
# 2    [0.44889354705810547, 0.4113673269748688, 0.22...
# 3    [0.5296972990036011, 0.5218737721443176, 0.439...
# 4    [0.5191579461097717, 0.6814079880714417, 0.253...
# ..                                                 ...
# 220  [0.6856687068939209, 0.6807435750961304, 0.672...
# 221  [0.6829214692115784, 0.6649841666221619, 0.568...
# 222  [0.6850746870040894, 0.6690654754638672, 0.619...
# 223  [0.5984817147254944, 0.527733325958252, 0.4437...
# 224  [0.6774039268493652, 0.6413163542747498, 0.588...
#
#                                         train_accuracy  \
# 0    [0.807573676109314, 0.863433837890625, 0.88022...
# 1    [0.7299520373344421, 0.8627484440803528, 0.879...
# 2    [0.823680579662323, 0.8658327460289001, 0.8869...
# 3    [0.7256682515144348, 0.8490404486656189, 0.875...
# 4    [0.7081905603408813, 0.851439356803894, 0.8755...
# ..                                                 ...
# 220  [0.5613433718681335, 0.561686098575592, 0.5616...
# 221  [0.5618574619293213, 0.561686098575592, 0.5618...
# 222  [0.562714159488678, 0.6206305623054504, 0.8152...
# 223  [0.5618574619293213, 0.7135024070739746, 0.874...
# 224  [0.5688828229904175, 0.6343386173248291, 0.851...
#
#                                           val_accuracy  \
# 0    [0.8197395205497742, 0.8677176237106323, 0.885...
# 1    [0.8553804159164429, 0.8944482803344727, 0.905...
# 2    [0.8032899498939514, 0.8005483150482178, 0.914...
# 3    [0.7738176584243774, 0.7422892451286316, 0.812...
# 4    [0.800000011920929, 0.6671232581138611, 0.9041...
# ..                                                 ...
# 220  [0.5613433718681335, 0.5613433718681335, 0.561...
# 221  [0.5613433718681335, 0.5613433718681335, 0.561...
# 222  [0.5750514268875122, 0.7950651049613953, 0.727...
# 223  [0.5613433718681335, 0.7916381359100342, 0.834...
# 224  [0.5616438388824463, 0.8732876777648926, 0.732...
#
#                                                Variant
# 0    baseline_tcn_model_fine_tune_sb_pool_no_early_...
# 1    baseline_tcn_model_fine_tune_sb_pool_no_early_...
# 2    baseline_tcn_model_fine_tune_sb_pool_no_early_...
# 3    baseline_tcn_model_fine_tune_sb_pool_no_early_...
# 4    baseline_tcn_model_fine_tune_sb_pool_no_early_...
# ..                                                 ...
# 220                     tcn_model_mb_precompute_seqOut
# 221                     tcn_model_mb_precompute_seqOut
# 222                     tcn_model_mb_precompute_seqOut
# 223                     tcn_model_mb_precompute_seqOut
# 224                     tcn_model_mb_precompute_seqOut
#
# [225 rows x 6 columns]

# %%
def list_to_tuple(val):
    return tuple(val) if isinstance(val, list) else val

history_df_no_dup = history_df.applymap(list_to_tuple)
history_df_no_dup = history_df_no_dup.drop_duplicates()

print(history_df_no_dup)
history_df_no_dup.to_excel(f'/content/drive/MyDrive/final_FYP_results/{folder_name}/history_df_no_dup.xlsx', index=False)
# Out:
#      fold                                         train_loss  \
# 0       1  (0.5911473631858826, 0.3687628209590912, 0.306...
# 1       2  (0.567293643951416, 0.3744669556617737, 0.3072...
# 2       3  (0.5060751438140869, 0.3511335253715515, 0.288...
# 3       4  (0.5932727456092834, 0.4053136110305786, 0.321...
# 4       5  (0.6068081855773926, 0.43104231357574463, 0.34...
# 25      1  (0.5837842226028442, 0.4121329188346863, 0.327...
# 26      2  (0.6464885473251343, 0.4302617609500885, 0.330...
# 27      3  (0.6106582880020142, 0.3871268332004547, 0.314...
# 28      4  (0.6462860107421875, 0.46285590529441833, 0.34...
# 29      5  (0.6539533734321594, 0.5258998870849609, 0.444...
# 50      1  (0.5940830111503601, 0.4753703773021698, 0.419...
# 51      2  (0.5962064862251282, 0.4716838002204895, 0.410...
# 52      3  (0.6595433354377747, 0.504814088344574, 0.4347...
# 53      4  (0.6450799107551575, 0.5268362164497375, 0.468...
# 54      5  (0.6867110133171082, 0.668612003326416, 0.5572...
# 75      1  (0.5718110203742981, 0.2994309365749359, 0.220...
# 76      2  (0.655301034450531, 0.41982945799827576, 0.269...
# 77      3  (0.6809048652648926, 0.5652832388877869, 0.356...
# 78      4  (0.638936460018158, 0.4328782558441162, 0.2996...
# 79      5  (0.6701260805130005, 0.5239548683166504, 0.332...
# 100     1  (0.6619650721549988, 0.49519819021224976, 0.39...
# 101     2  (0.63150554895401, 0.45054471492767334, 0.3773...
# 102     3  (0.612821102142334, 0.4650076925754547, 0.3259...
# 103     4  (0.6857832074165344, 0.6162458062171936, 0.494...
# 104     5  (0.687049925327301, 0.6558234691619873, 0.5275...
# 125     1  (0.670136034488678, 0.5999700427055359, 0.4688...
# 126     2  (0.6787658929824829, 0.6325597167015076, 0.509...
# 127     3  (0.6478030681610107, 0.5036916732788086, 0.393...
# 128     4  (0.6636699438095093, 0.5751647353172302, 0.465...
# 129     5  (0.6706090569496155, 0.5866457223892212, 0.438...
# 150     1  (0.6773914098739624, 0.6263635754585266, 0.546...
# 151     2  (0.6673510670661926, 0.6023421287536621, 0.532...
# 152     3  (0.6892971396446228, 0.656417191028595, 0.5802...
# 153     4  (0.6616678833961487, 0.566622793674469, 0.4883...
# 154     5  (0.6925514340400696, 0.6869086027145386, 0.683...
# 175     1  (0.6776557564735413, 0.6095543503761292, 0.437...
# 176     2  (0.6702589988708496, 0.5813703536987305, 0.401...
# 177     3  (0.6776357293128967, 0.6135872006416321, 0.456...
# 178     4  (0.6591317653656006, 0.5208938121795654, 0.348...
# 179     5  (0.6656708121299744, 0.5515313148498535, 0.407...
# 200     1  (0.6882638931274414, 0.6838489174842834, 0.677...
# 201     2  (0.6873559951782227, 0.6782068014144897, 0.632...
# 202     3  (0.6906444430351257, 0.6793757677078247, 0.650...
# 203     4  (0.6547876596450806, 0.5348842740058899, 0.447...
# 204     5  (0.6859668493270874, 0.6660921573638916, 0.560...
#
#                                               val_loss  \
# 0    (0.45832520723342896, 0.30765092372894287, 0.2...
# 1    (0.40726855397224426, 0.27331072092056274, 0.2...
# 2    (0.44889354705810547, 0.4113673269748688, 0.22...
# 3    (0.5296972990036011, 0.5218737721443176, 0.439...
# 4    (0.5191579461097717, 0.6814079880714417, 0.253...
# 25   (0.48089659214019775, 0.37396708130836487, 0.2...
# 26   (0.5223393440246582, 0.31995031237602234, 0.27...
# 27   (0.4451232850551605, 0.29738909006118774, 0.33...
# 28   (0.5651161670684814, 0.5511200428009033, 0.439...
# 29   (0.5726945996284485, 0.45774540305137634, 0.41...
# 50   (0.5273541212081909, 0.45880886912345886, 0.43...
# 51   (0.5006217956542969, 0.41846832633018494, 0.35...
# 52   (0.5485957860946655, 0.7243726253509521, 0.377...
# 53   (0.5986631512641907, 0.5324721932411194, 0.557...
# 54   (0.6791471838951111, 0.6418486833572388, 0.552...
# 75   (0.3656283915042877, 0.2265367954969406, 0.207...
# 76   (0.5630275011062622, 0.27082815766334534, 0.17...
# 77   (0.649300217628479, 0.45246684551239014, 0.234...
# 78   (0.54243004322052, 0.6592357754707336, 0.53139...
# 79   (0.6223993301391602, 0.3706120252609253, 0.224...
# 100  (0.574495255947113, 0.429475873708725, 0.37996...
# 101  (0.603193461894989, 0.5366423726081848, 0.2614...
# 102  (0.5282928943634033, 0.3714248538017273, 0.249...
# 103  (0.6769741773605347, 0.5844548344612122, 0.685...
# 104  (0.6807084083557129, 0.6253371238708496, 0.430...
# 125  (0.6428017020225525, 0.5344566106796265, 0.433...
# 126  (0.6586955189704895, 0.5725417137145996, 0.416...
# 127  (0.5846704244613647, 0.4339235723018646, 0.383...
# 128  (0.6257256865501404, 0.513701319694519, 0.4313...
# 129  (0.6390233039855957, 0.5026674270629883, 0.402...
# 150  (0.656851589679718, 0.627108097076416, 0.51258...
# 151  (0.636536717414856, 0.5523756146430969, 0.4859...
# 152  (0.6761237978935242, 0.6140623092651367, 0.471...
# 153  (0.6584802269935608, 0.5863245725631714, 0.454...
# 154  (0.6887452602386475, 0.6846898198127747, 0.681...
# 175  (0.6528984308242798, 0.5397483110427856, 0.337...
# 176  (0.6370125412940979, 0.48816901445388794, 0.31...
# 177  (0.6519469618797302, 0.5469933152198792, 0.349...
# 178  (0.6028925776481628, 0.4222721755504608, 0.312...
# 179  (0.6218136548995972, 0.46772727370262146, 0.34...
# 200  (0.6856687068939209, 0.6807435750961304, 0.672...
# 201  (0.6829214692115784, 0.6649841666221619, 0.568...
# 202  (0.6850746870040894, 0.6690654754638672, 0.619...
# 203  (0.5984817147254944, 0.527733325958252, 0.4437...
# 204  (0.6774039268493652, 0.6413163542747498, 0.588...
#
#                                         train_accuracy  \
# 0    (0.807573676109314, 0.863433837890625, 0.88022...
# 1    (0.7299520373344421, 0.8627484440803528, 0.879...
# 2    (0.823680579662323, 0.8658327460289001, 0.8869...
# 3    (0.7256682515144348, 0.8490404486656189, 0.875...
# 4    (0.7081905603408813, 0.851439356803894, 0.8755...
# 25   (0.7030500173568726, 0.8579506278038025, 0.871...
# 26   (0.7443454265594482, 0.8553804159164429, 0.875...
# 27   (0.7676490545272827, 0.8594927787780762, 0.879...
# 28   (0.7623372077941895, 0.8495544791221619, 0.857...
# 29   (0.6533584594726562, 0.8440712690353394, 0.868...
# 50   (0.6166895031929016, 0.8495544791221619, 0.853...
# 51   (0.6163468360900879, 0.8450993895530701, 0.872...
# 52   (0.5591158270835876, 0.8144276738166809, 0.830...
# 53   (0.561686098575592, 0.773646354675293, 0.85880...
# 54   (0.5598012208938599, 0.5615147352218628, 0.677...
# 75   (0.8265935778617859, 0.8989033699035645, 0.923...
# 76   (0.6790609955787659, 0.8944482803344727, 0.909...
# 77   (0.568540096282959, 0.8199108839035034, 0.8995...
# 78   (0.6016107201576233, 0.891192615032196, 0.9045...
# 79   (0.5630568861961365, 0.8110007047653198, 0.898...
# 100  (0.561686098575592, 0.7236120700836182, 0.9100...
# 101  (0.7220699191093445, 0.869773805141449, 0.8953...
# 102  (0.6336531639099121, 0.8661754727363586, 0.876...
# 103  (0.561686098575592, 0.5620287656784058, 0.8202...
# 104  (0.5615147352218628, 0.5615147352218628, 0.625...
# 125  (0.5620287656784058, 0.6718642711639404, 0.839...
# 126  (0.5529472231864929, 0.694139838218689, 0.8252...
# 127  (0.6679232120513916, 0.8401302099227905, 0.846...
# 128  (0.5676833391189575, 0.7498286366462708, 0.838...
# 129  (0.7011651992797852, 0.8286497592926025, 0.840...
# 150  (0.5618574619293213, 0.5639136433601379, 0.729...
# 151  (0.5632282495498657, 0.5777930021286011, 0.775...
# 152  (0.5959561467170715, 0.7594242691993713, 0.819...
# 153  (0.561686098575592, 0.6958533525466919, 0.8274...
# 154  (0.5221042037010193, 0.5657985210418701, 0.561...
# 175  (0.5759081840515137, 0.8173406720161438, 0.891...
# 176  (0.5959561467170715, 0.8415010571479797, 0.891...
# 177  (0.6985949277877808, 0.87440025806427, 0.88982...
# 178  (0.7534270286560059, 0.8805688619613647, 0.892...
# 179  (0.7440027594566345, 0.8497258424758911, 0.883...
# 200  (0.5613433718681335, 0.561686098575592, 0.5616...
# 201  (0.5618574619293213, 0.561686098575592, 0.5618...
# 202  (0.562714159488678, 0.6206305623054504, 0.8152...
# 203  (0.5618574619293213, 0.7135024070739746, 0.874...
# 204  (0.5688828229904175, 0.6343386173248291, 0.851...
#
#                                           val_accuracy  \
# 0    (0.8197395205497742, 0.8677176237106323, 0.885...
# 1    (0.8553804159164429, 0.8944482803344727, 0.905...
# 2    (0.8032899498939514, 0.8005483150482178, 0.914...
# 3    (0.7738176584243774, 0.7422892451286316, 0.812...
# 4    (0.800000011920929, 0.6671232581138611, 0.9041...
# 25   (0.8211103677749634, 0.840986967086792, 0.8821...
# 26   (0.8471555709838867, 0.8848526477813721, 0.898...
# 27   (0.8430432081222534, 0.8855380415916443, 0.851...
# 28   (0.8382453918457031, 0.7354352474212646, 0.793...
# 29   (0.8452054858207703, 0.8794520497322083, 0.861...
# 50   (0.8279643654823303, 0.8348183631896973, 0.851...
# 51   (0.851953387260437, 0.8601782321929932, 0.8869...
# 52   (0.5860178470611572, 0.45784783363342285, 0.83...
# 53   (0.5613433718681335, 0.8423577547073364, 0.710...
# 54   (0.5616438388824463, 0.5616438388824463, 0.836...
# 75   (0.8848526477813721, 0.9156956672668457, 0.923...
# 76   (0.8958190679550171, 0.9122686982154846, 0.940...
# 77   (0.7738176584243774, 0.8869088292121887, 0.925...
# 78   (0.8841672539710999, 0.592186450958252, 0.7525...
# 79   (0.5616438388824463, 0.9260274171829224, 0.921...
# 100  (0.5613433718681335, 0.9047292470932007, 0.925...
# 101  (0.8115147352218628, 0.891706645488739, 0.9095...
# 102  (0.8512679934501648, 0.8368745446205139, 0.908...
# 103  (0.5613433718681335, 0.5784783959388733, 0.490...
# 104  (0.5616438388824463, 0.5616438388824463, 0.925...
# 125  (0.5613433718681335, 0.8286497592926025, 0.825...
# 126  (0.5969842076301575, 0.8259081840515137, 0.835...
# 127  (0.8224811553955078, 0.830020546913147, 0.8368...
# 128  (0.7004798054695129, 0.8272789716720581, 0.827...
# 129  (0.8253424763679504, 0.8260273933410645, 0.831...
# 150  (0.5613433718681335, 0.5613433718681335, 0.833...
# 151  (0.5613433718681335, 0.6100068688392639, 0.838...
# 152  (0.7895818948745728, 0.7854694724082947, 0.851...
# 153  (0.5613433718681335, 0.7758738994598389, 0.834...
# 154  (0.5616438388824463, 0.5616438388824463, 0.561...
# 175  (0.8375599980354309, 0.8882796168327332, 0.882...
# 176  (0.8533241748809814, 0.8958190679550171, 0.895...
# 177  (0.8827964067459106, 0.8800548315048218, 0.892...
# 178  (0.8704591989517212, 0.8759424090385437, 0.887...
# 179  (0.7712329030036926, 0.8321917653083801, 0.898...
# 200  (0.5613433718681335, 0.5613433718681335, 0.561...
# 201  (0.5613433718681335, 0.5613433718681335, 0.561...
# 202  (0.5750514268875122, 0.7950651049613953, 0.727...
# 203  (0.5613433718681335, 0.7916381359100342, 0.834...
# 204  (0.5616438388824463, 0.8732876777648926, 0.732...
#
#                                                Variant
# 0    baseline_tcn_model_fine_tune_sb_pool_no_early_...
# 1    baseline_tcn_model_fine_tune_sb_pool_no_early_...
# 2    baseline_tcn_model_fine_tune_sb_pool_no_early_...
# 3    baseline_tcn_model_fine_tune_sb_pool_no_early_...
# 4    baseline_tcn_model_fine_tune_sb_pool_no_early_...
# 25                         tcn_model_fine_tune_sb_pool
# 26                         tcn_model_fine_tune_sb_pool
# 27                         tcn_model_fine_tune_sb_pool
# 28                         tcn_model_fine_tune_sb_pool
# 29                         tcn_model_fine_tune_sb_pool
# 50                       tcn_model_fine_tune_sb_seqOut
# 51                       tcn_model_fine_tune_sb_seqOut
# 52                       tcn_model_fine_tune_sb_seqOut
# 53                       tcn_model_fine_tune_sb_seqOut
# 54                       tcn_model_fine_tune_sb_seqOut
# 75                         tcn_model_fine_tune_mb_pool
# 76                         tcn_model_fine_tune_mb_pool
# 77                         tcn_model_fine_tune_mb_pool
# 78                         tcn_model_fine_tune_mb_pool
# 79                         tcn_model_fine_tune_mb_pool
# 100                      tcn_model_fine_tune_mb_seqOut
# 101                      tcn_model_fine_tune_mb_seqOut
# 102                      tcn_model_fine_tune_mb_seqOut
# 103                      tcn_model_fine_tune_mb_seqOut
# 104                      tcn_model_fine_tune_mb_seqOut
# 125                       tcn_model_sb_precompute_pool
# 126                       tcn_model_sb_precompute_pool
# 127                       tcn_model_sb_precompute_pool
# 128                       tcn_model_sb_precompute_pool
# 129                       tcn_model_sb_precompute_pool
# 150                     tcn_model_sb_precompute_seqOut
# 151                     tcn_model_sb_precompute_seqOut
# 152                     tcn_model_sb_precompute_seqOut
# 153                     tcn_model_sb_precompute_seqOut
# 154                     tcn_model_sb_precompute_seqOut
# 175                       tcn_model_mb_precompute_pool
# 176                       tcn_model_mb_precompute_pool
# 177                       tcn_model_mb_precompute_pool
# 178                       tcn_model_mb_precompute_pool
# 179                       tcn_model_mb_precompute_pool
# 200                     tcn_model_mb_precompute_seqOut
# 201                     tcn_model_mb_precompute_seqOut
# 202                     tcn_model_mb_precompute_seqOut
# 203                     tcn_model_mb_precompute_seqOut
# 204                     tcn_model_mb_precompute_seqOut
